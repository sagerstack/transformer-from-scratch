# %% [markdown]
# # HW 2 - Descriptive Notebook
#
# In this homework notebook, we will create a Wasserstein GAN with Convolution and Transpose Convolution layers for the MNIST Digit Generation dataset.
#
# Get familiar with the code and write a small report (2 pages max), with answers to the questions listed at the end of the notebook.
#
# **The report must be submitted in PDF format, before April 15th, 11.59pm!**
#
# Do not forget to write your name and student ID on the report.
#
# You may also submit your own copy of the notebook along with the report. If you do so, please add your name and ID to the cell below.

# %%
# Name: Sagar Pratap Singh
# Student ID: 1010736

# %%
# Dependencies for SUTD Cluster env
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ### Imports needed

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
from torch import Tensor
from torch.autograd import Variable
import torch.autograd as autograd
from torchvision.utils import save_image

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'mps')
print(device)
# Out:
# cuda

# %% [markdown]
# ### Dataset and dataloader

# %%
# Image transform to be applied to dataset
# - Tensor conversion
transform = transforms.Compose([transforms.ToTensor()])

# %%
# MNIST train dataset
mnist = torchvision.datasets.MNIST(root = './data/',
                                   train = True,
                                   transform = transform,
                                   download = True)

# %%
# Data loader
batch_size = 32
data_loader = torch.utils.data.DataLoader(dataset = mnist,
                                          batch_size = batch_size,
                                          shuffle = True)

# %% [markdown]
# ### Critic model as a set of Conv2d layers

# %% [markdown]
# **Task1:** Rewrite the Critic model below, so that it uses Conv2d layers instead of fully connected ones shown in class.
#
# You may look for inspiration in the encoder models used in Notebook 3 (W9S1 lecture).
#
# The critic should use three Conv2d layers with progressive downsampling.
#
# We do not advise to add more layers to the mix (BatchNorm, Dropout, etc.).

# %%
# Critic
class Critic(nn.Module):

    def __init__(self, image_size):
        """
        Only forced parameter will be the image size, set to 28.
        """
        super().__init__()
        assert image_size == 28, "This architecture is written for 28x28 MNIST."

        self.net = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=4, stride=2, padding=1),   # 28 -> 14
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=1),  # 14 -> 7
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(32, 1, kernel_size=7, stride=1, padding=0)    # 7 -> 1
        )

    def forward(self, x):
        x = self.net(x)                  # (B, 1, 1, 1)
        return x.view(x.size(0), 1)      # (B, 1)

# %% [markdown]
# ### Generator model as a set of Transposed Conv2d layers

# %% [markdown]
# **Task2:** Rewrite the Generator model below, so that it uses Transposed Conv2d layers instead of fully connected ones shown in class.
#
# You may look for inspiration in the encoder models used in Notebooks 2 and 3 (W9S1 lecture).
#
# The critic should use three Transposed Conv2d layers with progressive upsampling.
#
# We do not advise to add more layers to the mix (BatchNorm, Dropout, etc.).

# %%
# Generator
class Generator(nn.Module):

    def __init__(self, latent_size, image_size):
        """
        Only forced parameters will be the image size, set to 28,
        and the latent size set to 64.
        """
        super().__init__()
        assert image_size == 28, "This architecture is written for 28x28 MNIST."

        self.net = nn.Sequential(
            nn.ConvTranspose2d(latent_size, 32, kernel_size=7, stride=1, padding=0),   # 1 -> 7
            nn.ReLU(inplace=True),

            nn.ConvTranspose2d(32, 16, kernel_size=4, stride=2, padding=1),             # 7 -> 14
            nn.ReLU(inplace=True),

            nn.ConvTranspose2d(16, 1, kernel_size=4, stride=2, padding=1),              # 14 -> 28
            nn.Sigmoid()
        )

    def forward(self, x):
        x = x.view(x.size(0), x.size(1), 1, 1)   # (B, 64) -> (B, 64, 1, 1)
        return self.net(x)

# %% [markdown]
# ### Trainer function
#
# **Task 3:** Decide on a number of iterations num_epochs for training!

# %%
# Hyperparameters for model generation and training
latent_size = 64
image_size = 28
num_epochs = 50
batch_size = 64
lambda_gp = 10
n_critic = 5

# %%
# Create discriminator model
f = Critic(image_size)
f.to(device)
# Out:
# Critic(
#   (net): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Conv2d(16, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (3): LeakyReLU(negative_slope=0.2, inplace=True)
#     (4): Conv2d(32, 1, kernel_size=(7, 7), stride=(1, 1))
#   )
# )

# %%
# Create generator model
G = Generator(latent_size, image_size)
G.to(device)
# Out:
# Generator(
#   (net): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(7, 7), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): ConvTranspose2d(32, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): ConvTranspose2d(16, 1, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (5): Sigmoid()
#   )
# )

# %%
# Losses and optimizers
d_optimizer = torch.optim.Adam(f.parameters(), lr = 0.0002)
g_optimizer = torch.optim.Adam(G.parameters(), lr = 0.0002)

d_optimizer = torch.optim.Adam(f.parameters(), lr=0.0002, betas=(0.5,0.9))
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002, betas=(0.5,0.9))

# %%
# History trackers for training curves
# Keeping track of losses
d_losses = np.zeros(num_epochs)
g_losses = np.zeros(num_epochs)

# %% [markdown]
# **Note: running the cell below (our trainer function) will take a long time!**

# %%
total_step = len(data_loader)
for epoch in range(num_epochs):
  for i, (images, _) in enumerate(data_loader):

      images = images.to(device)

      # TRAIN CRITIC (n_critic steps per G step)
      for _ in range(n_critic):
          outputs_real = f(images)

          z = torch.randn(images.size(0), latent_size).to(device)
          fake_images = G(z).detach()
          outputs_fake = f(fake_images)

          # Gradient penalty on interpolated samples
          alpha = torch.rand(images.size(0), 1, 1, 1).to(device)
          interpolated = (alpha * images + (1 - alpha) * fake_images).requires_grad_(True)
          d_interpolated = f(interpolated)

          gradients = autograd.grad(
              outputs=d_interpolated,
              inputs=interpolated,
              grad_outputs=torch.ones_like(d_interpolated),
              create_graph=True,
              retain_graph=True)[0]
          gradients = gradients.view(gradients.size(0), -1)
          gradient_penalty = ((gradients.norm(2, dim=1) - 1) ** 2).mean()

          d_loss = -outputs_real.mean() + outputs_fake.mean() + lambda_gp * gradient_penalty

          d_optimizer.zero_grad()
          d_loss.backward()
          d_optimizer.step()

      # NO weight clipping

      # TRAIN GENERATOR
      z = torch.randn(images.size(0), latent_size).to(device)
      fake_images = G(z)
      outputs = f(fake_images)

      g_loss = -outputs.mean()

      g_optimizer.zero_grad()
      g_loss.backward()
      g_optimizer.step()

      # LOGGING
      d_losses[epoch] = d_losses[epoch] * (i/(i+1.)) + d_loss.item() * (1./(i+1.))
      g_losses[epoch] = g_losses[epoch] * (i/(i+1.)) + g_loss.item() * (1./(i+1.))

      if (i+1) % 200 == 0:
          print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss:{:.4f}'
                .format(epoch, num_epochs, i+1, total_step,d_loss.item(), g_loss.item()))
# Out:
# Epoch [0/50], Step [200/1875], d_loss: -9.3035, g_loss:-7.6232
# Epoch [0/50], Step [400/1875], d_loss: -7.7891, g_loss:-4.3121
# Epoch [0/50], Step [600/1875], d_loss: -6.1861, g_loss:-5.8887
# Epoch [0/50], Step [800/1875], d_loss: -5.3451, g_loss:-12.2207
# Epoch [0/50], Step [1000/1875], d_loss: -4.8172, g_loss:-13.6012
# Epoch [0/50], Step [1200/1875], d_loss: -3.6929, g_loss:-12.8525
# Epoch [0/50], Step [1400/1875], d_loss: -2.6695, g_loss:-10.3680
# Epoch [0/50], Step [1600/1875], d_loss: -1.9218, g_loss:-8.0023
# Epoch [0/50], Step [1800/1875], d_loss: -1.5104, g_loss:-6.9632
# Epoch [1/50], Step [200/1875], d_loss: -1.2765, g_loss:-6.2170
# Epoch [1/50], Step [400/1875], d_loss: -1.4059, g_loss:-4.4837
# Epoch [1/50], Step [600/1875], d_loss: -1.3155, g_loss:-4.1965
# Epoch [1/50], Step [800/1875], d_loss: -1.2100, g_loss:-4.2484
# Epoch [1/50], Step [1000/1875], d_loss: -1.0620, g_loss:-4.3117
# Epoch [1/50], Step [1200/1875], d_loss: -1.1450, g_loss:-4.0804
# Epoch [1/50], Step [1400/1875], d_loss: -1.0564, g_loss:-2.5900
# Epoch [1/50], Step [1600/1875], d_loss: -1.1350, g_loss:-1.8126
# Epoch [1/50], Step [1800/1875], d_loss: -0.9634, g_loss:-2.3937
# Epoch [2/50], Step [200/1875], d_loss: -1.1315, g_loss:-2.3678
# Epoch [2/50], Step [400/1875], d_loss: -0.9671, g_loss:-1.5437
# Epoch [2/50], Step [600/1875], d_loss: -0.9209, g_loss:-0.5613
# Epoch [2/50], Step [800/1875], d_loss: -0.9630, g_loss:-1.1925
# Epoch [2/50], Step [1000/1875], d_loss: -0.8886, g_loss:-2.9313
# Epoch [2/50], Step [1200/1875], d_loss: -0.9179, g_loss:-0.8930
# Epoch [2/50], Step [1400/1875], d_loss: -0.8602, g_loss:-2.1530
# Epoch [2/50], Step [1600/1875], d_loss: -0.6733, g_loss:-1.6840
# Epoch [2/50], Step [1800/1875], d_loss: -1.0827, g_loss:-3.0762
# Epoch [3/50], Step [200/1875], d_loss: -0.6507, g_loss:-1.6305
# Epoch [3/50], Step [400/1875], d_loss: -0.8464, g_loss:-2.5312
# Epoch [3/50], Step [600/1875], d_loss: -0.6783, g_loss:-2.1795
# Epoch [3/50], Step [800/1875], d_loss: -0.6851, g_loss:-2.2369
# Epoch [3/50], Step [1000/1875], d_loss: -0.5632, g_loss:-2.5229
# Epoch [3/50], Step [1200/1875], d_loss: -0.7739, g_loss:-2.6001
# Epoch [3/50], Step [1400/1875], d_loss: -0.8851, g_loss:-2.0286
# Epoch [3/50], Step [1600/1875], d_loss: -0.7713, g_loss:-2.9134
# Epoch [3/50], Step [1800/1875], d_loss: -0.8832, g_loss:-1.7062
# Epoch [4/50], Step [200/1875], d_loss: -0.8046, g_loss:-1.3462
# Epoch [4/50], Step [400/1875], d_loss: -0.5475, g_loss:-1.7422
# Epoch [4/50], Step [600/1875], d_loss: -0.6398, g_loss:-2.2665
# Epoch [4/50], Step [800/1875], d_loss: -0.6549, g_loss:-1.0111
# Epoch [4/50], Step [1000/1875], d_loss: -0.7010, g_loss:-1.6253
# Epoch [4/50], Step [1200/1875], d_loss: -0.7188, g_loss:-2.0914
# Epoch [4/50], Step [1400/1875], d_loss: -0.6294, g_loss:-2.1995
# Epoch [4/50], Step [1600/1875], d_loss: -0.8021, g_loss:-0.5521
# Epoch [4/50], Step [1800/1875], d_loss: -0.3861, g_loss:-2.0224
# Epoch [5/50], Step [200/1875], d_loss: -0.8177, g_loss:-2.5540
# Epoch [5/50], Step [400/1875], d_loss: -0.5281, g_loss:-1.6978
# Epoch [5/50], Step [600/1875], d_loss: -0.5119, g_loss:-1.6433
# Epoch [5/50], Step [800/1875], d_loss: -0.5931, g_loss:-1.6562
# Epoch [5/50], Step [1000/1875], d_loss: -0.6849, g_loss:-1.5397
# Epoch [5/50], Step [1200/1875], d_loss: -0.7422, g_loss:-0.0985
# Epoch [5/50], Step [1400/1875], d_loss: -0.5561, g_loss:-1.9615
# Epoch [5/50], Step [1600/1875], d_loss: -0.3840, g_loss:-3.3553
# Epoch [5/50], Step [1800/1875], d_loss: -0.4252, g_loss:-1.2618
# Epoch [6/50], Step [200/1875], d_loss: -0.5013, g_loss:-1.9274
# Epoch [6/50], Step [400/1875], d_loss: -0.4402, g_loss:-1.5815
# Epoch [6/50], Step [600/1875], d_loss: -0.4278, g_loss:-2.1369
# Epoch [6/50], Step [800/1875], d_loss: -0.7413, g_loss:0.2396
# Epoch [6/50], Step [1000/1875], d_loss: -0.7321, g_loss:-1.5195
# Epoch [6/50], Step [1200/1875], d_loss: -0.3928, g_loss:-1.4269
# Epoch [6/50], Step [1400/1875], d_loss: -0.4656, g_loss:-2.3866
# Epoch [6/50], Step [1600/1875], d_loss: -0.5497, g_loss:-1.5231
# Epoch [6/50], Step [1800/1875], d_loss: -0.6720, g_loss:-0.9645
# Epoch [7/50], Step [200/1875], d_loss: -0.5389, g_loss:-2.0344
# Epoch [7/50], Step [400/1875], d_loss: -0.4929, g_loss:-1.9853
# Epoch [7/50], Step [600/1875], d_loss: -0.4828, g_loss:-0.8337
# Epoch [7/50], Step [800/1875], d_loss: -0.3151, g_loss:-1.4303
# Epoch [7/50], Step [1000/1875], d_loss: -0.5314, g_loss:-1.5040
# Epoch [7/50], Step [1200/1875], d_loss: -0.5336, g_loss:-2.2089
# Epoch [7/50], Step [1400/1875], d_loss: -0.6025, g_loss:-1.6622
# Epoch [7/50], Step [1600/1875], d_loss: -0.6045, g_loss:-1.1669
# Epoch [7/50], Step [1800/1875], d_loss: -0.4173, g_loss:-1.1810
# Epoch [8/50], Step [200/1875], d_loss: -0.3758, g_loss:-2.6059
# Epoch [8/50], Step [400/1875], d_loss: -0.4179, g_loss:-1.0299
# Epoch [8/50], Step [600/1875], d_loss: -0.6564, g_loss:-3.2459
# Epoch [8/50], Step [800/1875], d_loss: -0.3776, g_loss:-2.9059
# Epoch [8/50], Step [1000/1875], d_loss: -0.4753, g_loss:-1.2702
# Epoch [8/50], Step [1200/1875], d_loss: -0.5822, g_loss:-3.1471
# Epoch [8/50], Step [1400/1875], d_loss: -0.4712, g_loss:-2.2418
# Epoch [8/50], Step [1600/1875], d_loss: -0.6871, g_loss:-2.9277
# Epoch [8/50], Step [1800/1875], d_loss: -0.3526, g_loss:-0.9263
# Epoch [9/50], Step [200/1875], d_loss: -0.6656, g_loss:-2.1790
# Epoch [9/50], Step [400/1875], d_loss: -0.3061, g_loss:-2.7268
# Epoch [9/50], Step [600/1875], d_loss: -0.3022, g_loss:-2.0207
# Epoch [9/50], Step [800/1875], d_loss: -0.5880, g_loss:-1.9222
# Epoch [9/50], Step [1000/1875], d_loss: -0.4410, g_loss:-2.4824
# Epoch [9/50], Step [1200/1875], d_loss: -0.4719, g_loss:-1.5175
# Epoch [9/50], Step [1400/1875], d_loss: -0.5847, g_loss:-1.6621
# Epoch [9/50], Step [1600/1875], d_loss: -0.4753, g_loss:-2.5158
# Epoch [9/50], Step [1800/1875], d_loss: -0.3971, g_loss:-3.1636
# Epoch [10/50], Step [200/1875], d_loss: -0.4610, g_loss:-1.7832
# Epoch [10/50], Step [400/1875], d_loss: -0.5571, g_loss:-1.5028
# Epoch [10/50], Step [600/1875], d_loss: -0.5517, g_loss:-2.7603
# Epoch [10/50], Step [800/1875], d_loss: -0.4709, g_loss:-2.7703
# Epoch [10/50], Step [1000/1875], d_loss: -0.3333, g_loss:-2.8001
# Epoch [10/50], Step [1200/1875], d_loss: -0.5413, g_loss:-2.4171
# Epoch [10/50], Step [1400/1875], d_loss: -0.6215, g_loss:-2.2488
# Epoch [10/50], Step [1600/1875], d_loss: -0.3192, g_loss:-3.2327
# Epoch [10/50], Step [1800/1875], d_loss: -0.5320, g_loss:-3.0424
# Epoch [11/50], Step [200/1875], d_loss: -0.6039, g_loss:-1.6649
# Epoch [11/50], Step [400/1875], d_loss: -0.4383, g_loss:-3.2383
# Epoch [11/50], Step [600/1875], d_loss: -0.4192, g_loss:-2.8110
# Epoch [11/50], Step [800/1875], d_loss: -0.4390, g_loss:-1.4079
# Epoch [11/50], Step [1000/1875], d_loss: -0.5758, g_loss:-1.8623
# Epoch [11/50], Step [1200/1875], d_loss: -0.3987, g_loss:-2.7676
# Epoch [11/50], Step [1400/1875], d_loss: -0.4239, g_loss:-1.9947
# Epoch [11/50], Step [1600/1875], d_loss: -0.5385, g_loss:-2.2891
# Epoch [11/50], Step [1800/1875], d_loss: -0.6938, g_loss:-3.9534
# Epoch [12/50], Step [200/1875], d_loss: -0.7008, g_loss:-2.0324
# Epoch [12/50], Step [400/1875], d_loss: -0.5717, g_loss:-2.5974
# Epoch [12/50], Step [600/1875], d_loss: -0.4390, g_loss:-3.5629
# Epoch [12/50], Step [800/1875], d_loss: -0.4810, g_loss:-3.1024
# Epoch [12/50], Step [1000/1875], d_loss: -0.5751, g_loss:-2.5453
# Epoch [12/50], Step [1200/1875], d_loss: -0.5743, g_loss:-2.3783
# Epoch [12/50], Step [1400/1875], d_loss: -0.5064, g_loss:-2.0415
# Epoch [12/50], Step [1600/1875], d_loss: -0.4970, g_loss:-2.9187
# Epoch [12/50], Step [1800/1875], d_loss: -0.6877, g_loss:-3.3761
# Epoch [13/50], Step [200/1875], d_loss: -0.5430, g_loss:-3.8050
# Epoch [13/50], Step [400/1875], d_loss: -0.5557, g_loss:-3.1731
# Epoch [13/50], Step [600/1875], d_loss: -0.6423, g_loss:-1.9033
# Epoch [13/50], Step [800/1875], d_loss: -0.2225, g_loss:-2.8245
# Epoch [13/50], Step [1000/1875], d_loss: -0.6061, g_loss:-2.3693
# Epoch [13/50], Step [1200/1875], d_loss: -0.5844, g_loss:-2.2002
# Epoch [13/50], Step [1400/1875], d_loss: -0.5405, g_loss:-3.7268
# Epoch [13/50], Step [1600/1875], d_loss: -0.6290, g_loss:-3.7278
# Epoch [13/50], Step [1800/1875], d_loss: -0.5507, g_loss:-2.6724
# Epoch [14/50], Step [200/1875], d_loss: -0.8061, g_loss:-1.3020
# Epoch [14/50], Step [400/1875], d_loss: -0.3146, g_loss:-3.9975
# Epoch [14/50], Step [600/1875], d_loss: -0.5221, g_loss:-1.9969
# Epoch [14/50], Step [800/1875], d_loss: -0.3096, g_loss:-3.0925
# Epoch [14/50], Step [1000/1875], d_loss: -0.4479, g_loss:-3.0196
# Epoch [14/50], Step [1200/1875], d_loss: -0.8703, g_loss:-5.0375
# Epoch [14/50], Step [1400/1875], d_loss: -0.4383, g_loss:-2.8770
# Epoch [14/50], Step [1600/1875], d_loss: -0.5539, g_loss:-2.8555
# Epoch [14/50], Step [1800/1875], d_loss: -0.5724, g_loss:-2.6294
# Epoch [15/50], Step [200/1875], d_loss: -0.3553, g_loss:-2.4908
# Epoch [15/50], Step [400/1875], d_loss: -0.4264, g_loss:-3.1600
# Epoch [15/50], Step [600/1875], d_loss: -0.3181, g_loss:-2.8519
# Epoch [15/50], Step [800/1875], d_loss: -0.4161, g_loss:-3.6700
# Epoch [15/50], Step [1000/1875], d_loss: -0.4446, g_loss:-3.0637
# Epoch [15/50], Step [1200/1875], d_loss: -0.3123, g_loss:-3.1239
# Epoch [15/50], Step [1400/1875], d_loss: -0.5254, g_loss:-2.3500
# Epoch [15/50], Step [1600/1875], d_loss: -0.4241, g_loss:-3.2878
# Epoch [15/50], Step [1800/1875], d_loss: -0.0776, g_loss:-1.8758
# Epoch [16/50], Step [200/1875], d_loss: -0.4420, g_loss:-3.1202
# Epoch [16/50], Step [400/1875], d_loss: -0.4821, g_loss:-3.2907
# Epoch [16/50], Step [600/1875], d_loss: -0.4682, g_loss:-3.2428
# Epoch [16/50], Step [800/1875], d_loss: -0.5641, g_loss:-3.0456
# Epoch [16/50], Step [1000/1875], d_loss: -0.6278, g_loss:-4.1887
# Epoch [16/50], Step [1200/1875], d_loss: -0.3829, g_loss:-2.4311
# Epoch [16/50], Step [1400/1875], d_loss: -0.4116, g_loss:-1.8521
# Epoch [16/50], Step [1600/1875], d_loss: -0.1661, g_loss:-3.6097
# Epoch [16/50], Step [1800/1875], d_loss: -0.2397, g_loss:-2.2355
# Epoch [17/50], Step [200/1875], d_loss: -0.3992, g_loss:-3.9467
# Epoch [17/50], Step [400/1875], d_loss: -0.5517, g_loss:-3.3964
# Epoch [17/50], Step [600/1875], d_loss: -0.4311, g_loss:-4.0455
# Epoch [17/50], Step [800/1875], d_loss: -0.3847, g_loss:-3.0486
# Epoch [17/50], Step [1000/1875], d_loss: -0.3691, g_loss:-2.5950
# Epoch [17/50], Step [1200/1875], d_loss: -0.4888, g_loss:-3.2387
# Epoch [17/50], Step [1400/1875], d_loss: -0.3505, g_loss:-2.6268
# Epoch [17/50], Step [1600/1875], d_loss: -0.4228, g_loss:-3.9433
# Epoch [17/50], Step [1800/1875], d_loss: -0.4212, g_loss:-2.7899
# Epoch [18/50], Step [200/1875], d_loss: -0.3724, g_loss:-2.9208
# Epoch [18/50], Step [400/1875], d_loss: -0.4683, g_loss:-2.1032
# Epoch [18/50], Step [600/1875], d_loss: -0.4752, g_loss:-3.7400
# Epoch [18/50], Step [800/1875], d_loss: -0.4014, g_loss:-4.1558
# Epoch [18/50], Step [1000/1875], d_loss: -0.4235, g_loss:-3.3004
# Epoch [18/50], Step [1200/1875], d_loss: -0.3948, g_loss:-2.8915
# Epoch [18/50], Step [1400/1875], d_loss: -0.1888, g_loss:-3.3521
# Epoch [18/50], Step [1600/1875], d_loss: -0.3957, g_loss:-4.1415
# Epoch [18/50], Step [1800/1875], d_loss: -0.4503, g_loss:-3.2874
# Epoch [19/50], Step [200/1875], d_loss: -0.5700, g_loss:-4.6071
# Epoch [19/50], Step [400/1875], d_loss: -0.5606, g_loss:-4.9581
# Epoch [19/50], Step [600/1875], d_loss: -0.3324, g_loss:-4.5935
# Epoch [19/50], Step [800/1875], d_loss: -0.3544, g_loss:-3.1156
# Epoch [19/50], Step [1000/1875], d_loss: -0.5232, g_loss:-4.4990
# Epoch [19/50], Step [1200/1875], d_loss: -0.3709, g_loss:-3.0115
# Epoch [19/50], Step [1400/1875], d_loss: -0.3679, g_loss:-4.1229
# Epoch [21/50], Step [1000/1875], d_loss: -0.4497, g_loss:-2.7706
# Epoch [21/50], Step [1200/1875], d_loss: -0.3900, g_loss:-1.9474
# Epoch [21/50], Step [1400/1875], d_loss: -0.3233, g_loss:-3.4875
# Epoch [21/50], Step [1600/1875], d_loss: -0.3412, g_loss:-3.7843
# Epoch [21/50], Step [1800/1875], d_loss: -0.3907, g_loss:-3.7284
# Epoch [22/50], Step [200/1875], d_loss: -0.5283, g_loss:-3.3679
# Epoch [22/50], Step [400/1875], d_loss: -0.4744, g_loss:-3.3981
# Epoch [22/50], Step [600/1875], d_loss: -0.7124, g_loss:-4.2169
# Epoch [22/50], Step [800/1875], d_loss: -0.3400, g_loss:-3.2145
# Epoch [22/50], Step [1000/1875], d_loss: -0.4164, g_loss:-3.6406
# Epoch [22/50], Step [1200/1875], d_loss: -0.4775, g_loss:-3.6521
# Epoch [22/50], Step [1400/1875], d_loss: -0.5156, g_loss:-4.5521
# Epoch [22/50], Step [1600/1875], d_loss: -0.4342, g_loss:-4.2141
# Epoch [22/50], Step [1800/1875], d_loss: -0.4613, g_loss:-4.6284
# Epoch [23/50], Step [200/1875], d_loss: -0.2929, g_loss:-3.1732
# Epoch [23/50], Step [400/1875], d_loss: -0.7056, g_loss:-4.3670
# Epoch [23/50], Step [600/1875], d_loss: -0.4976, g_loss:-2.6053
# Epoch [23/50], Step [800/1875], d_loss: -0.2801, g_loss:-2.8908
# Epoch [23/50], Step [1000/1875], d_loss: -0.3110, g_loss:-2.9935
# Epoch [23/50], Step [1200/1875], d_loss: -0.2148, g_loss:-3.5914
# Epoch [23/50], Step [1400/1875], d_loss: -0.5226, g_loss:-4.6393
# Epoch [23/50], Step [1600/1875], d_loss: -0.3557, g_loss:-4.7656
# Epoch [23/50], Step [1800/1875], d_loss: -0.4618, g_loss:-4.6004
# Epoch [24/50], Step [200/1875], d_loss: -0.4054, g_loss:-4.1755
# Epoch [24/50], Step [400/1875], d_loss: -0.2611, g_loss:-4.4055
# Epoch [24/50], Step [600/1875], d_loss: -0.2788, g_loss:-3.9910
# Epoch [24/50], Step [800/1875], d_loss: -0.5695, g_loss:-3.9170
# Epoch [24/50], Step [1000/1875], d_loss: -0.4461, g_loss:-4.8595
# Epoch [24/50], Step [1200/1875], d_loss: -0.3400, g_loss:-4.2471
# Epoch [24/50], Step [1400/1875], d_loss: -0.5909, g_loss:-4.4533
# Epoch [24/50], Step [1600/1875], d_loss: -0.4265, g_loss:-4.7484
# Epoch [24/50], Step [1800/1875], d_loss: -0.1815, g_loss:-3.7481
# Epoch [25/50], Step [200/1875], d_loss: -0.3272, g_loss:-4.7740
# Epoch [25/50], Step [400/1875], d_loss: -0.3126, g_loss:-4.4660
# Epoch [25/50], Step [600/1875], d_loss: -0.4536, g_loss:-4.0563
# Epoch [25/50], Step [800/1875], d_loss: -0.3928, g_loss:-3.6890
# Epoch [25/50], Step [1000/1875], d_loss: -0.3977, g_loss:-5.2110
# Epoch [25/50], Step [1200/1875], d_loss: -0.2598, g_loss:-4.8229
# Epoch [25/50], Step [1400/1875], d_loss: -0.4544, g_loss:-4.2754
# Epoch [25/50], Step [1600/1875], d_loss: -0.3582, g_loss:-4.2727
# Epoch [25/50], Step [1800/1875], d_loss: -0.2799, g_loss:-4.0582
# Epoch [26/50], Step [200/1875], d_loss: -0.5347, g_loss:-5.0416
# Epoch [26/50], Step [400/1875], d_loss: -0.2656, g_loss:-4.5491
# Epoch [26/50], Step [600/1875], d_loss: -0.3408, g_loss:-2.3486
# Epoch [26/50], Step [800/1875], d_loss: -0.3605, g_loss:-4.5053
# Epoch [26/50], Step [1000/1875], d_loss: -0.2552, g_loss:-4.7379
# Epoch [26/50], Step [1200/1875], d_loss: -0.4925, g_loss:-4.2385
# Epoch [26/50], Step [1400/1875], d_loss: -0.4190, g_loss:-4.2537
# Epoch [26/50], Step [1600/1875], d_loss: -0.2296, g_loss:-4.4820
# Epoch [26/50], Step [1800/1875], d_loss: -0.3580, g_loss:-3.5310
# Epoch [27/50], Step [200/1875], d_loss: -0.3688, g_loss:-4.6865
# Epoch [27/50], Step [400/1875], d_loss: -0.5200, g_loss:-2.3866
# Epoch [27/50], Step [600/1875], d_loss: -0.1393, g_loss:-3.5258
# Epoch [27/50], Step [800/1875], d_loss: -0.2549, g_loss:-4.4981
# Epoch [27/50], Step [1000/1875], d_loss: -0.4494, g_loss:-4.6387
# Epoch [27/50], Step [1200/1875], d_loss: -0.5585, g_loss:-4.7469
# Epoch [27/50], Step [1400/1875], d_loss: -0.4916, g_loss:-3.9645
# Epoch [27/50], Step [1600/1875], d_loss: -0.5670, g_loss:-3.2077
# Epoch [27/50], Step [1800/1875], d_loss: -0.6006, g_loss:-3.6576
# Epoch [28/50], Step [200/1875], d_loss: -0.4340, g_loss:-4.3768
# Epoch [28/50], Step [400/1875], d_loss: -0.5571, g_loss:-2.8658
# Epoch [28/50], Step [600/1875], d_loss: -0.4777, g_loss:-3.9455
# Epoch [28/50], Step [800/1875], d_loss: -0.5363, g_loss:-3.9512
# Epoch [28/50], Step [1000/1875], d_loss: -0.5317, g_loss:-5.8444
# Epoch [28/50], Step [1200/1875], d_loss: -0.5460, g_loss:-2.9464
# Epoch [28/50], Step [1400/1875], d_loss: -0.1761, g_loss:-4.3085
# Epoch [28/50], Step [1600/1875], d_loss: -0.2639, g_loss:-3.2641
# Epoch [28/50], Step [1800/1875], d_loss: -0.5719, g_loss:-5.8057
# Epoch [29/50], Step [200/1875], d_loss: -0.6001, g_loss:-2.8747
# Epoch [29/50], Step [400/1875], d_loss: -0.2254, g_loss:-4.6409
# Epoch [29/50], Step [600/1875], d_loss: -0.2908, g_loss:-4.9623
# Epoch [29/50], Step [800/1875], d_loss: -0.3337, g_loss:-4.2963
# Epoch [29/50], Step [1000/1875], d_loss: -0.4715, g_loss:-3.2754
# Epoch [29/50], Step [1200/1875], d_loss: -0.1452, g_loss:-4.1789
# Epoch [29/50], Step [1400/1875], d_loss: -0.2964, g_loss:-4.1669
# Epoch [29/50], Step [1600/1875], d_loss: -0.3276, g_loss:-3.9373
# Epoch [29/50], Step [1800/1875], d_loss: -0.0171, g_loss:-5.0352
# Epoch [30/50], Step [200/1875], d_loss: -0.4895, g_loss:-4.8503
# Epoch [30/50], Step [400/1875], d_loss: -0.3962, g_loss:-5.4288
# Epoch [30/50], Step [600/1875], d_loss: -0.5195, g_loss:-4.5745
# Epoch [30/50], Step [800/1875], d_loss: -0.3832, g_loss:-4.2238
# Epoch [30/50], Step [1000/1875], d_loss: -0.5279, g_loss:-3.9591
# Epoch [30/50], Step [1200/1875], d_loss: -0.4837, g_loss:-5.0820
# Epoch [30/50], Step [1400/1875], d_loss: -0.3802, g_loss:-2.8329
# Epoch [30/50], Step [1600/1875], d_loss: -0.4368, g_loss:-4.1430
# Epoch [30/50], Step [1800/1875], d_loss: -0.2742, g_loss:-5.2924
# Epoch [31/50], Step [200/1875], d_loss: -0.4735, g_loss:-3.9960
# Epoch [31/50], Step [400/1875], d_loss: -0.3243, g_loss:-5.3186
# Epoch [31/50], Step [600/1875], d_loss: -0.3422, g_loss:-4.9941
# Epoch [31/50], Step [800/1875], d_loss: -0.2557, g_loss:-4.7847
# Epoch [31/50], Step [1000/1875], d_loss: -0.7000, g_loss:-2.6833
# Epoch [31/50], Step [1200/1875], d_loss: -0.4297, g_loss:-4.7776
# Epoch [31/50], Step [1400/1875], d_loss: -0.3085, g_loss:-5.2326
# Epoch [31/50], Step [1600/1875], d_loss: -0.5274, g_loss:-3.2971
# Epoch [31/50], Step [1800/1875], d_loss: -0.5330, g_loss:-4.7341
# Epoch [32/50], Step [200/1875], d_loss: -0.2834, g_loss:-6.0132
# Epoch [32/50], Step [400/1875], d_loss: -0.4937, g_loss:-4.2151
# Epoch [32/50], Step [600/1875], d_loss: -0.2408, g_loss:-3.5263
# Epoch [32/50], Step [800/1875], d_loss: -0.5149, g_loss:-5.3201
# Epoch [32/50], Step [1000/1875], d_loss: -0.2795, g_loss:-5.6612
# Epoch [32/50], Step [1200/1875], d_loss: -0.4520, g_loss:-4.1047
# Epoch [32/50], Step [1400/1875], d_loss: -0.5125, g_loss:-5.9811
# Epoch [32/50], Step [1600/1875], d_loss: -0.2884, g_loss:-4.8079
# Epoch [32/50], Step [1800/1875], d_loss: -0.2990, g_loss:-4.9145
# Epoch [33/50], Step [200/1875], d_loss: -0.5602, g_loss:-5.1018
# Epoch [33/50], Step [400/1875], d_loss: -0.3354, g_loss:-5.3429
# Epoch [33/50], Step [600/1875], d_loss: -0.3541, g_loss:-3.8124
# Epoch [33/50], Step [800/1875], d_loss: -0.6708, g_loss:-3.5930
# Epoch [33/50], Step [1000/1875], d_loss: -0.3887, g_loss:-3.9661
# Epoch [33/50], Step [1200/1875], d_loss: -0.3856, g_loss:-4.7802
# Epoch [33/50], Step [1400/1875], d_loss: -0.4403, g_loss:-3.7654
# Epoch [33/50], Step [1600/1875], d_loss: -0.4624, g_loss:-4.7798
# Epoch [33/50], Step [1800/1875], d_loss: -0.4353, g_loss:-5.7511
# Epoch [34/50], Step [200/1875], d_loss: -0.3383, g_loss:-4.2985
# Epoch [34/50], Step [400/1875], d_loss: -0.2264, g_loss:-5.5429
# Epoch [34/50], Step [600/1875], d_loss: -0.4998, g_loss:-5.7645
# Epoch [34/50], Step [800/1875], d_loss: -0.5435, g_loss:-3.7984
# Epoch [34/50], Step [1000/1875], d_loss: -0.2324, g_loss:-3.7638
# Epoch [34/50], Step [1200/1875], d_loss: -0.4832, g_loss:-4.4658
# Epoch [34/50], Step [1400/1875], d_loss: -0.4349, g_loss:-5.3444
# Epoch [34/50], Step [1600/1875], d_loss: -0.4975, g_loss:-5.3898
# Epoch [34/50], Step [1800/1875], d_loss: -0.2390, g_loss:-5.5524
# Epoch [35/50], Step [200/1875], d_loss: -0.3383, g_loss:-4.5539
# Epoch [35/50], Step [400/1875], d_loss: -0.3666, g_loss:-5.3521
# Epoch [35/50], Step [600/1875], d_loss: -0.3085, g_loss:-5.0260
# Epoch [35/50], Step [800/1875], d_loss: -0.2330, g_loss:-4.7762
# Epoch [35/50], Step [1000/1875], d_loss: -0.5991, g_loss:-3.8291
# Epoch [35/50], Step [1200/1875], d_loss: -0.5854, g_loss:-5.2182
# Epoch [35/50], Step [1400/1875], d_loss: -0.4734, g_loss:-5.8145
# Epoch [35/50], Step [1600/1875], d_loss: -0.1462, g_loss:-5.2033
# Epoch [35/50], Step [1800/1875], d_loss: -0.6073, g_loss:-6.0867
# Epoch [36/50], Step [200/1875], d_loss: -0.2718, g_loss:-5.0882
# Epoch [36/50], Step [400/1875], d_loss: -0.4855, g_loss:-6.1819
# Epoch [36/50], Step [600/1875], d_loss: -0.1652, g_loss:-5.2035
# Epoch [36/50], Step [800/1875], d_loss: -0.3425, g_loss:-5.0448
# Epoch [36/50], Step [1000/1875], d_loss: -0.3932, g_loss:-4.3537
# Epoch [36/50], Step [1200/1875], d_loss: -0.6252, g_loss:-3.9162
# Epoch [36/50], Step [1400/1875], d_loss: -0.3342, g_loss:-5.1791
# Epoch [36/50], Step [1600/1875], d_loss: -0.3044, g_loss:-3.9379
# Epoch [36/50], Step [1800/1875], d_loss: -0.1324, g_loss:-5.6457
# Epoch [37/50], Step [200/1875], d_loss: -0.1872, g_loss:-3.8023
# Epoch [37/50], Step [400/1875], d_loss: -0.1502, g_loss:-4.6409
# Epoch [37/50], Step [600/1875], d_loss: -0.4159, g_loss:-4.1772
# Epoch [37/50], Step [800/1875], d_loss: -0.5381, g_loss:-4.5671
# Epoch [37/50], Step [1000/1875], d_loss: -0.5021, g_loss:-4.6697
# Epoch [37/50], Step [1200/1875], d_loss: -0.2139, g_loss:-5.1920
# Epoch [37/50], Step [1400/1875], d_loss: -0.3340, g_loss:-5.4481
# Epoch [37/50], Step [1600/1875], d_loss: -0.3992, g_loss:-6.1795
# Epoch [37/50], Step [1800/1875], d_loss: -0.0296, g_loss:-4.6434
# Epoch [38/50], Step [200/1875], d_loss: -0.2955, g_loss:-5.6577
# Epoch [38/50], Step [400/1875], d_loss: -0.0277, g_loss:-5.5939
# Epoch [38/50], Step [600/1875], d_loss: -0.2653, g_loss:-5.5235
# Epoch [38/50], Step [800/1875], d_loss: -0.2962, g_loss:-4.9207
# Epoch [38/50], Step [1000/1875], d_loss: -0.5735, g_loss:-5.9583
# Epoch [38/50], Step [1200/1875], d_loss: -0.3593, g_loss:-4.1200
# Epoch [38/50], Step [1400/1875], d_loss: -0.3799, g_loss:-5.8866
# Epoch [38/50], Step [1600/1875], d_loss: -0.2475, g_loss:-4.8635
# Epoch [38/50], Step [1800/1875], d_loss: -0.2610, g_loss:-3.7461
# Epoch [39/50], Step [200/1875], d_loss: -0.2777, g_loss:-5.1332
# Epoch [39/50], Step [400/1875], d_loss: -0.4234, g_loss:-3.9933
# Epoch [39/50], Step [600/1875], d_loss: -0.4332, g_loss:-5.4919
# Epoch [39/50], Step [800/1875], d_loss: -0.1144, g_loss:-5.4871
# Epoch [39/50], Step [1000/1875], d_loss: -0.2732, g_loss:-3.5903
# Epoch [39/50], Step [1200/1875], d_loss: -0.6610, g_loss:-4.4353
# Epoch [39/50], Step [1400/1875], d_loss: -0.2549, g_loss:-3.4410
# Epoch [39/50], Step [1600/1875], d_loss: -0.4252, g_loss:-4.0918
# Epoch [39/50], Step [1800/1875], d_loss: -0.2281, g_loss:-4.5900
# Epoch [40/50], Step [200/1875], d_loss: -0.3160, g_loss:-4.8296
# Epoch [40/50], Step [400/1875], d_loss: -0.3146, g_loss:-4.5398
# Epoch [40/50], Step [600/1875], d_loss: -0.2049, g_loss:-3.7617
# Epoch [40/50], Step [800/1875], d_loss: -0.2549, g_loss:-5.6611
# Epoch [40/50], Step [1000/1875], d_loss: -0.3806, g_loss:-4.5953
# Epoch [40/50], Step [1200/1875], d_loss: -0.1672, g_loss:-3.1359
# Epoch [40/50], Step [1400/1875], d_loss: -0.4001, g_loss:-4.9545
# Epoch [40/50], Step [1600/1875], d_loss: -0.4427, g_loss:-4.0948
# Epoch [40/50], Step [1800/1875], d_loss: -0.4133, g_loss:-5.1434
# Epoch [41/50], Step [200/1875], d_loss: -0.0988, g_loss:-4.1831
# Epoch [41/50], Step [400/1875], d_loss: -0.3739, g_loss:-4.9540
# Epoch [41/50], Step [600/1875], d_loss: -0.5735, g_loss:-5.5856
# Epoch [41/50], Step [800/1875], d_loss: -0.3381, g_loss:-2.6925
# Epoch [41/50], Step [1000/1875], d_loss: -0.6144, g_loss:-5.1976
# Epoch [41/50], Step [1200/1875], d_loss: -0.3505, g_loss:-5.1418
# Epoch [41/50], Step [1400/1875], d_loss: -0.0580, g_loss:-6.2010
# Epoch [41/50], Step [1600/1875], d_loss: -0.1998, g_loss:-4.0777
# Epoch [41/50], Step [1800/1875], d_loss: -0.3347, g_loss:-5.0105
# Epoch [42/50], Step [200/1875], d_loss: -0.3371, g_loss:-5.5036
# Epoch [42/50], Step [400/1875], d_loss: -0.3802, g_loss:-4.6257
# Epoch [42/50], Step [600/1875], d_loss: -0.6640, g_loss:-5.3756
# Epoch [42/50], Step [800/1875], d_loss: -0.2533, g_loss:-5.2821
# Epoch [42/50], Step [1000/1875], d_loss: -0.4160, g_loss:-4.6340
# Epoch [42/50], Step [1200/1875], d_loss: -0.7531, g_loss:-4.3396
# Epoch [42/50], Step [1400/1875], d_loss: 0.0688, g_loss:-3.8062
# Epoch [42/50], Step [1600/1875], d_loss: -0.2843, g_loss:-4.0144
# Epoch [42/50], Step [1800/1875], d_loss: -0.6781, g_loss:-3.3056
# Epoch [43/50], Step [200/1875], d_loss: -0.6133, g_loss:-5.4890
# Epoch [43/50], Step [400/1875], d_loss: -0.3501, g_loss:-4.7171
# Epoch [43/50], Step [600/1875], d_loss: -0.3563, g_loss:-4.0397
# Epoch [43/50], Step [800/1875], d_loss: -0.3097, g_loss:-5.0318
# Epoch [43/50], Step [1000/1875], d_loss: -0.2191, g_loss:-5.1073
# Epoch [43/50], Step [1200/1875], d_loss: -0.2476, g_loss:-4.1951
# Epoch [43/50], Step [1400/1875], d_loss: -0.3888, g_loss:-4.7133
# Epoch [43/50], Step [1600/1875], d_loss: -0.4422, g_loss:-4.8428
# Epoch [43/50], Step [1800/1875], d_loss: -0.1214, g_loss:-3.5560
# Epoch [44/50], Step [200/1875], d_loss: -0.6106, g_loss:-4.0610
# Epoch [44/50], Step [400/1875], d_loss: -0.1004, g_loss:-3.3689
# Epoch [44/50], Step [600/1875], d_loss: -0.2712, g_loss:-4.3307
# Epoch [44/50], Step [800/1875], d_loss: -0.0881, g_loss:-4.1201
# Epoch [44/50], Step [1000/1875], d_loss: -0.2124, g_loss:-4.9484
# Epoch [44/50], Step [1200/1875], d_loss: -0.6504, g_loss:-4.3778
# Epoch [44/50], Step [1400/1875], d_loss: -0.5372, g_loss:-3.6478
# Epoch [44/50], Step [1600/1875], d_loss: -0.3722, g_loss:-4.2479
# Epoch [44/50], Step [1800/1875], d_loss: -0.2911, g_loss:-4.8023
# Epoch [45/50], Step [200/1875], d_loss: -0.3287, g_loss:-5.3280
# Epoch [45/50], Step [400/1875], d_loss: -0.3595, g_loss:-4.5647
# Epoch [45/50], Step [600/1875], d_loss: -0.5012, g_loss:-3.1595
# Epoch [45/50], Step [800/1875], d_loss: -0.2834, g_loss:-4.5373
# Epoch [45/50], Step [1000/1875], d_loss: -0.3902, g_loss:-5.5912
# Epoch [45/50], Step [1200/1875], d_loss: -0.2758, g_loss:-3.9161
# Epoch [45/50], Step [1400/1875], d_loss: -0.5619, g_loss:-4.6893
# Epoch [45/50], Step [1600/1875], d_loss: -0.1976, g_loss:-4.2667
# Epoch [45/50], Step [1800/1875], d_loss: -0.1617, g_loss:-4.8630
# Epoch [46/50], Step [200/1875], d_loss: -0.2136, g_loss:-4.2261
# Epoch [46/50], Step [400/1875], d_loss: -0.3019, g_loss:-4.2816
# Epoch [46/50], Step [600/1875], d_loss: -0.1921, g_loss:-4.5680
# Epoch [46/50], Step [800/1875], d_loss: -0.3457, g_loss:-4.6166
# Epoch [46/50], Step [1000/1875], d_loss: -0.1798, g_loss:-4.3588
# Epoch [46/50], Step [1200/1875], d_loss: -0.3777, g_loss:-3.7948
# Epoch [46/50], Step [1400/1875], d_loss: -0.2543, g_loss:-3.6617
# Epoch [46/50], Step [1600/1875], d_loss: -0.3827, g_loss:-5.3533
# Epoch [46/50], Step [1800/1875], d_loss: -0.0309, g_loss:-4.7899
# Epoch [47/50], Step [200/1875], d_loss: -0.3178, g_loss:-4.4922
# Epoch [47/50], Step [400/1875], d_loss: -0.1147, g_loss:-4.1633
# Epoch [47/50], Step [600/1875], d_loss: -0.4457, g_loss:-5.3501
# Epoch [47/50], Step [800/1875], d_loss: -0.3682, g_loss:-3.2675
# Epoch [47/50], Step [1000/1875], d_loss: -0.4591, g_loss:-4.0174
# Epoch [47/50], Step [1200/1875], d_loss: -0.4279, g_loss:-2.5792
# Epoch [47/50], Step [1400/1875], d_loss: -0.1763, g_loss:-4.6298
# Epoch [47/50], Step [1600/1875], d_loss: -0.3684, g_loss:-4.6347
# Epoch [47/50], Step [1800/1875], d_loss: -0.3073, g_loss:-4.0558
# Epoch [48/50], Step [200/1875], d_loss: -0.2890, g_loss:-3.8754
# Epoch [48/50], Step [400/1875], d_loss: -0.1773, g_loss:-4.8897
# Epoch [48/50], Step [600/1875], d_loss: -0.2663, g_loss:-2.7222
# Epoch [48/50], Step [800/1875], d_loss: -0.3014, g_loss:-3.5881
# Epoch [48/50], Step [1000/1875], d_loss: -0.4243, g_loss:-4.6631
# Epoch [48/50], Step [1200/1875], d_loss: -0.5067, g_loss:-3.4585
# Epoch [48/50], Step [1400/1875], d_loss: -0.3919, g_loss:-4.0569
# Epoch [48/50], Step [1600/1875], d_loss: -0.3403, g_loss:-3.9029
# Epoch [48/50], Step [1800/1875], d_loss: -0.2029, g_loss:-3.0576
# Epoch [49/50], Step [200/1875], d_loss: -0.3372, g_loss:-3.6865
# Epoch [49/50], Step [400/1875], d_loss: -0.4036, g_loss:-3.4291
# Epoch [49/50], Step [600/1875], d_loss: -0.2853, g_loss:-4.2809
# Epoch [49/50], Step [800/1875], d_loss: -0.5368, g_loss:-3.1961
# Epoch [49/50], Step [1000/1875], d_loss: -0.4346, g_loss:-2.3300
# Epoch [49/50], Step [1200/1875], d_loss: -0.3714, g_loss:-4.2587
# Epoch [49/50], Step [1400/1875], d_loss: -0.5192, g_loss:-3.7481
# Epoch [49/50], Step [1600/1875], d_loss: -0.1991, g_loss:-3.2638
# Epoch [49/50], Step [1800/1875], d_loss: -0.2213, g_loss:-4.3966

# %% [markdown]
# ### Visualization

# %%
# Display losses for both the generator and discriminator
plt.figure()
plt.plot(range(1, num_epochs + 1), d_losses, label = 'd loss')
plt.plot(range(1, num_epochs + 1), g_losses, label = 'g loss')
plt.legend()
plt.show()

# %%
n_samples = 16
z = torch.randn(n_samples, latent_size).to(device)
fake_images = G(z)
fake_images = fake_images.cpu().detach().numpy().reshape(n_samples, 28, 28)

fig, axes = plt.subplots(4, 4, figsize=(8, 8))
for idx, ax in enumerate(axes.flat):
  ax.imshow(fake_images[idx], cmap='gray')
  ax.axis('off')
plt.tight_layout()
plt.show()

# %%
# Display
plt.figure()
plt.imshow(fake_images[0])
plt.show()
plt.figure()
plt.imshow(fake_images[1])
plt.show()
plt.figure()
plt.imshow(fake_images[2])
plt.show()
plt.figure()
plt.imshow(fake_images[3])
plt.show()
plt.figure()
plt.imshow(fake_images[4])
plt.show()

# %% [markdown]
# ### Questions and expected answers for the report
#
# 1. [15 points] Copy and paste the code for your Critic class. Briefly explain your choice of architecture.
#
#
# 2. [15 points] Copy and paste the code for your Generator class. Briefly explain your choice of architecture.
#
#
# 3. [5 points] For how many iterations did you have to train when using Wasserstein with Conv/TransposeConv layers to get plausible images from the generator? Is it training faster than the Fully Connected Wasserstein/Vanilla GAN?
#
#
# 4. [5 points] Display some samples generated by your trained generator. Do they look plausible?
#
#
# 5. [10 points] Let us assume we use Conv2d layers in the Critic. We do NOT use Transposed Conv2d layers, but only Fully Connected layers in the Generator. Would the GAN still be able to train both models or would it encounter difficulties? Discuss.
