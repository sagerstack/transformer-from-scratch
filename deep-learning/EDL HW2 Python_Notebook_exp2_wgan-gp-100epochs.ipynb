# %% [markdown]
# # HW 2 - Descriptive Notebook
#
# In this homework notebook, we will create a Wasserstein GAN with Convolution and Transpose Convolution layers for the MNIST Digit Generation dataset.
#
# Get familiar with the code and write a small report (2 pages max), with answers to the questions listed at the end of the notebook.
#
# **The report must be submitted in PDF format, before April 15th, 11.59pm!**
#
# Do not forget to write your name and student ID on the report.
#
# You may also submit your own copy of the notebook along with the report. If you do so, please add your name and ID to the cell below.

# %%
# Name: Sagar Pratap Singh
# Student ID: 1010736

# %%
# Dependencies for SUTD Cluster env
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ### Imports needed

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
from torch import Tensor
from torch.autograd import Variable
import torch.autograd as autograd
from torchvision.utils import save_image

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'mps')
print(device)
# Out:
# cuda

# %% [markdown]
# ### Dataset and dataloader

# %%
# Image transform to be applied to dataset
# - Tensor conversion
transform = transforms.Compose([transforms.ToTensor()])

# %%
# MNIST train dataset
mnist = torchvision.datasets.MNIST(root = './data/',
                                   train = True,
                                   transform = transform,
                                   download = True)

# %%
# Data loader
batch_size = 32
data_loader = torch.utils.data.DataLoader(dataset = mnist,
                                          batch_size = batch_size,
                                          shuffle = True)

# %% [markdown]
# ### Critic model as a set of Conv2d layers

# %% [markdown]
# **Task1:** Rewrite the Critic model below, so that it uses Conv2d layers instead of fully connected ones shown in class.
#
# You may look for inspiration in the encoder models used in Notebook 3 (W9S1 lecture).
#
# The critic should use three Conv2d layers with progressive downsampling.
#
# We do not advise to add more layers to the mix (BatchNorm, Dropout, etc.).

# %%
# Critic
class Critic(nn.Module):

    def __init__(self, image_size):
        """
        Only forced parameter will be the image size, set to 28.
        """
        super().__init__()
        assert image_size == 28, "This architecture is written for 28x28 MNIST."

        self.net = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=4, stride=2, padding=1),   # 28 -> 14
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=1),  # 14 -> 7
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(32, 1, kernel_size=7, stride=1, padding=0)    # 7 -> 1
        )

    def forward(self, x):
        x = self.net(x)                  # (B, 1, 1, 1)
        return x.view(x.size(0), 1)      # (B, 1)

# %% [markdown]
# ### Generator model as a set of Transposed Conv2d layers

# %% [markdown]
# **Task2:** Rewrite the Generator model below, so that it uses Transposed Conv2d layers instead of fully connected ones shown in class.
#
# You may look for inspiration in the encoder models used in Notebooks 2 and 3 (W9S1 lecture).
#
# The critic should use three Transposed Conv2d layers with progressive upsampling.
#
# We do not advise to add more layers to the mix (BatchNorm, Dropout, etc.).

# %%
# Generator
class Generator(nn.Module):

    def __init__(self, latent_size, image_size):
        """
        Only forced parameters will be the image size, set to 28,
        and the latent size set to 64.
        """
        super().__init__()
        assert image_size == 28, "This architecture is written for 28x28 MNIST."

        self.net = nn.Sequential(
            nn.ConvTranspose2d(latent_size, 32, kernel_size=7, stride=1, padding=0),   # 1 -> 7
            nn.ReLU(inplace=True),

            nn.ConvTranspose2d(32, 16, kernel_size=4, stride=2, padding=1),             # 7 -> 14
            nn.ReLU(inplace=True),

            nn.ConvTranspose2d(16, 1, kernel_size=4, stride=2, padding=1),              # 14 -> 28
            nn.Sigmoid()
        )

    def forward(self, x):
        x = x.view(x.size(0), x.size(1), 1, 1)   # (B, 64) -> (B, 64, 1, 1)
        return self.net(x)

# %% [markdown]
# ### Trainer function
#
# **Task 3:** Decide on a number of iterations num_epochs for training!

# %%
# Hyperparameters for model generation and training
latent_size = 64
image_size = 28
num_epochs = 100
batch_size = 64
lambda_gp = 10
n_critic = 5

# %%
# Create discriminator model
f = Critic(image_size)
f.to(device)
# Out:
# Critic(
#   (net): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Conv2d(16, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (3): LeakyReLU(negative_slope=0.2, inplace=True)
#     (4): Conv2d(32, 1, kernel_size=(7, 7), stride=(1, 1))
#   )
# )

# %%
# Create generator model
G = Generator(latent_size, image_size)
G.to(device)
# Out:
# Generator(
#   (net): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(7, 7), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): ConvTranspose2d(32, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): ConvTranspose2d(16, 1, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (5): Sigmoid()
#   )
# )

# %%
# Losses and optimizers
d_optimizer = torch.optim.Adam(f.parameters(), lr = 0.0002)
g_optimizer = torch.optim.Adam(G.parameters(), lr = 0.0002)

d_optimizer = torch.optim.Adam(f.parameters(), lr=0.0002, betas=(0.5,0.9))
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002, betas=(0.5,0.9))

# %%
# History trackers for training curves
# Keeping track of losses
d_losses = np.zeros(num_epochs)
g_losses = np.zeros(num_epochs)

# %% [markdown]
# **Note: running the cell below (our trainer function) will take a long time!**

# %%
total_step = len(data_loader)
for epoch in range(num_epochs):
  for i, (images, _) in enumerate(data_loader):

      images = images.to(device)

      # TRAIN CRITIC (n_critic steps per G step)
      for _ in range(n_critic):
          outputs_real = f(images)

          z = torch.randn(images.size(0), latent_size).to(device)
          fake_images = G(z).detach()
          outputs_fake = f(fake_images)

          # Gradient penalty on interpolated samples
          alpha = torch.rand(images.size(0), 1, 1, 1).to(device)
          interpolated = (alpha * images + (1 - alpha) * fake_images).requires_grad_(True)
          d_interpolated = f(interpolated)

          gradients = autograd.grad(
              outputs=d_interpolated,
              inputs=interpolated,
              grad_outputs=torch.ones_like(d_interpolated),
              create_graph=True,
              retain_graph=True)[0]
          gradients = gradients.view(gradients.size(0), -1)
          gradient_penalty = ((gradients.norm(2, dim=1) - 1) ** 2).mean()

          d_loss = -outputs_real.mean() + outputs_fake.mean() + lambda_gp * gradient_penalty

          d_optimizer.zero_grad()
          d_loss.backward()
          d_optimizer.step()

      # NO weight clipping

      # TRAIN GENERATOR
      z = torch.randn(images.size(0), latent_size).to(device)
      fake_images = G(z)
      outputs = f(fake_images)

      g_loss = -outputs.mean()

      g_optimizer.zero_grad()
      g_loss.backward()
      g_optimizer.step()

      # LOGGING
      d_losses[epoch] = d_losses[epoch] * (i/(i+1.)) + d_loss.item() * (1./(i+1.))
      g_losses[epoch] = g_losses[epoch] * (i/(i+1.)) + g_loss.item() * (1./(i+1.))

      if (i+1) % 200 == 0:
          print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss:{:.4f}'
                .format(epoch, num_epochs, i+1, total_step,d_loss.item(), g_loss.item()))
# Out:
# Epoch [0/100], Step [200/1875], d_loss: -9.1873, g_loss:-1.5893
# Epoch [0/100], Step [400/1875], d_loss: -7.2428, g_loss:-2.1345
# Epoch [0/100], Step [600/1875], d_loss: -5.8298, g_loss:-5.3400
# Epoch [0/100], Step [800/1875], d_loss: -4.9964, g_loss:-8.6010
# Epoch [0/100], Step [1000/1875], d_loss: -4.7031, g_loss:-10.4071
# Epoch [0/100], Step [1200/1875], d_loss: -3.3657, g_loss:-9.6519
# Epoch [0/100], Step [1400/1875], d_loss: -2.4771, g_loss:-9.0159
# Epoch [0/100], Step [1600/1875], d_loss: -1.8920, g_loss:-7.0277
# Epoch [0/100], Step [1800/1875], d_loss: -1.7930, g_loss:-6.0969
# Epoch [1/100], Step [200/1875], d_loss: -1.1662, g_loss:-2.7664
# Epoch [1/100], Step [400/1875], d_loss: -1.2163, g_loss:-3.5073
# Epoch [1/100], Step [600/1875], d_loss: -1.5016, g_loss:-1.8099
# Epoch [1/100], Step [800/1875], d_loss: -1.1702, g_loss:-1.9438
# Epoch [1/100], Step [1000/1875], d_loss: -1.3403, g_loss:-3.1990
# Epoch [1/100], Step [1200/1875], d_loss: -1.0062, g_loss:-1.6005
# Epoch [1/100], Step [1400/1875], d_loss: -1.0872, g_loss:-1.6992
# Epoch [1/100], Step [1600/1875], d_loss: -1.2513, g_loss:-3.7894
# Epoch [1/100], Step [1800/1875], d_loss: -1.2715, g_loss:-1.9592
# Epoch [2/100], Step [200/1875], d_loss: -1.1880, g_loss:-1.4489
# Epoch [2/100], Step [400/1875], d_loss: -0.9577, g_loss:-0.6798
# Epoch [2/100], Step [600/1875], d_loss: -0.8864, g_loss:-1.6429
# Epoch [2/100], Step [800/1875], d_loss: -0.7625, g_loss:-2.2350
# Epoch [2/100], Step [1000/1875], d_loss: -1.0706, g_loss:-1.2517
# Epoch [2/100], Step [1200/1875], d_loss: -0.9088, g_loss:-0.2180
# Epoch [2/100], Step [1400/1875], d_loss: -0.7932, g_loss:0.0357
# Epoch [2/100], Step [1600/1875], d_loss: -1.1623, g_loss:-1.5399
# Epoch [2/100], Step [1800/1875], d_loss: -0.7872, g_loss:0.1589
# Epoch [3/100], Step [200/1875], d_loss: -0.8688, g_loss:-2.1453
# Epoch [3/100], Step [400/1875], d_loss: -0.9888, g_loss:0.6496
# Epoch [3/100], Step [600/1875], d_loss: -0.8836, g_loss:-0.5759
# Epoch [3/100], Step [800/1875], d_loss: -0.7233, g_loss:0.1718
# Epoch [3/100], Step [1000/1875], d_loss: -0.7094, g_loss:-0.4345
# Epoch [3/100], Step [1200/1875], d_loss: -0.8016, g_loss:-1.2593
# Epoch [3/100], Step [1400/1875], d_loss: -1.2423, g_loss:1.7594
# Epoch [3/100], Step [1600/1875], d_loss: -0.7548, g_loss:0.8447
# Epoch [3/100], Step [1800/1875], d_loss: -0.5483, g_loss:0.8606
# Epoch [4/100], Step [200/1875], d_loss: -0.8294, g_loss:-0.9160
# Epoch [4/100], Step [400/1875], d_loss: -0.5521, g_loss:0.7004
# Epoch [4/100], Step [600/1875], d_loss: -0.7477, g_loss:1.3458
# Epoch [4/100], Step [800/1875], d_loss: -0.4971, g_loss:-0.2726
# Epoch [4/100], Step [1000/1875], d_loss: -0.6598, g_loss:1.0075
# Epoch [4/100], Step [1200/1875], d_loss: -0.6074, g_loss:0.9383
# Epoch [4/100], Step [1400/1875], d_loss: -0.5061, g_loss:0.5570
# Epoch [4/100], Step [1600/1875], d_loss: -0.5625, g_loss:-0.5859
# Epoch [4/100], Step [1800/1875], d_loss: -0.8652, g_loss:0.9447
# Epoch [5/100], Step [200/1875], d_loss: -0.6104, g_loss:1.3925
# Epoch [5/100], Step [400/1875], d_loss: -0.5887, g_loss:0.1300
# Epoch [5/100], Step [600/1875], d_loss: -0.5315, g_loss:0.1365
# Epoch [5/100], Step [800/1875], d_loss: -0.6654, g_loss:0.9006
# Epoch [5/100], Step [1000/1875], d_loss: -0.7456, g_loss:1.5050
# Epoch [5/100], Step [1200/1875], d_loss: -0.8276, g_loss:-0.3553
# Epoch [5/100], Step [1400/1875], d_loss: -0.4754, g_loss:0.6545
# Epoch [5/100], Step [1600/1875], d_loss: -0.5180, g_loss:0.1017
# Epoch [5/100], Step [1800/1875], d_loss: -0.4409, g_loss:2.7009
# Epoch [6/100], Step [200/1875], d_loss: -0.4516, g_loss:0.4849
# Epoch [6/100], Step [400/1875], d_loss: -0.7553, g_loss:-0.6352
# Epoch [6/100], Step [600/1875], d_loss: -0.4969, g_loss:0.5932
# Epoch [6/100], Step [800/1875], d_loss: -0.3643, g_loss:1.8923
# Epoch [6/100], Step [1000/1875], d_loss: -0.6373, g_loss:0.9743
# Epoch [6/100], Step [1200/1875], d_loss: -0.3728, g_loss:0.9112
# Epoch [6/100], Step [1400/1875], d_loss: -0.5952, g_loss:1.7548
# Epoch [6/100], Step [1600/1875], d_loss: -0.2200, g_loss:1.2730
# Epoch [6/100], Step [1800/1875], d_loss: -0.0583, g_loss:-0.1103
# Epoch [7/100], Step [200/1875], d_loss: -0.5271, g_loss:-0.3076
# Epoch [7/100], Step [400/1875], d_loss: -0.5229, g_loss:2.3663
# Epoch [7/100], Step [600/1875], d_loss: -0.6556, g_loss:-0.0078
# Epoch [7/100], Step [800/1875], d_loss: -0.6508, g_loss:0.5892
# Epoch [7/100], Step [1000/1875], d_loss: -0.5555, g_loss:0.5569
# Epoch [7/100], Step [1200/1875], d_loss: -0.5002, g_loss:-0.1140
# Epoch [7/100], Step [1400/1875], d_loss: -0.4750, g_loss:-0.9515
# Epoch [7/100], Step [1600/1875], d_loss: -0.6068, g_loss:0.5280
# Epoch [7/100], Step [1800/1875], d_loss: -0.6613, g_loss:2.7660
# Epoch [8/100], Step [200/1875], d_loss: -0.4493, g_loss:1.2490
# Epoch [8/100], Step [400/1875], d_loss: -0.4917, g_loss:1.1257
# Epoch [8/100], Step [600/1875], d_loss: -0.5574, g_loss:0.9714
# Epoch [8/100], Step [800/1875], d_loss: -0.5021, g_loss:-0.2499
# Epoch [8/100], Step [1000/1875], d_loss: -0.1186, g_loss:1.2880
# Epoch [8/100], Step [1200/1875], d_loss: -0.5058, g_loss:0.9446
# Epoch [8/100], Step [1400/1875], d_loss: -0.4256, g_loss:-0.4008
# Epoch [8/100], Step [1600/1875], d_loss: -0.6016, g_loss:-0.4758
# Epoch [8/100], Step [1800/1875], d_loss: -0.6532, g_loss:-0.0856
# Epoch [9/100], Step [200/1875], d_loss: -0.4199, g_loss:0.9447
# Epoch [9/100], Step [400/1875], d_loss: -0.4592, g_loss:1.0684
# Epoch [9/100], Step [600/1875], d_loss: -0.3738, g_loss:1.1591
# Epoch [9/100], Step [800/1875], d_loss: -0.4467, g_loss:0.8847
# Epoch [9/100], Step [1000/1875], d_loss: -0.6165, g_loss:0.8723
# Epoch [9/100], Step [1200/1875], d_loss: -0.4680, g_loss:1.3671
# Epoch [9/100], Step [1400/1875], d_loss: -0.4423, g_loss:1.6990
# Epoch [9/100], Step [1600/1875], d_loss: -0.4800, g_loss:0.0048
# Epoch [9/100], Step [1800/1875], d_loss: -0.4093, g_loss:0.6780
# Epoch [10/100], Step [200/1875], d_loss: -0.6770, g_loss:2.2358
# Epoch [10/100], Step [400/1875], d_loss: -0.5506, g_loss:-0.4530
# Epoch [10/100], Step [600/1875], d_loss: -0.5158, g_loss:1.4654
# Epoch [10/100], Step [800/1875], d_loss: -0.4075, g_loss:1.5387
# Epoch [10/100], Step [1000/1875], d_loss: -0.4780, g_loss:0.4340
# Epoch [10/100], Step [1200/1875], d_loss: -0.4093, g_loss:2.1856
# Epoch [10/100], Step [1400/1875], d_loss: -0.4206, g_loss:1.2388
# Epoch [10/100], Step [1600/1875], d_loss: -0.3165, g_loss:1.0110
# Epoch [10/100], Step [1800/1875], d_loss: -0.3693, g_loss:0.5194
# Epoch [11/100], Step [200/1875], d_loss: -0.4596, g_loss:1.0015
# Epoch [11/100], Step [400/1875], d_loss: -0.3452, g_loss:0.3969
# Epoch [11/100], Step [600/1875], d_loss: -0.3327, g_loss:1.1776
# Epoch [11/100], Step [800/1875], d_loss: -0.6647, g_loss:1.4222
# Epoch [11/100], Step [1000/1875], d_loss: -0.4315, g_loss:0.2670
# Epoch [11/100], Step [1200/1875], d_loss: -0.5548, g_loss:1.4896
# Epoch [11/100], Step [1400/1875], d_loss: -0.6372, g_loss:-0.1362
# Epoch [11/100], Step [1600/1875], d_loss: -0.5028, g_loss:1.1463
# Epoch [11/100], Step [1800/1875], d_loss: -0.5751, g_loss:0.0781
# Epoch [12/100], Step [200/1875], d_loss: -0.4765, g_loss:-0.7843
# Epoch [12/100], Step [400/1875], d_loss: -0.3624, g_loss:0.5340
# Epoch [12/100], Step [600/1875], d_loss: -0.5854, g_loss:0.7884
# Epoch [12/100], Step [800/1875], d_loss: -0.3774, g_loss:-0.3404
# Epoch [12/100], Step [1000/1875], d_loss: -0.3784, g_loss:0.7330
# Epoch [12/100], Step [1200/1875], d_loss: -0.4992, g_loss:1.0763
# Epoch [12/100], Step [1400/1875], d_loss: -0.2557, g_loss:0.2550
# Epoch [12/100], Step [1600/1875], d_loss: -0.4581, g_loss:1.6123
# Epoch [12/100], Step [1800/1875], d_loss: -0.4962, g_loss:0.5575
# Epoch [13/100], Step [200/1875], d_loss: -0.3626, g_loss:0.8593
# Epoch [13/100], Step [400/1875], d_loss: -0.4472, g_loss:0.4426
# Epoch [13/100], Step [600/1875], d_loss: -0.2597, g_loss:0.1693
# Epoch [13/100], Step [800/1875], d_loss: -0.3984, g_loss:0.9093
# Epoch [13/100], Step [1000/1875], d_loss: -0.4175, g_loss:0.8994
# Epoch [13/100], Step [1200/1875], d_loss: -0.6350, g_loss:0.9266
# Epoch [13/100], Step [1400/1875], d_loss: -0.6130, g_loss:1.8035
# Epoch [13/100], Step [1600/1875], d_loss: -0.4071, g_loss:1.4315
# Epoch [13/100], Step [1800/1875], d_loss: -0.4065, g_loss:2.0781
# Epoch [14/100], Step [200/1875], d_loss: -0.3362, g_loss:1.1854
# Epoch [14/100], Step [400/1875], d_loss: -0.3173, g_loss:2.0951
# Epoch [14/100], Step [600/1875], d_loss: -0.5397, g_loss:1.1786
# Epoch [14/100], Step [800/1875], d_loss: -0.6440, g_loss:0.0453
# Epoch [14/100], Step [1000/1875], d_loss: -0.5242, g_loss:0.7345
# Epoch [14/100], Step [1200/1875], d_loss: -0.3310, g_loss:0.6666
# Epoch [14/100], Step [1400/1875], d_loss: -0.4594, g_loss:0.5604
# Epoch [14/100], Step [1600/1875], d_loss: -0.6975, g_loss:2.0534
# Epoch [14/100], Step [1800/1875], d_loss: -0.3855, g_loss:1.6762
# Epoch [15/100], Step [200/1875], d_loss: -0.3162, g_loss:1.5270
# Epoch [15/100], Step [400/1875], d_loss: -0.3435, g_loss:2.3800
# Epoch [15/100], Step [600/1875], d_loss: -0.4855, g_loss:-0.2801
# Epoch [15/100], Step [800/1875], d_loss: -0.3503, g_loss:0.9657
# Epoch [15/100], Step [1000/1875], d_loss: -0.4397, g_loss:0.4396
# Epoch [15/100], Step [1200/1875], d_loss: -0.3990, g_loss:2.7208
# Epoch [15/100], Step [1400/1875], d_loss: -0.3916, g_loss:2.4341
# Epoch [15/100], Step [1600/1875], d_loss: -0.2705, g_loss:-0.0204
# Epoch [15/100], Step [1800/1875], d_loss: -0.5667, g_loss:0.8463
# Epoch [16/100], Step [200/1875], d_loss: -0.4945, g_loss:0.4814
# Epoch [16/100], Step [400/1875], d_loss: -0.4499, g_loss:0.4996
# Epoch [16/100], Step [600/1875], d_loss: -0.4327, g_loss:2.4157
# Epoch [16/100], Step [800/1875], d_loss: -0.3810, g_loss:2.2313
# Epoch [16/100], Step [1000/1875], d_loss: -0.4348, g_loss:0.1910
# Epoch [16/100], Step [1200/1875], d_loss: -0.6115, g_loss:1.4585
# Epoch [16/100], Step [1400/1875], d_loss: -0.5218, g_loss:1.1076
# Epoch [16/100], Step [1600/1875], d_loss: -0.2913, g_loss:0.8190
# Epoch [16/100], Step [1800/1875], d_loss: -0.4388, g_loss:2.1242
# Epoch [17/100], Step [200/1875], d_loss: -0.2974, g_loss:1.2686
# Epoch [17/100], Step [400/1875], d_loss: -0.4220, g_loss:2.4696
# Epoch [17/100], Step [600/1875], d_loss: -0.5497, g_loss:2.1996
# Epoch [17/100], Step [800/1875], d_loss: -0.4181, g_loss:3.2034
# Epoch [17/100], Step [1000/1875], d_loss: -0.6047, g_loss:2.2911
# Epoch [17/100], Step [1200/1875], d_loss: -0.4028, g_loss:1.4750
# Epoch [17/100], Step [1400/1875], d_loss: -0.3335, g_loss:1.5147
# Epoch [17/100], Step [1600/1875], d_loss: -0.6143, g_loss:1.8231
# Epoch [17/100], Step [1800/1875], d_loss: -0.4664, g_loss:1.3345
# Epoch [18/100], Step [200/1875], d_loss: -0.6219, g_loss:1.1578
# Epoch [18/100], Step [400/1875], d_loss: -0.4492, g_loss:2.5537
# Epoch [18/100], Step [600/1875], d_loss: -0.2871, g_loss:3.3825
# Epoch [18/100], Step [800/1875], d_loss: -0.2889, g_loss:1.8969
# Epoch [18/100], Step [1000/1875], d_loss: -0.2777, g_loss:1.9454
# Epoch [18/100], Step [1200/1875], d_loss: -0.3478, g_loss:0.0197
# Epoch [18/100], Step [1400/1875], d_loss: -0.3225, g_loss:3.3092
# Epoch [18/100], Step [1600/1875], d_loss: -0.5101, g_loss:2.5310
# Epoch [18/100], Step [1800/1875], d_loss: -0.3868, g_loss:1.6289
# Epoch [19/100], Step [200/1875], d_loss: -0.3955, g_loss:1.9088
# Epoch [19/100], Step [400/1875], d_loss: -0.3181, g_loss:3.1034
# Epoch [19/100], Step [600/1875], d_loss: -0.1543, g_loss:1.5940
# Epoch [19/100], Step [800/1875], d_loss: -0.4020, g_loss:0.1531
# Epoch [19/100], Step [1000/1875], d_loss: -0.3736, g_loss:1.7298
# Epoch [19/100], Step [1200/1875], d_loss: -0.4172, g_loss:1.1275
# Epoch [19/100], Step [1400/1875], d_loss: -0.6383, g_loss:0.9730
# Epoch [19/100], Step [1600/1875], d_loss: -0.4699, g_loss:2.9510
# Epoch [19/100], Step [1800/1875], d_loss: -0.2108, g_loss:1.6916
# Epoch [20/100], Step [200/1875], d_loss: -0.5929, g_loss:0.4063
# Epoch [20/100], Step [400/1875], d_loss: -0.5527, g_loss:2.4693
# Epoch [20/100], Step [600/1875], d_loss: -0.4285, g_loss:1.0218
# Epoch [20/100], Step [800/1875], d_loss: -0.3497, g_loss:1.2741
# Epoch [20/100], Step [1000/1875], d_loss: -0.4216, g_loss:1.2976
# Epoch [20/100], Step [1200/1875], d_loss: -0.3026, g_loss:0.9845
# Epoch [20/100], Step [1400/1875], d_loss: -0.3977, g_loss:0.8219
# Epoch [20/100], Step [1600/1875], d_loss: -0.4125, g_loss:0.4138
# Epoch [20/100], Step [1800/1875], d_loss: -0.5101, g_loss:2.0630
# Epoch [21/100], Step [200/1875], d_loss: -0.2647, g_loss:0.6370
# Epoch [21/100], Step [400/1875], d_loss: -0.4054, g_loss:0.7572
# Epoch [21/100], Step [600/1875], d_loss: -0.2942, g_loss:1.4755
# Epoch [21/100], Step [800/1875], d_loss: -0.4091, g_loss:2.4464
# Epoch [21/100], Step [1000/1875], d_loss: -0.3344, g_loss:0.6148
# Epoch [21/100], Step [1200/1875], d_loss: -0.3690, g_loss:1.3120
# Epoch [21/100], Step [1400/1875], d_loss: -0.3853, g_loss:1.7385
# Epoch [21/100], Step [1600/1875], d_loss: -0.5230, g_loss:1.4659
# Epoch [21/100], Step [1800/1875], d_loss: -0.4789, g_loss:1.9801
# Epoch [22/100], Step [200/1875], d_loss: -0.3504, g_loss:2.0913
# Epoch [22/100], Step [400/1875], d_loss: -0.5376, g_loss:-0.4543
# Epoch [22/100], Step [600/1875], d_loss: -0.6666, g_loss:0.1616
# Epoch [22/100], Step [800/1875], d_loss: -0.2303, g_loss:1.7397
# Epoch [22/100], Step [1000/1875], d_loss: -0.3126, g_loss:0.4195
# Epoch [22/100], Step [1200/1875], d_loss: -0.3506, g_loss:1.4435
# Epoch [22/100], Step [1400/1875], d_loss: -0.3456, g_loss:1.8730
# Epoch [22/100], Step [1600/1875], d_loss: -0.4085, g_loss:1.9655
# Epoch [22/100], Step [1800/1875], d_loss: -0.4254, g_loss:0.8566
# Epoch [23/100], Step [200/1875], d_loss: -0.3875, g_loss:0.9598
# Epoch [23/100], Step [400/1875], d_loss: -0.4137, g_loss:1.3473
# Epoch [23/100], Step [600/1875], d_loss: -0.5287, g_loss:1.6035
# Epoch [23/100], Step [800/1875], d_loss: -0.5706, g_loss:0.4829
# Epoch [23/100], Step [1000/1875], d_loss: -0.3622, g_loss:1.2725
# Epoch [23/100], Step [1200/1875], d_loss: -0.3178, g_loss:1.1642
# Epoch [23/100], Step [1400/1875], d_loss: -0.4858, g_loss:1.7848
# Epoch [23/100], Step [1600/1875], d_loss: -0.4052, g_loss:0.8203
# Epoch [23/100], Step [1800/1875], d_loss: -0.5449, g_loss:3.5133
# Epoch [24/100], Step [200/1875], d_loss: -0.3281, g_loss:1.2315
# Epoch [24/100], Step [400/1875], d_loss: -0.5452, g_loss:-0.4192
# Epoch [24/100], Step [600/1875], d_loss: -0.2988, g_loss:0.1460
# Epoch [24/100], Step [800/1875], d_loss: -0.4653, g_loss:0.2269
# Epoch [24/100], Step [1000/1875], d_loss: -0.3233, g_loss:1.7539
# Epoch [24/100], Step [1200/1875], d_loss: -0.4663, g_loss:1.8523
# Epoch [24/100], Step [1400/1875], d_loss: -0.4602, g_loss:1.9260
# Epoch [24/100], Step [1600/1875], d_loss: -0.3738, g_loss:0.0741
# Epoch [24/100], Step [1800/1875], d_loss: -0.3495, g_loss:0.8470
# Epoch [25/100], Step [200/1875], d_loss: -0.4616, g_loss:1.0856
# Epoch [25/100], Step [400/1875], d_loss: -0.5902, g_loss:2.4192
# Epoch [25/100], Step [600/1875], d_loss: -0.3965, g_loss:1.8853
# Epoch [25/100], Step [800/1875], d_loss: -0.3723, g_loss:0.3775
# Epoch [25/100], Step [1000/1875], d_loss: -0.4092, g_loss:1.1941
# Epoch [25/100], Step [1200/1875], d_loss: -0.5502, g_loss:0.6330
# Epoch [25/100], Step [1400/1875], d_loss: -0.2356, g_loss:3.8257
# Epoch [25/100], Step [1600/1875], d_loss: -0.3719, g_loss:1.4798
# Epoch [25/100], Step [1800/1875], d_loss: -0.3984, g_loss:0.9361
# Epoch [26/100], Step [200/1875], d_loss: -0.1867, g_loss:1.6716
# Epoch [26/100], Step [400/1875], d_loss: -0.5238, g_loss:1.9460
# Epoch [26/100], Step [600/1875], d_loss: -0.4591, g_loss:0.4861
# Epoch [26/100], Step [800/1875], d_loss: -0.4694, g_loss:0.8247
# Epoch [26/100], Step [1000/1875], d_loss: -0.3733, g_loss:1.1272
# Epoch [26/100], Step [1200/1875], d_loss: -0.4267, g_loss:-0.0233
# Epoch [26/100], Step [1400/1875], d_loss: -0.4623, g_loss:0.6927
# Epoch [26/100], Step [1600/1875], d_loss: -0.3363, g_loss:1.4006
# Epoch [26/100], Step [1800/1875], d_loss: -0.3531, g_loss:1.6177
# Epoch [27/100], Step [200/1875], d_loss: -0.3383, g_loss:0.4459
# Epoch [27/100], Step [400/1875], d_loss: -0.2790, g_loss:1.7154
# Epoch [27/100], Step [600/1875], d_loss: -0.4663, g_loss:1.4076
# Epoch [27/100], Step [800/1875], d_loss: -0.3504, g_loss:3.3461
# Epoch [27/100], Step [1000/1875], d_loss: -0.3232, g_loss:2.1790
# Epoch [27/100], Step [1200/1875], d_loss: -0.3917, g_loss:0.5586
# Epoch [27/100], Step [1400/1875], d_loss: -0.4365, g_loss:1.6792
# Epoch [27/100], Step [1600/1875], d_loss: -0.5379, g_loss:1.1065
# Epoch [27/100], Step [1800/1875], d_loss: -0.3361, g_loss:0.9137
# Epoch [28/100], Step [200/1875], d_loss: -0.1873, g_loss:0.9309
# Epoch [28/100], Step [400/1875], d_loss: -0.2522, g_loss:1.5141
# Epoch [28/100], Step [600/1875], d_loss: -0.4006, g_loss:2.1263
# Epoch [28/100], Step [800/1875], d_loss: -0.5042, g_loss:0.5116
# Epoch [28/100], Step [1000/1875], d_loss: -0.3859, g_loss:0.3020
# Epoch [28/100], Step [1200/1875], d_loss: -0.3793, g_loss:1.3130
# Epoch [28/100], Step [1400/1875], d_loss: -0.1993, g_loss:1.0013
# Epoch [28/100], Step [1600/1875], d_loss: -0.5673, g_loss:1.9982
# Epoch [28/100], Step [1800/1875], d_loss: -0.3675, g_loss:1.4844
# Epoch [29/100], Step [200/1875], d_loss: -0.3291, g_loss:0.8627
# Epoch [29/100], Step [400/1875], d_loss: -0.2647, g_loss:0.8310
# Epoch [29/100], Step [600/1875], d_loss: -0.3701, g_loss:1.0002
# Epoch [29/100], Step [800/1875], d_loss: -0.4383, g_loss:1.0060
# Epoch [29/100], Step [1000/1875], d_loss: -0.3696, g_loss:1.7464
# Epoch [29/100], Step [1200/1875], d_loss: -0.3553, g_loss:1.6186
# Epoch [29/100], Step [1400/1875], d_loss: -0.3078, g_loss:0.6172
# Epoch [29/100], Step [1600/1875], d_loss: -0.4834, g_loss:2.1523
# Epoch [29/100], Step [1800/1875], d_loss: -0.4831, g_loss:1.0319
# Epoch [30/100], Step [200/1875], d_loss: -0.4897, g_loss:1.0140
# Epoch [30/100], Step [400/1875], d_loss: -0.4301, g_loss:2.2133
# Epoch [30/100], Step [600/1875], d_loss: -0.3138, g_loss:0.9161
# Epoch [30/100], Step [800/1875], d_loss: -0.4443, g_loss:2.4003
# Epoch [30/100], Step [1000/1875], d_loss: -0.5165, g_loss:0.6952
# Epoch [30/100], Step [1200/1875], d_loss: -0.3015, g_loss:1.5818
# Epoch [30/100], Step [1400/1875], d_loss: -0.1846, g_loss:0.4582
# Epoch [30/100], Step [1600/1875], d_loss: -0.4723, g_loss:2.1906
# Epoch [30/100], Step [1800/1875], d_loss: -0.5270, g_loss:1.6026
# Epoch [31/100], Step [200/1875], d_loss: -0.1687, g_loss:0.6144
# Epoch [31/100], Step [400/1875], d_loss: -0.4624, g_loss:0.9396
# Epoch [31/100], Step [600/1875], d_loss: -0.2832, g_loss:2.5658
# Epoch [31/100], Step [800/1875], d_loss: -0.5365, g_loss:1.4901
# Epoch [31/100], Step [1000/1875], d_loss: -0.3366, g_loss:1.8153
# Epoch [31/100], Step [1200/1875], d_loss: -0.3014, g_loss:1.6957
# Epoch [31/100], Step [1400/1875], d_loss: -0.3371, g_loss:0.9166
# Epoch [31/100], Step [1600/1875], d_loss: -0.1406, g_loss:2.4959
# Epoch [31/100], Step [1800/1875], d_loss: 0.2539, g_loss:3.2316
# Epoch [32/100], Step [200/1875], d_loss: -0.3419, g_loss:2.3270
# Epoch [32/100], Step [400/1875], d_loss: -0.4197, g_loss:2.2357
# Epoch [32/100], Step [600/1875], d_loss: -0.4561, g_loss:2.1109
# Epoch [32/100], Step [800/1875], d_loss: -0.3980, g_loss:1.6869
# Epoch [32/100], Step [1000/1875], d_loss: -0.3703, g_loss:0.3919
# Epoch [32/100], Step [1200/1875], d_loss: -0.4067, g_loss:1.3813
# Epoch [32/100], Step [1400/1875], d_loss: -0.1007, g_loss:2.7065
# Epoch [32/100], Step [1600/1875], d_loss: -0.4872, g_loss:0.5805
# Epoch [32/100], Step [1800/1875], d_loss: -0.4994, g_loss:3.2179
# Epoch [33/100], Step [200/1875], d_loss: -0.4115, g_loss:1.8637
# Epoch [33/100], Step [400/1875], d_loss: -0.6465, g_loss:0.1659
# Epoch [33/100], Step [600/1875], d_loss: -0.6225, g_loss:2.2797
# Epoch [33/100], Step [800/1875], d_loss: -0.5037, g_loss:2.4766
# Epoch [33/100], Step [1000/1875], d_loss: -0.2861, g_loss:2.7762
# Epoch [33/100], Step [1200/1875], d_loss: -0.4725, g_loss:2.3475
# Epoch [33/100], Step [1400/1875], d_loss: -0.4027, g_loss:0.9518
# Epoch [33/100], Step [1600/1875], d_loss: -0.5236, g_loss:0.3434
# Epoch [33/100], Step [1800/1875], d_loss: -0.5794, g_loss:0.5048
# Epoch [34/100], Step [200/1875], d_loss: -0.4358, g_loss:2.6303
# Epoch [34/100], Step [400/1875], d_loss: -0.3231, g_loss:2.4779
# Epoch [34/100], Step [600/1875], d_loss: -0.3197, g_loss:1.9469
# Epoch [34/100], Step [800/1875], d_loss: -0.2832, g_loss:2.0972
# Epoch [34/100], Step [1000/1875], d_loss: -0.1457, g_loss:1.3068
# Epoch [34/100], Step [1200/1875], d_loss: -0.5495, g_loss:2.1033
# Epoch [34/100], Step [1400/1875], d_loss: -0.3063, g_loss:2.0300
# Epoch [34/100], Step [1600/1875], d_loss: -0.3340, g_loss:1.4749
# Epoch [34/100], Step [1800/1875], d_loss: -0.1993, g_loss:2.2778
# Epoch [35/100], Step [200/1875], d_loss: -0.7147, g_loss:3.4000
# Epoch [35/100], Step [400/1875], d_loss: -0.4652, g_loss:0.8865
# Epoch [35/100], Step [600/1875], d_loss: -0.3537, g_loss:2.3155
# Epoch [35/100], Step [800/1875], d_loss: -0.1327, g_loss:0.8146
# Epoch [35/100], Step [1000/1875], d_loss: -0.4615, g_loss:2.0725
# Epoch [35/100], Step [1200/1875], d_loss: -0.2919, g_loss:2.9349
# Epoch [35/100], Step [1400/1875], d_loss: -0.3435, g_loss:2.3220
# Epoch [35/100], Step [1600/1875], d_loss: -0.4118, g_loss:2.2675
# Epoch [35/100], Step [1800/1875], d_loss: -0.2388, g_loss:0.8344
# Epoch [36/100], Step [200/1875], d_loss: -0.0982, g_loss:1.5569
# Epoch [36/100], Step [400/1875], d_loss: -0.3109, g_loss:2.5575
# Epoch [36/100], Step [600/1875], d_loss: -0.4153, g_loss:3.2087
# Epoch [36/100], Step [800/1875], d_loss: -0.2201, g_loss:2.0045
# Epoch [36/100], Step [1000/1875], d_loss: -0.4200, g_loss:3.6094
# Epoch [36/100], Step [1200/1875], d_loss: -0.4824, g_loss:1.2131
# Epoch [36/100], Step [1400/1875], d_loss: -0.3404, g_loss:2.7907
# Epoch [36/100], Step [1600/1875], d_loss: -0.2294, g_loss:2.0326
# Epoch [36/100], Step [1800/1875], d_loss: -0.3820, g_loss:1.0682
# Epoch [37/100], Step [200/1875], d_loss: -0.4995, g_loss:1.3081
# Epoch [37/100], Step [400/1875], d_loss: -0.1979, g_loss:3.2133
# Epoch [37/100], Step [600/1875], d_loss: -0.4826, g_loss:2.9704
# Epoch [37/100], Step [800/1875], d_loss: -0.4356, g_loss:1.6058
# Epoch [37/100], Step [1000/1875], d_loss: -0.2754, g_loss:2.6096
# Epoch [37/100], Step [1200/1875], d_loss: -0.3774, g_loss:2.1035
# Epoch [37/100], Step [1400/1875], d_loss: -0.3850, g_loss:2.7943
# Epoch [37/100], Step [1600/1875], d_loss: -0.3538, g_loss:0.9922
# Epoch [37/100], Step [1800/1875], d_loss: -0.6114, g_loss:2.9010
# Epoch [38/100], Step [200/1875], d_loss: -0.3676, g_loss:1.6365
# Epoch [38/100], Step [400/1875], d_loss: -0.4402, g_loss:2.6009
# Epoch [38/100], Step [600/1875], d_loss: -0.4621, g_loss:3.8669
# Epoch [38/100], Step [800/1875], d_loss: -0.2960, g_loss:0.7899
# Epoch [38/100], Step [1000/1875], d_loss: -0.1977, g_loss:1.7329
# Epoch [38/100], Step [1200/1875], d_loss: -0.4876, g_loss:0.4198
# Epoch [38/100], Step [1400/1875], d_loss: -0.3335, g_loss:2.1757
# Epoch [38/100], Step [1600/1875], d_loss: -0.4615, g_loss:2.7789
# Epoch [38/100], Step [1800/1875], d_loss: 0.0576, g_loss:1.6431
# Epoch [39/100], Step [200/1875], d_loss: -0.2970, g_loss:3.0650
# Epoch [39/100], Step [400/1875], d_loss: -0.3833, g_loss:0.6706
# Epoch [39/100], Step [600/1875], d_loss: -0.0883, g_loss:2.9327
# Epoch [39/100], Step [800/1875], d_loss: -0.3780, g_loss:1.7331
# Epoch [39/100], Step [1000/1875], d_loss: -0.2734, g_loss:1.6747
# Epoch [39/100], Step [1200/1875], d_loss: -0.6402, g_loss:1.5803
# Epoch [39/100], Step [1400/1875], d_loss: -0.4127, g_loss:2.5659
# Epoch [39/100], Step [1600/1875], d_loss: -0.1192, g_loss:1.2521
# Epoch [39/100], Step [1800/1875], d_loss: -0.4296, g_loss:2.4326
# Epoch [40/100], Step [200/1875], d_loss: -0.4600, g_loss:2.0900
# Epoch [40/100], Step [400/1875], d_loss: -0.2930, g_loss:2.0342
# Epoch [40/100], Step [600/1875], d_loss: -0.3355, g_loss:2.8946
# Epoch [40/100], Step [800/1875], d_loss: -0.5240, g_loss:1.3518
# Epoch [40/100], Step [1000/1875], d_loss: -0.3104, g_loss:2.2060
# Epoch [40/100], Step [1200/1875], d_loss: -0.1634, g_loss:1.4288
# Epoch [40/100], Step [1400/1875], d_loss: -0.3603, g_loss:1.8746
# Epoch [40/100], Step [1600/1875], d_loss: -0.4152, g_loss:1.8478
# Epoch [40/100], Step [1800/1875], d_loss: -0.3202, g_loss:3.1512
# Epoch [41/100], Step [200/1875], d_loss: -0.4171, g_loss:3.0784
# Epoch [41/100], Step [400/1875], d_loss: -0.1763, g_loss:1.2890
# Epoch [41/100], Step [600/1875], d_loss: -0.5051, g_loss:1.8548
# Epoch [41/100], Step [800/1875], d_loss: -0.3682, g_loss:3.7261
# Epoch [41/100], Step [1000/1875], d_loss: -0.4324, g_loss:2.5605
# Epoch [41/100], Step [1200/1875], d_loss: -0.5100, g_loss:3.4744
# Epoch [41/100], Step [1400/1875], d_loss: -0.3990, g_loss:1.5679
# Epoch [41/100], Step [1600/1875], d_loss: -0.3269, g_loss:3.0625
# Epoch [41/100], Step [1800/1875], d_loss: -0.3156, g_loss:2.4539
# Epoch [42/100], Step [200/1875], d_loss: -0.3042, g_loss:2.8680
# Epoch [42/100], Step [400/1875], d_loss: -0.2898, g_loss:2.2967
# Epoch [42/100], Step [600/1875], d_loss: -0.4271, g_loss:2.4449
# Epoch [42/100], Step [800/1875], d_loss: -0.3221, g_loss:1.8517
# Epoch [42/100], Step [1000/1875], d_loss: -0.3249, g_loss:4.1935
# Epoch [42/100], Step [1200/1875], d_loss: -0.3366, g_loss:3.9284
# Epoch [42/100], Step [1400/1875], d_loss: -0.4121, g_loss:3.9794
# Epoch [42/100], Step [1600/1875], d_loss: -0.2888, g_loss:2.7280
# Epoch [42/100], Step [1800/1875], d_loss: -0.4711, g_loss:2.2378
# Epoch [43/100], Step [200/1875], d_loss: -0.2805, g_loss:2.8423
# Epoch [43/100], Step [400/1875], d_loss: -0.2885, g_loss:3.4437
# Epoch [43/100], Step [600/1875], d_loss: -0.3693, g_loss:3.1926
# Epoch [43/100], Step [800/1875], d_loss: 0.0389, g_loss:3.5364
# Epoch [43/100], Step [1000/1875], d_loss: -0.2819, g_loss:2.9845
# Epoch [43/100], Step [1200/1875], d_loss: -0.2935, g_loss:3.2080
# Epoch [43/100], Step [1400/1875], d_loss: -0.2237, g_loss:2.8002
# Epoch [43/100], Step [1600/1875], d_loss: -0.4440, g_loss:2.8495
# Epoch [43/100], Step [1800/1875], d_loss: -0.2544, g_loss:2.7245
# Epoch [44/100], Step [200/1875], d_loss: -0.3812, g_loss:3.4411
# Epoch [44/100], Step [400/1875], d_loss: -0.2842, g_loss:2.9367
# Epoch [44/100], Step [600/1875], d_loss: -0.2608, g_loss:4.2933
# Epoch [44/100], Step [800/1875], d_loss: -0.3545, g_loss:1.8718
# Epoch [44/100], Step [1000/1875], d_loss: -0.1192, g_loss:1.7508
# Epoch [44/100], Step [1200/1875], d_loss: -0.5113, g_loss:1.6655
# Epoch [44/100], Step [1400/1875], d_loss: -0.2107, g_loss:3.1653
# Epoch [44/100], Step [1600/1875], d_loss: -0.2764, g_loss:2.7816
# Epoch [44/100], Step [1800/1875], d_loss: -0.4728, g_loss:2.5586
# Epoch [45/100], Step [200/1875], d_loss: -0.4402, g_loss:3.1915
# Epoch [45/100], Step [400/1875], d_loss: -0.4116, g_loss:2.6952
# Epoch [45/100], Step [600/1875], d_loss: -0.2950, g_loss:2.1138
# Epoch [45/100], Step [800/1875], d_loss: -0.4546, g_loss:2.3748
# Epoch [45/100], Step [1000/1875], d_loss: -0.4254, g_loss:3.0724
# Epoch [45/100], Step [1200/1875], d_loss: -0.1157, g_loss:2.5054
# Epoch [45/100], Step [1400/1875], d_loss: -0.3593, g_loss:2.4452
# Epoch [45/100], Step [1600/1875], d_loss: -0.2381, g_loss:3.1097
# Epoch [45/100], Step [1800/1875], d_loss: -0.4901, g_loss:3.3370
# Epoch [46/100], Step [200/1875], d_loss: -0.3985, g_loss:2.6925
# Epoch [46/100], Step [400/1875], d_loss: -0.3294, g_loss:2.7608
# Epoch [46/100], Step [600/1875], d_loss: -0.5500, g_loss:2.2356
# Epoch [46/100], Step [800/1875], d_loss: -0.5726, g_loss:2.1696
# Epoch [46/100], Step [1000/1875], d_loss: -0.4536, g_loss:3.3229
# Epoch [46/100], Step [1200/1875], d_loss: -0.4887, g_loss:2.6437
# Epoch [46/100], Step [1400/1875], d_loss: -0.4630, g_loss:2.1910
# Epoch [46/100], Step [1600/1875], d_loss: -0.3158, g_loss:1.5267
# Epoch [46/100], Step [1800/1875], d_loss: -0.4158, g_loss:2.6439
# Epoch [47/100], Step [200/1875], d_loss: -0.2111, g_loss:2.0117
# Epoch [47/100], Step [400/1875], d_loss: -0.2052, g_loss:2.1862
# Epoch [47/100], Step [600/1875], d_loss: -0.1777, g_loss:2.6261
# Epoch [47/100], Step [800/1875], d_loss: -0.2789, g_loss:2.7884
# Epoch [47/100], Step [1000/1875], d_loss: -0.1882, g_loss:3.3192
# Epoch [47/100], Step [1200/1875], d_loss: -0.3518, g_loss:2.0243
# Epoch [47/100], Step [1400/1875], d_loss: -0.4312, g_loss:2.4570
# Epoch [47/100], Step [1600/1875], d_loss: -0.1764, g_loss:3.3967
# Epoch [47/100], Step [1800/1875], d_loss: -0.1684, g_loss:2.4535
# Epoch [48/100], Step [200/1875], d_loss: -0.3530, g_loss:2.3640
# Epoch [48/100], Step [400/1875], d_loss: -0.1724, g_loss:2.7375
# Epoch [48/100], Step [600/1875], d_loss: -0.5931, g_loss:2.8901
# Epoch [48/100], Step [800/1875], d_loss: -0.2532, g_loss:2.1949
# Epoch [48/100], Step [1000/1875], d_loss: -0.4273, g_loss:3.2658
# Epoch [48/100], Step [1200/1875], d_loss: -0.3256, g_loss:2.3886
# Epoch [48/100], Step [1400/1875], d_loss: -0.2989, g_loss:2.8700
# Epoch [48/100], Step [1600/1875], d_loss: -0.3261, g_loss:2.6738
# Epoch [48/100], Step [1800/1875], d_loss: -0.4533, g_loss:2.9855
# Epoch [49/100], Step [200/1875], d_loss: -0.2154, g_loss:2.9058
# Epoch [49/100], Step [400/1875], d_loss: -0.3653, g_loss:3.0566
# Epoch [49/100], Step [600/1875], d_loss: -0.2571, g_loss:3.0124
# Epoch [49/100], Step [800/1875], d_loss: -0.3596, g_loss:1.6606
# Epoch [49/100], Step [1000/1875], d_loss: -0.2734, g_loss:2.3641
# Epoch [49/100], Step [1200/1875], d_loss: -0.4562, g_loss:4.2175
# Epoch [49/100], Step [1400/1875], d_loss: -0.3648, g_loss:2.8799
# Epoch [49/100], Step [1600/1875], d_loss: -0.1765, g_loss:2.7564
# Epoch [49/100], Step [1800/1875], d_loss: -0.4247, g_loss:3.1271
# Epoch [50/100], Step [200/1875], d_loss: -0.2686, g_loss:2.5983
# Epoch [50/100], Step [400/1875], d_loss: -0.4248, g_loss:1.9939
# Epoch [50/100], Step [600/1875], d_loss: -0.2480, g_loss:3.5397
# Epoch [50/100], Step [800/1875], d_loss: -0.1380, g_loss:2.4558
# Epoch [50/100], Step [1000/1875], d_loss: -0.1738, g_loss:1.9455
# Epoch [50/100], Step [1200/1875], d_loss: -0.5595, g_loss:2.7368
# Epoch [50/100], Step [1400/1875], d_loss: -0.4925, g_loss:2.2965
# Epoch [50/100], Step [1600/1875], d_loss: -0.2718, g_loss:2.8896
# Epoch [50/100], Step [1800/1875], d_loss: -0.3314, g_loss:2.4538
# Epoch [51/100], Step [200/1875], d_loss: -0.3728, g_loss:1.9761
# Epoch [51/100], Step [400/1875], d_loss: -0.2516, g_loss:3.4008
# Epoch [51/100], Step [600/1875], d_loss: -0.2945, g_loss:2.7912
# Epoch [51/100], Step [800/1875], d_loss: -0.1484, g_loss:2.2509
# Epoch [51/100], Step [1000/1875], d_loss: -0.3154, g_loss:1.9123
# Epoch [51/100], Step [1200/1875], d_loss: -0.3230, g_loss:2.0891
# Epoch [51/100], Step [1400/1875], d_loss: -0.4053, g_loss:1.7632
# Epoch [51/100], Step [1600/1875], d_loss: -0.7556, g_loss:2.8998
# Epoch [51/100], Step [1800/1875], d_loss: -0.5106, g_loss:1.8934
# Epoch [52/100], Step [200/1875], d_loss: -0.4493, g_loss:1.7740
# Epoch [52/100], Step [400/1875], d_loss: -0.2637, g_loss:1.9151
# Epoch [52/100], Step [600/1875], d_loss: -0.3082, g_loss:2.2484
# Epoch [52/100], Step [800/1875], d_loss: -0.4838, g_loss:1.5559
# Epoch [52/100], Step [1000/1875], d_loss: -0.2182, g_loss:3.6918
# Epoch [52/100], Step [1200/1875], d_loss: -0.2170, g_loss:2.8657
# Epoch [52/100], Step [1400/1875], d_loss: -0.1445, g_loss:2.0978
# Epoch [52/100], Step [1600/1875], d_loss: -0.5249, g_loss:1.9553
# Epoch [52/100], Step [1800/1875], d_loss: -0.3045, g_loss:2.1027
# Epoch [53/100], Step [200/1875], d_loss: -0.3685, g_loss:1.5737
# Epoch [53/100], Step [400/1875], d_loss: -0.3591, g_loss:1.5935
# Epoch [53/100], Step [600/1875], d_loss: -0.3783, g_loss:1.8539
# Epoch [53/100], Step [800/1875], d_loss: -0.4060, g_loss:1.7016
# Epoch [53/100], Step [1000/1875], d_loss: -0.5137, g_loss:1.7235
# Epoch [53/100], Step [1200/1875], d_loss: -0.5945, g_loss:1.9815
# Epoch [53/100], Step [1400/1875], d_loss: -0.2647, g_loss:2.2836
# Epoch [53/100], Step [1600/1875], d_loss: -0.3501, g_loss:2.1727
# Epoch [53/100], Step [1800/1875], d_loss: -0.3171, g_loss:2.0990
# Epoch [54/100], Step [200/1875], d_loss: -0.3197, g_loss:0.9078
# Epoch [54/100], Step [400/1875], d_loss: -0.5777, g_loss:1.3853
# Epoch [54/100], Step [600/1875], d_loss: -0.2155, g_loss:2.2696
# Epoch [54/100], Step [800/1875], d_loss: -0.3335, g_loss:2.0498
# Epoch [54/100], Step [1000/1875], d_loss: -0.0764, g_loss:1.4107
# Epoch [54/100], Step [1200/1875], d_loss: -0.1837, g_loss:2.3712
# Epoch [54/100], Step [1400/1875], d_loss: -0.3894, g_loss:2.0795
# Epoch [54/100], Step [1600/1875], d_loss: -0.2617, g_loss:2.2554
# Epoch [54/100], Step [1800/1875], d_loss: -0.5033, g_loss:0.3827
# Epoch [55/100], Step [200/1875], d_loss: -0.2139, g_loss:1.8784
# Epoch [55/100], Step [400/1875], d_loss: -0.4744, g_loss:2.3084
# Epoch [55/100], Step [600/1875], d_loss: -0.3354, g_loss:1.0001
# Epoch [55/100], Step [800/1875], d_loss: -0.3254, g_loss:0.8357
# Epoch [55/100], Step [1000/1875], d_loss: -0.3415, g_loss:1.0857
# Epoch [55/100], Step [1200/1875], d_loss: -0.0541, g_loss:0.9448
# Epoch [55/100], Step [1400/1875], d_loss: -0.2339, g_loss:1.5395
# Epoch [55/100], Step [1600/1875], d_loss: -0.4201, g_loss:1.7424
# Epoch [55/100], Step [1800/1875], d_loss: -0.4676, g_loss:1.9512
# Epoch [56/100], Step [200/1875], d_loss: -0.4507, g_loss:0.9125
# Epoch [56/100], Step [400/1875], d_loss: -0.3331, g_loss:1.1826
# Epoch [56/100], Step [600/1875], d_loss: -0.3559, g_loss:1.7171
# Epoch [56/100], Step [800/1875], d_loss: -0.3235, g_loss:2.0526
# Epoch [56/100], Step [1000/1875], d_loss: -0.2336, g_loss:1.1083
# Epoch [56/100], Step [1200/1875], d_loss: -0.3173, g_loss:2.3380
# Epoch [56/100], Step [1400/1875], d_loss: -0.2500, g_loss:1.4766
# Epoch [56/100], Step [1600/1875], d_loss: -0.2792, g_loss:1.4716
# Epoch [56/100], Step [1800/1875], d_loss: -0.2136, g_loss:2.2342
# Epoch [57/100], Step [200/1875], d_loss: -0.3673, g_loss:1.6867
# Epoch [57/100], Step [400/1875], d_loss: -0.1898, g_loss:1.7808
# Epoch [57/100], Step [600/1875], d_loss: -0.3263, g_loss:1.6571
# Epoch [57/100], Step [800/1875], d_loss: -0.4510, g_loss:1.5855
# Epoch [57/100], Step [1000/1875], d_loss: -0.3356, g_loss:1.6975
# Epoch [57/100], Step [1200/1875], d_loss: -0.2365, g_loss:0.3738
# Epoch [57/100], Step [1400/1875], d_loss: -0.3331, g_loss:2.1538
# Epoch [57/100], Step [1600/1875], d_loss: -0.2495, g_loss:0.7076
# Epoch [57/100], Step [1800/1875], d_loss: -0.3738, g_loss:1.1004
# Epoch [58/100], Step [200/1875], d_loss: -0.8611, g_loss:0.5277
# Epoch [58/100], Step [400/1875], d_loss: -0.2806, g_loss:0.4263
# Epoch [58/100], Step [600/1875], d_loss: -0.2489, g_loss:2.4853
# Epoch [58/100], Step [800/1875], d_loss: -0.1988, g_loss:0.7839
# Epoch [58/100], Step [1000/1875], d_loss: -0.4234, g_loss:0.7480
# Epoch [58/100], Step [1200/1875], d_loss: -0.1882, g_loss:1.3955
# Epoch [58/100], Step [1400/1875], d_loss: -0.1770, g_loss:1.3010
# Epoch [58/100], Step [1600/1875], d_loss: -0.3992, g_loss:0.6582
# Epoch [58/100], Step [1800/1875], d_loss: -0.3918, g_loss:1.1038
# Epoch [59/100], Step [200/1875], d_loss: -0.4828, g_loss:1.1907
# Epoch [59/100], Step [400/1875], d_loss: -0.3619, g_loss:1.3548
# Epoch [59/100], Step [600/1875], d_loss: -0.4218, g_loss:1.3916
# Epoch [59/100], Step [800/1875], d_loss: -0.2299, g_loss:0.6812
# Epoch [59/100], Step [1000/1875], d_loss: -0.4322, g_loss:1.0596
# Epoch [59/100], Step [1200/1875], d_loss: -0.1548, g_loss:0.4291
# Epoch [59/100], Step [1400/1875], d_loss: -0.3496, g_loss:0.0841
# Epoch [59/100], Step [1600/1875], d_loss: -0.3519, g_loss:1.1788
# Epoch [59/100], Step [1800/1875], d_loss: -0.2440, g_loss:0.9221
# Epoch [60/100], Step [200/1875], d_loss: -0.1987, g_loss:0.6989
# Epoch [60/100], Step [400/1875], d_loss: -0.2547, g_loss:1.3696
# Epoch [60/100], Step [600/1875], d_loss: -0.0235, g_loss:0.6005
# Epoch [60/100], Step [800/1875], d_loss: -0.4948, g_loss:0.8335
# Epoch [60/100], Step [1000/1875], d_loss: -0.3065, g_loss:0.1941
# Epoch [60/100], Step [1200/1875], d_loss: -0.2431, g_loss:1.1500
# Epoch [60/100], Step [1400/1875], d_loss: -0.2468, g_loss:1.1309
# Epoch [60/100], Step [1600/1875], d_loss: -0.2577, g_loss:0.5222
# Epoch [60/100], Step [1800/1875], d_loss: -0.3321, g_loss:0.9508
# Epoch [61/100], Step [200/1875], d_loss: -0.2618, g_loss:-0.5105
# Epoch [61/100], Step [400/1875], d_loss: -0.2246, g_loss:0.9182
# Epoch [61/100], Step [600/1875], d_loss: -0.0125, g_loss:1.2049
# Epoch [61/100], Step [800/1875], d_loss: -0.3288, g_loss:1.6885
# Epoch [61/100], Step [1000/1875], d_loss: -0.2066, g_loss:0.0608
# Epoch [61/100], Step [1200/1875], d_loss: -0.2911, g_loss:0.9169
# Epoch [61/100], Step [1400/1875], d_loss: -0.3017, g_loss:0.8826
# Epoch [61/100], Step [1600/1875], d_loss: -0.5020, g_loss:1.8728
# Epoch [61/100], Step [1800/1875], d_loss: -0.4133, g_loss:1.0401
# Epoch [62/100], Step [200/1875], d_loss: -0.3236, g_loss:1.4817
# Epoch [62/100], Step [400/1875], d_loss: -0.2166, g_loss:0.6435
# Epoch [62/100], Step [600/1875], d_loss: -0.1408, g_loss:0.9944
# Epoch [62/100], Step [800/1875], d_loss: -0.4198, g_loss:0.2636
# Epoch [62/100], Step [1000/1875], d_loss: -0.2410, g_loss:0.8464
# Epoch [62/100], Step [1200/1875], d_loss: -0.2318, g_loss:0.8932
# Epoch [62/100], Step [1400/1875], d_loss: -0.6232, g_loss:1.6537
# Epoch [62/100], Step [1600/1875], d_loss: -0.2038, g_loss:0.5321
# Epoch [62/100], Step [1800/1875], d_loss: -0.1439, g_loss:0.1989
# Epoch [63/100], Step [200/1875], d_loss: -0.1841, g_loss:0.7754
# Epoch [63/100], Step [400/1875], d_loss: -0.3447, g_loss:1.4004
# Epoch [63/100], Step [600/1875], d_loss: -0.4415, g_loss:1.2121
# Epoch [63/100], Step [800/1875], d_loss: -0.2969, g_loss:1.0581
# Epoch [63/100], Step [1000/1875], d_loss: -0.2692, g_loss:1.6296
# Epoch [63/100], Step [1200/1875], d_loss: -0.2153, g_loss:0.5265
# Epoch [63/100], Step [1400/1875], d_loss: -0.0960, g_loss:1.1954
# Epoch [63/100], Step [1600/1875], d_loss: -0.2729, g_loss:1.4691
# Epoch [63/100], Step [1800/1875], d_loss: -0.3985, g_loss:-0.2096
# Epoch [64/100], Step [200/1875], d_loss: -0.2743, g_loss:-0.2089
# Epoch [64/100], Step [400/1875], d_loss: -0.1942, g_loss:-0.1214
# Epoch [64/100], Step [600/1875], d_loss: -0.2584, g_loss:1.0787
# Epoch [64/100], Step [800/1875], d_loss: -0.3090, g_loss:0.4325
# Epoch [64/100], Step [1000/1875], d_loss: -0.3002, g_loss:0.1942
# Epoch [64/100], Step [1200/1875], d_loss: -0.3042, g_loss:0.4075
# Epoch [64/100], Step [1400/1875], d_loss: -0.3542, g_loss:0.8565
# Epoch [64/100], Step [1600/1875], d_loss: -0.5246, g_loss:1.0004
# Epoch [64/100], Step [1800/1875], d_loss: -0.4144, g_loss:-0.3972
# Epoch [65/100], Step [200/1875], d_loss: -0.2373, g_loss:0.3898
# Epoch [65/100], Step [400/1875], d_loss: -0.4780, g_loss:0.0638
# Epoch [65/100], Step [600/1875], d_loss: -0.3322, g_loss:1.2347
# Epoch [65/100], Step [800/1875], d_loss: -0.2809, g_loss:1.1035
# Epoch [65/100], Step [1000/1875], d_loss: -0.4573, g_loss:1.6601
# Epoch [65/100], Step [1200/1875], d_loss: -0.3426, g_loss:-0.0019
# Epoch [65/100], Step [1400/1875], d_loss: -0.5176, g_loss:0.7825
# Epoch [65/100], Step [1600/1875], d_loss: -0.1565, g_loss:1.1876
# Epoch [65/100], Step [1800/1875], d_loss: -0.1613, g_loss:0.7409
# Epoch [66/100], Step [200/1875], d_loss: -0.3506, g_loss:1.1306
# Epoch [66/100], Step [400/1875], d_loss: -0.3640, g_loss:1.5143
# Epoch [66/100], Step [600/1875], d_loss: -0.3649, g_loss:0.5308
# Epoch [66/100], Step [800/1875], d_loss: -0.3956, g_loss:-0.0279
# Epoch [66/100], Step [1000/1875], d_loss: -0.0624, g_loss:0.5637
# Epoch [66/100], Step [1200/1875], d_loss: -0.2427, g_loss:1.2761
# Epoch [66/100], Step [1400/1875], d_loss: -0.2533, g_loss:0.9512
# Epoch [66/100], Step [1600/1875], d_loss: -0.3997, g_loss:1.8656
# Epoch [66/100], Step [1800/1875], d_loss: -0.5272, g_loss:0.7644
# Epoch [67/100], Step [200/1875], d_loss: -0.3983, g_loss:0.9664
# Epoch [67/100], Step [400/1875], d_loss: -0.3006, g_loss:0.1057
# Epoch [67/100], Step [600/1875], d_loss: -0.2485, g_loss:0.3985
# Epoch [67/100], Step [800/1875], d_loss: -0.3981, g_loss:0.6593
# Epoch [67/100], Step [1000/1875], d_loss: -0.2230, g_loss:0.4521
# Epoch [67/100], Step [1200/1875], d_loss: -0.3080, g_loss:0.6754
# Epoch [67/100], Step [1400/1875], d_loss: -0.3559, g_loss:0.1003
# Epoch [67/100], Step [1600/1875], d_loss: -0.5350, g_loss:0.1974
# Epoch [67/100], Step [1800/1875], d_loss: -0.3033, g_loss:1.3544
# Epoch [68/100], Step [200/1875], d_loss: -0.3156, g_loss:-0.0056
# Epoch [68/100], Step [400/1875], d_loss: -0.4644, g_loss:0.6933
# Epoch [68/100], Step [600/1875], d_loss: -0.3239, g_loss:0.4164
# Epoch [68/100], Step [800/1875], d_loss: -0.4618, g_loss:0.0035
# Epoch [68/100], Step [1000/1875], d_loss: -0.1844, g_loss:0.3286
# Epoch [68/100], Step [1200/1875], d_loss: -0.3707, g_loss:0.1627
# Epoch [68/100], Step [1400/1875], d_loss: -0.1732, g_loss:0.9038
# Epoch [68/100], Step [1600/1875], d_loss: -0.3563, g_loss:0.7356
# Epoch [68/100], Step [1800/1875], d_loss: -0.3011, g_loss:0.4024
# Epoch [69/100], Step [200/1875], d_loss: -0.2019, g_loss:-0.1568
# Epoch [69/100], Step [400/1875], d_loss: -0.3404, g_loss:-0.2927
# Epoch [69/100], Step [600/1875], d_loss: -0.4514, g_loss:1.5064
# Epoch [69/100], Step [800/1875], d_loss: -0.3572, g_loss:1.0015
# Epoch [69/100], Step [1000/1875], d_loss: -0.1995, g_loss:1.5857
# Epoch [69/100], Step [1200/1875], d_loss: -0.3120, g_loss:-0.0499
# Epoch [69/100], Step [1400/1875], d_loss: -0.3264, g_loss:0.4939
# Epoch [69/100], Step [1600/1875], d_loss: -0.5717, g_loss:-0.2640
# Epoch [69/100], Step [1800/1875], d_loss: -0.1776, g_loss:0.6178
# Epoch [70/100], Step [200/1875], d_loss: -0.4317, g_loss:0.0513
# Epoch [70/100], Step [400/1875], d_loss: -0.2972, g_loss:0.4840
# Epoch [70/100], Step [600/1875], d_loss: -0.2275, g_loss:-0.7158
# Epoch [70/100], Step [800/1875], d_loss: -0.4141, g_loss:0.5766
# Epoch [70/100], Step [1000/1875], d_loss: -0.2238, g_loss:-0.1141
# Epoch [70/100], Step [1200/1875], d_loss: -0.4181, g_loss:1.0341
# Epoch [70/100], Step [1400/1875], d_loss: -0.3865, g_loss:-0.5646
# Epoch [70/100], Step [1600/1875], d_loss: -0.3447, g_loss:0.3690
# Epoch [70/100], Step [1800/1875], d_loss: -0.1838, g_loss:0.4856
# Epoch [71/100], Step [200/1875], d_loss: -0.3995, g_loss:-0.0621
# Epoch [71/100], Step [400/1875], d_loss: -0.2058, g_loss:0.1175
# Epoch [71/100], Step [600/1875], d_loss: -0.3190, g_loss:1.1890
# Epoch [71/100], Step [800/1875], d_loss: -0.3520, g_loss:0.7092
# Epoch [71/100], Step [1000/1875], d_loss: -0.2160, g_loss:0.6676
# Epoch [71/100], Step [1200/1875], d_loss: -0.2949, g_loss:0.7122
# Epoch [71/100], Step [1400/1875], d_loss: -0.3748, g_loss:0.3068
# Epoch [71/100], Step [1600/1875], d_loss: -0.2069, g_loss:0.0321
# Epoch [71/100], Step [1800/1875], d_loss: -0.1840, g_loss:1.0625
# Epoch [72/100], Step [200/1875], d_loss: -0.3049, g_loss:0.3423
# Epoch [72/100], Step [400/1875], d_loss: -0.6340, g_loss:0.8738
# Epoch [72/100], Step [600/1875], d_loss: -0.5380, g_loss:-0.3312
# Epoch [72/100], Step [800/1875], d_loss: -0.2649, g_loss:0.3937
# Epoch [72/100], Step [1000/1875], d_loss: -0.4994, g_loss:-1.0396
# Epoch [72/100], Step [1200/1875], d_loss: -0.1768, g_loss:-0.7411
# Epoch [72/100], Step [1400/1875], d_loss: -0.2826, g_loss:0.7817
# Epoch [72/100], Step [1600/1875], d_loss: -0.4250, g_loss:-0.2694
# Epoch [72/100], Step [1800/1875], d_loss: -0.3127, g_loss:0.6074
# Epoch [73/100], Step [200/1875], d_loss: -0.4392, g_loss:-0.1194
# Epoch [73/100], Step [400/1875], d_loss: -0.3496, g_loss:1.0126
# Epoch [73/100], Step [600/1875], d_loss: -0.1202, g_loss:-0.1593
# Epoch [73/100], Step [800/1875], d_loss: -0.3891, g_loss:0.6589
# Epoch [73/100], Step [1000/1875], d_loss: -0.5303, g_loss:-0.0521
# Epoch [73/100], Step [1200/1875], d_loss: -0.2240, g_loss:0.7618
# Epoch [73/100], Step [1400/1875], d_loss: -0.3152, g_loss:0.1378
# Epoch [73/100], Step [1600/1875], d_loss: -0.0771, g_loss:0.2697
# Epoch [73/100], Step [1800/1875], d_loss: -0.3659, g_loss:0.6481
# Epoch [74/100], Step [200/1875], d_loss: -0.2701, g_loss:0.3574
# Epoch [74/100], Step [400/1875], d_loss: -0.2221, g_loss:0.0530
# Epoch [74/100], Step [600/1875], d_loss: -0.4011, g_loss:-0.3719
# Epoch [74/100], Step [800/1875], d_loss: -0.3130, g_loss:0.6530
# Epoch [74/100], Step [1000/1875], d_loss: -0.1491, g_loss:0.5318
# Epoch [74/100], Step [1200/1875], d_loss: -0.3794, g_loss:-0.0085
# Epoch [74/100], Step [1400/1875], d_loss: -0.2550, g_loss:0.6126
# Epoch [74/100], Step [1600/1875], d_loss: -0.4501, g_loss:-0.2905
# Epoch [74/100], Step [1800/1875], d_loss: -0.3445, g_loss:-0.9783
# Epoch [75/100], Step [200/1875], d_loss: -0.2057, g_loss:0.4123
# Epoch [75/100], Step [400/1875], d_loss: -0.4543, g_loss:1.1560
# Epoch [75/100], Step [600/1875], d_loss: -0.4750, g_loss:1.3886
# Epoch [75/100], Step [800/1875], d_loss: -0.4546, g_loss:0.1311
# Epoch [75/100], Step [1000/1875], d_loss: -0.3657, g_loss:-0.0142
# Epoch [75/100], Step [1200/1875], d_loss: -0.2109, g_loss:0.6506
# Epoch [75/100], Step [1400/1875], d_loss: -0.5628, g_loss:0.7234
# Epoch [75/100], Step [1600/1875], d_loss: -0.1791, g_loss:0.4635
# Epoch [75/100], Step [1800/1875], d_loss: -0.2925, g_loss:-0.1838
# Epoch [76/100], Step [200/1875], d_loss: -0.3216, g_loss:0.1662
# Epoch [76/100], Step [400/1875], d_loss: -0.1675, g_loss:0.2229
# Epoch [76/100], Step [600/1875], d_loss: -0.3972, g_loss:-0.4042
# Epoch [76/100], Step [800/1875], d_loss: -0.1305, g_loss:-0.7827
# Epoch [76/100], Step [1000/1875], d_loss: -0.2557, g_loss:0.6941
# Epoch [76/100], Step [1200/1875], d_loss: -0.3686, g_loss:0.8086
# Epoch [76/100], Step [1400/1875], d_loss: -0.3356, g_loss:0.0893
# Epoch [76/100], Step [1600/1875], d_loss: -0.2437, g_loss:-0.6605
# Epoch [76/100], Step [1800/1875], d_loss: -0.3635, g_loss:0.3396
# Epoch [77/100], Step [200/1875], d_loss: -0.3919, g_loss:0.4398
# Epoch [77/100], Step [400/1875], d_loss: -0.2743, g_loss:-0.2771
# Epoch [77/100], Step [600/1875], d_loss: -0.4468, g_loss:0.6743
# Epoch [77/100], Step [800/1875], d_loss: -0.2831, g_loss:-0.2875
# Epoch [77/100], Step [1000/1875], d_loss: -0.2137, g_loss:-0.0011
# Epoch [77/100], Step [1200/1875], d_loss: -0.2334, g_loss:0.3685
# Epoch [77/100], Step [1400/1875], d_loss: -0.3350, g_loss:-0.3348
# Epoch [77/100], Step [1600/1875], d_loss: -0.3324, g_loss:0.0894
# Epoch [77/100], Step [1800/1875], d_loss: -0.2240, g_loss:-0.5088
# Epoch [78/100], Step [200/1875], d_loss: -0.2923, g_loss:0.2523
# Epoch [78/100], Step [400/1875], d_loss: -0.4131, g_loss:-1.0290
# Epoch [78/100], Step [600/1875], d_loss: -0.1292, g_loss:-0.1244
# Epoch [78/100], Step [800/1875], d_loss: -0.2965, g_loss:0.8208
# Epoch [78/100], Step [1000/1875], d_loss: -0.2925, g_loss:0.0264
# Epoch [78/100], Step [1200/1875], d_loss: -0.2885, g_loss:0.9058
# Epoch [78/100], Step [1400/1875], d_loss: -0.3025, g_loss:0.3617
# Epoch [78/100], Step [1600/1875], d_loss: -0.3202, g_loss:-0.4509
# Epoch [78/100], Step [1800/1875], d_loss: -0.1238, g_loss:-0.4198
# Epoch [79/100], Step [200/1875], d_loss: -0.3443, g_loss:-0.4895
# Epoch [79/100], Step [400/1875], d_loss: -0.2200, g_loss:-0.4876
# Epoch [79/100], Step [600/1875], d_loss: -0.0638, g_loss:-0.4598
# Epoch [79/100], Step [800/1875], d_loss: -0.2666, g_loss:0.5074
# Epoch [79/100], Step [1000/1875], d_loss: -0.2566, g_loss:-0.2891
# Epoch [79/100], Step [1200/1875], d_loss: -0.3031, g_loss:-0.5943
# Epoch [79/100], Step [1400/1875], d_loss: -0.4130, g_loss:0.1445
# Epoch [79/100], Step [1600/1875], d_loss: 0.0256, g_loss:-0.0044
# Epoch [79/100], Step [1800/1875], d_loss: -0.4420, g_loss:-0.5471
# Epoch [80/100], Step [200/1875], d_loss: -0.3485, g_loss:-0.0446
# Epoch [80/100], Step [400/1875], d_loss: -0.6321, g_loss:0.3934
# Epoch [80/100], Step [600/1875], d_loss: -0.3462, g_loss:-1.0446
# Epoch [80/100], Step [800/1875], d_loss: -0.1862, g_loss:-0.3356
# Epoch [80/100], Step [1000/1875], d_loss: -0.3422, g_loss:0.5684
# Epoch [80/100], Step [1200/1875], d_loss: -0.2948, g_loss:-0.4603
# Epoch [80/100], Step [1400/1875], d_loss: -0.3353, g_loss:-0.6497
# Epoch [80/100], Step [1600/1875], d_loss: -0.1066, g_loss:-1.0043
# Epoch [80/100], Step [1800/1875], d_loss: -0.2339, g_loss:-0.2128
# Epoch [81/100], Step [200/1875], d_loss: -0.4046, g_loss:-0.3936
# Epoch [81/100], Step [400/1875], d_loss: -0.4952, g_loss:-0.5749
# Epoch [81/100], Step [600/1875], d_loss: -0.3028, g_loss:-0.6875
# Epoch [81/100], Step [800/1875], d_loss: -0.2233, g_loss:-0.5713
# Epoch [81/100], Step [1000/1875], d_loss: -0.1925, g_loss:-0.6331
# Epoch [81/100], Step [1200/1875], d_loss: -0.3058, g_loss:0.4366
# Epoch [81/100], Step [1400/1875], d_loss: -0.1480, g_loss:-0.6567
# Epoch [81/100], Step [1600/1875], d_loss: -0.2946, g_loss:-0.3532
# Epoch [81/100], Step [1800/1875], d_loss: -0.2867, g_loss:-0.0495
# Epoch [82/100], Step [200/1875], d_loss: -0.2326, g_loss:-0.7410
# Epoch [82/100], Step [400/1875], d_loss: -0.3367, g_loss:-0.5558
# Epoch [82/100], Step [600/1875], d_loss: -0.1136, g_loss:-0.0289
# Epoch [82/100], Step [800/1875], d_loss: -0.3188, g_loss:0.0240
# Epoch [82/100], Step [1000/1875], d_loss: -0.2476, g_loss:0.6873
# Epoch [82/100], Step [1200/1875], d_loss: -0.4066, g_loss:0.6543
# Epoch [82/100], Step [1400/1875], d_loss: -0.2718, g_loss:0.0854
# Epoch [82/100], Step [1600/1875], d_loss: -0.2491, g_loss:-0.3719
# Epoch [82/100], Step [1800/1875], d_loss: -0.2775, g_loss:-0.2497
# Epoch [83/100], Step [200/1875], d_loss: -0.3269, g_loss:-1.6381
# Epoch [83/100], Step [400/1875], d_loss: -0.4524, g_loss:-0.7693
# Epoch [83/100], Step [600/1875], d_loss: -0.5091, g_loss:0.1279
# Epoch [83/100], Step [800/1875], d_loss: -0.0929, g_loss:0.0375
# Epoch [83/100], Step [1000/1875], d_loss: -0.4539, g_loss:0.7740
# Epoch [83/100], Step [1200/1875], d_loss: -0.2448, g_loss:-0.4605
# Epoch [83/100], Step [1400/1875], d_loss: -0.2774, g_loss:-0.2039
# Epoch [83/100], Step [1600/1875], d_loss: -0.4002, g_loss:0.3146
# Epoch [83/100], Step [1800/1875], d_loss: -0.6363, g_loss:-1.4272
# Epoch [84/100], Step [200/1875], d_loss: -0.8851, g_loss:1.1751
# Epoch [84/100], Step [400/1875], d_loss: -0.1184, g_loss:0.2596
# Epoch [84/100], Step [600/1875], d_loss: -0.6402, g_loss:1.0373
# Epoch [84/100], Step [800/1875], d_loss: -0.7202, g_loss:0.8835
# Epoch [84/100], Step [1000/1875], d_loss: -0.3245, g_loss:-0.7831
# Epoch [84/100], Step [1200/1875], d_loss: -0.3765, g_loss:0.0684
# Epoch [84/100], Step [1400/1875], d_loss: -0.3340, g_loss:0.0505
# Epoch [84/100], Step [1600/1875], d_loss: -0.3125, g_loss:-0.7706
# Epoch [84/100], Step [1800/1875], d_loss: -0.3672, g_loss:-0.5360
# Epoch [85/100], Step [200/1875], d_loss: -0.1710, g_loss:-0.7118
# Epoch [85/100], Step [400/1875], d_loss: -0.1489, g_loss:-0.8458
# Epoch [85/100], Step [600/1875], d_loss: -0.2644, g_loss:-0.2235
# Epoch [85/100], Step [800/1875], d_loss: -0.2660, g_loss:0.7009
# Epoch [85/100], Step [1000/1875], d_loss: -0.5451, g_loss:-1.3181
# Epoch [85/100], Step [1200/1875], d_loss: -0.3204, g_loss:-0.6798
# Epoch [85/100], Step [1400/1875], d_loss: -0.3086, g_loss:-1.1200
# Epoch [85/100], Step [1600/1875], d_loss: -0.1249, g_loss:-0.5812
# Epoch [85/100], Step [1800/1875], d_loss: -0.1861, g_loss:-1.0246
# Epoch [86/100], Step [200/1875], d_loss: -0.3522, g_loss:-1.1320
# Epoch [86/100], Step [400/1875], d_loss: -0.3341, g_loss:-0.3942
# Epoch [86/100], Step [600/1875], d_loss: -0.2911, g_loss:-0.1357
# Epoch [86/100], Step [800/1875], d_loss: -0.4145, g_loss:0.0513
# Epoch [86/100], Step [1000/1875], d_loss: -0.3450, g_loss:-0.7768
# Epoch [86/100], Step [1200/1875], d_loss: -0.1774, g_loss:-0.1203
# Epoch [86/100], Step [1400/1875], d_loss: -0.5280, g_loss:0.0580
# Epoch [86/100], Step [1600/1875], d_loss: -0.2475, g_loss:0.0589
# Epoch [86/100], Step [1800/1875], d_loss: -0.1570, g_loss:1.0339
# Epoch [87/100], Step [200/1875], d_loss: -0.2328, g_loss:-0.0021
# Epoch [87/100], Step [400/1875], d_loss: -0.3806, g_loss:-0.0904
# Epoch [87/100], Step [600/1875], d_loss: -0.3917, g_loss:-0.8213
# Epoch [87/100], Step [800/1875], d_loss: -0.3574, g_loss:-0.1222
# Epoch [87/100], Step [1000/1875], d_loss: -0.3732, g_loss:-0.8481
# Epoch [87/100], Step [1200/1875], d_loss: -0.2004, g_loss:-0.5895
# Epoch [87/100], Step [1400/1875], d_loss: -0.3115, g_loss:-0.3222
# Epoch [87/100], Step [1600/1875], d_loss: -0.3544, g_loss:0.0559
# Epoch [87/100], Step [1800/1875], d_loss: -0.2070, g_loss:0.1821
# Epoch [88/100], Step [200/1875], d_loss: -0.4254, g_loss:-0.2335
# Epoch [88/100], Step [400/1875], d_loss: -0.4094, g_loss:-0.6995
# Epoch [88/100], Step [600/1875], d_loss: -0.2757, g_loss:-1.1086
# Epoch [88/100], Step [800/1875], d_loss: -0.2413, g_loss:-0.6041
# Epoch [88/100], Step [1000/1875], d_loss: -0.2871, g_loss:0.2658
# Epoch [88/100], Step [1200/1875], d_loss: -0.2926, g_loss:-1.7326
# Epoch [88/100], Step [1400/1875], d_loss: -0.2812, g_loss:-1.4046
# Epoch [88/100], Step [1600/1875], d_loss: -0.1735, g_loss:-1.7207
# Epoch [88/100], Step [1800/1875], d_loss: -0.2706, g_loss:-0.5642
# Epoch [89/100], Step [200/1875], d_loss: -0.2975, g_loss:0.6114
# Epoch [89/100], Step [400/1875], d_loss: -0.4786, g_loss:-0.4002
# Epoch [89/100], Step [600/1875], d_loss: -0.4014, g_loss:-0.4904
# Epoch [89/100], Step [1000/1875], d_loss: -0.0676, g_loss:-0.9861
# Epoch [89/100], Step [1200/1875], d_loss: -0.3594, g_loss:-0.7220
# Epoch [89/100], Step [1400/1875], d_loss: -0.3277, g_loss:-0.5164
# Epoch [89/100], Step [1600/1875], d_loss: -0.2820, g_loss:1.0879
# Epoch [89/100], Step [1800/1875], d_loss: -0.3077, g_loss:0.5047
# Epoch [90/100], Step [200/1875], d_loss: -0.3523, g_loss:-0.3274
# Epoch [90/100], Step [400/1875], d_loss: -0.3095, g_loss:-0.7093
# Epoch [90/100], Step [600/1875], d_loss: -0.3532, g_loss:0.1918
# Epoch [90/100], Step [800/1875], d_loss: -0.0420, g_loss:-0.7432
# Epoch [90/100], Step [1000/1875], d_loss: -0.5381, g_loss:-1.6423
# Epoch [90/100], Step [1200/1875], d_loss: -0.2437, g_loss:-0.1476
# Epoch [90/100], Step [1400/1875], d_loss: 0.0196, g_loss:-1.1197
# Epoch [90/100], Step [1600/1875], d_loss: -0.3085, g_loss:-0.2419
# Epoch [90/100], Step [1800/1875], d_loss: -0.3252, g_loss:-0.5150
# Epoch [91/100], Step [200/1875], d_loss: -0.2751, g_loss:0.8571
# Epoch [91/100], Step [400/1875], d_loss: -0.3137, g_loss:-0.5187
# Epoch [91/100], Step [600/1875], d_loss: -0.3048, g_loss:0.0348
# Epoch [91/100], Step [800/1875], d_loss: -0.2245, g_loss:-0.5102
# Epoch [91/100], Step [1000/1875], d_loss: -0.4205, g_loss:-1.1440
# Epoch [91/100], Step [1200/1875], d_loss: -0.5802, g_loss:-1.3326
# Epoch [91/100], Step [1400/1875], d_loss: -0.1913, g_loss:-0.7845
# Epoch [91/100], Step [1600/1875], d_loss: -0.3239, g_loss:-0.6086
# Epoch [91/100], Step [1800/1875], d_loss: -0.4362, g_loss:-0.3856
# Epoch [92/100], Step [200/1875], d_loss: -0.2713, g_loss:-0.1167
# Epoch [92/100], Step [400/1875], d_loss: -0.5090, g_loss:0.3115
# Epoch [92/100], Step [600/1875], d_loss: -0.2945, g_loss:-0.3222
# Epoch [92/100], Step [800/1875], d_loss: -0.4210, g_loss:-0.2992
# Epoch [92/100], Step [1000/1875], d_loss: -0.1999, g_loss:-0.6301
# Epoch [92/100], Step [1200/1875], d_loss: -0.2080, g_loss:-0.2730
# Epoch [92/100], Step [1400/1875], d_loss: -0.2929, g_loss:-0.5905
# Epoch [92/100], Step [1600/1875], d_loss: 0.0437, g_loss:-0.9485
# Epoch [92/100], Step [1800/1875], d_loss: -0.3147, g_loss:-0.8004
# Epoch [93/100], Step [200/1875], d_loss: -0.3353, g_loss:0.2578
# Epoch [93/100], Step [400/1875], d_loss: -0.7909, g_loss:0.4976
# Epoch [93/100], Step [600/1875], d_loss: -0.1887, g_loss:0.0845
# Epoch [93/100], Step [800/1875], d_loss: -0.5894, g_loss:-0.1457
# Epoch [93/100], Step [1000/1875], d_loss: -0.2896, g_loss:-0.6289
# Epoch [93/100], Step [1200/1875], d_loss: -0.3741, g_loss:-0.7100
# Epoch [93/100], Step [1400/1875], d_loss: -0.1967, g_loss:-0.7441
# Epoch [93/100], Step [1600/1875], d_loss: -0.4254, g_loss:0.4231
# Epoch [93/100], Step [1800/1875], d_loss: -0.3410, g_loss:-0.2965
# Epoch [94/100], Step [200/1875], d_loss: -0.2179, g_loss:-0.8029
# Epoch [94/100], Step [400/1875], d_loss: -0.4073, g_loss:-0.0113
# Epoch [94/100], Step [600/1875], d_loss: -0.5747, g_loss:0.5281
# Epoch [94/100], Step [800/1875], d_loss: -0.5848, g_loss:0.3320
# Epoch [94/100], Step [1000/1875], d_loss: -0.5513, g_loss:-0.5402
# Epoch [94/100], Step [1200/1875], d_loss: -0.1839, g_loss:-1.2337
# Epoch [94/100], Step [1400/1875], d_loss: -0.3247, g_loss:-0.5713
# Epoch [94/100], Step [1600/1875], d_loss: -0.3525, g_loss:-0.1147
# Epoch [94/100], Step [1800/1875], d_loss: -0.2260, g_loss:-0.7317
# Epoch [95/100], Step [200/1875], d_loss: -0.1213, g_loss:-1.3384
# Epoch [95/100], Step [400/1875], d_loss: -0.2927, g_loss:-1.2978
# Epoch [95/100], Step [600/1875], d_loss: -0.2284, g_loss:-0.0565
# Epoch [95/100], Step [800/1875], d_loss: -0.4205, g_loss:-0.4762
# Epoch [95/100], Step [1000/1875], d_loss: -0.3258, g_loss:-0.3850
# Epoch [95/100], Step [1200/1875], d_loss: -0.5313, g_loss:-1.8158
# Epoch [95/100], Step [1400/1875], d_loss: -0.3348, g_loss:0.2358
# Epoch [95/100], Step [1600/1875], d_loss: -0.4974, g_loss:-0.8822
# Epoch [95/100], Step [1800/1875], d_loss: -0.2010, g_loss:-0.7868
# Epoch [96/100], Step [200/1875], d_loss: -0.1320, g_loss:0.3888
# Epoch [96/100], Step [400/1875], d_loss: -0.2485, g_loss:-0.1057
# Epoch [96/100], Step [600/1875], d_loss: -0.4044, g_loss:0.6034
# Epoch [96/100], Step [800/1875], d_loss: -0.2379, g_loss:-0.5410
# Epoch [96/100], Step [1000/1875], d_loss: -0.1146, g_loss:-0.8885
# Epoch [96/100], Step [1200/1875], d_loss: -0.1802, g_loss:-1.2629
# Epoch [96/100], Step [1400/1875], d_loss: -0.0692, g_loss:-0.3655
# Epoch [96/100], Step [1600/1875], d_loss: -0.6921, g_loss:1.0741
# Epoch [96/100], Step [1800/1875], d_loss: -0.2477, g_loss:0.4670
# Epoch [97/100], Step [200/1875], d_loss: -0.0879, g_loss:0.3586
# Epoch [97/100], Step [400/1875], d_loss: -0.2560, g_loss:-0.4199
# Epoch [97/100], Step [600/1875], d_loss: -0.2574, g_loss:-0.2383
# Epoch [97/100], Step [800/1875], d_loss: -0.2930, g_loss:-0.2517
# Epoch [97/100], Step [1000/1875], d_loss: -0.4628, g_loss:-1.0461
# Epoch [97/100], Step [1200/1875], d_loss: -0.4041, g_loss:0.5205
# Epoch [97/100], Step [1400/1875], d_loss: -0.4725, g_loss:-0.8503
# Epoch [97/100], Step [1600/1875], d_loss: -0.3943, g_loss:-0.8187
# Epoch [97/100], Step [1800/1875], d_loss: -0.2482, g_loss:-0.5006
# Epoch [98/100], Step [200/1875], d_loss: -0.1841, g_loss:-0.3439
# Epoch [98/100], Step [400/1875], d_loss: -0.7549, g_loss:1.7117
# Epoch [98/100], Step [600/1875], d_loss: -0.5034, g_loss:-1.0275
# Epoch [98/100], Step [800/1875], d_loss: -0.3376, g_loss:-1.1576
# Epoch [98/100], Step [1000/1875], d_loss: -0.3360, g_loss:-0.0987
# Epoch [98/100], Step [1200/1875], d_loss: -0.2125, g_loss:-1.4247
# Epoch [98/100], Step [1400/1875], d_loss: -0.3629, g_loss:-1.3133
# Epoch [98/100], Step [1600/1875], d_loss: -0.2823, g_loss:-1.3831
# Epoch [98/100], Step [1800/1875], d_loss: -0.3883, g_loss:-0.8308
# Epoch [99/100], Step [200/1875], d_loss: -0.2656, g_loss:0.0499
# Epoch [99/100], Step [400/1875], d_loss: -0.2711, g_loss:-0.2730
# Epoch [99/100], Step [600/1875], d_loss: -0.3477, g_loss:-0.4649
# Epoch [99/100], Step [800/1875], d_loss: -0.1751, g_loss:-0.0098
# Epoch [99/100], Step [1000/1875], d_loss: -0.1858, g_loss:-0.2345
# Epoch [99/100], Step [1200/1875], d_loss: -0.2621, g_loss:0.1049
# Epoch [99/100], Step [1400/1875], d_loss: -0.3757, g_loss:0.7727
# Epoch [99/100], Step [1600/1875], d_loss: -0.3473, g_loss:0.5429
# Epoch [99/100], Step [1800/1875], d_loss: -0.4180, g_loss:-0.9192

# %% [markdown]
# ### Visualization

# %%
# Display losses for both the generator and discriminator
plt.figure()
plt.plot(range(1, num_epochs + 1), d_losses, label = 'd loss')
plt.plot(range(1, num_epochs + 1), g_losses, label = 'g loss')
plt.legend()
plt.show()

# %%
n_samples = 16
z = torch.randn(n_samples, latent_size).to(device)
fake_images = G(z)
fake_images = fake_images.cpu().detach().numpy().reshape(n_samples, 28, 28)

fig, axes = plt.subplots(4, 4, figsize=(8, 8))
for idx, ax in enumerate(axes.flat):
  ax.imshow(fake_images[idx], cmap='gray')
  ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Questions and expected answers for the report
#
# 1. [15 points] Copy and paste the code for your Critic class. Briefly explain your choice of architecture.
#
#
# 2. [15 points] Copy and paste the code for your Generator class. Briefly explain your choice of architecture.
#
#
# 3. [5 points] For how many iterations did you have to train when using Wasserstein with Conv/TransposeConv layers to get plausible images from the generator? Is it training faster than the Fully Connected Wasserstein/Vanilla GAN?
#
#
# 4. [5 points] Display some samples generated by your trained generator. Do they look plausible?
#
#
# 5. [10 points] Let us assume we use Conv2d layers in the Critic. We do NOT use Transposed Conv2d layers, but only Fully Connected layers in the Generator. Would the GAN still be able to train both models or would it encounter difficulties? Discuss.
