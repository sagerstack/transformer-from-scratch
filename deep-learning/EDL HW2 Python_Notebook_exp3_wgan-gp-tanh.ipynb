# %% [markdown]
# # HW 2 - Descriptive Notebook
#
# In this homework notebook, we will create a Wasserstein GAN with Convolution and Transpose Convolution layers for the MNIST Digit Generation dataset.
#
# Get familiar with the code and write a small report (2 pages max), with answers to the questions listed at the end of the notebook.
#
# **The report must be submitted in PDF format, before April 15th, 11.59pm!**
#
# Do not forget to write your name and student ID on the report.
#
# You may also submit your own copy of the notebook along with the report. If you do so, please add your name and ID to the cell below.

# %%
# Name: Sagar Pratap Singh
# Student ID: 1010736

# %%
# Dependencies for SUTD Cluster env
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ### Imports needed

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
from torch import Tensor
from torch.autograd import Variable
import torch.autograd as autograd
from torchvision.utils import save_image

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'mps')
print(device)
# Out:
# cuda

# %% [markdown]
# ### Dataset and dataloader

# %%
# Image transform to be applied to dataset
# - Tensor conversion
# transform = transforms.Compose([transforms.ToTensor()])
transform = transforms.Compose([                                                                                               
  transforms.ToTensor(),      
  transforms.Normalize([0.5], [0.5])                                                                                         
])

# %%
# MNIST train dataset
mnist = torchvision.datasets.MNIST(root = './data/',
                                   train = True,
                                   transform = transform,
                                   download = True)

# %%
# Data loader
batch_size = 32
data_loader = torch.utils.data.DataLoader(dataset = mnist,
                                          batch_size = batch_size,
                                          shuffle = True)

# %% [markdown]
# ### Critic model as a set of Conv2d layers

# %% [markdown]
# **Task1:** Rewrite the Critic model below, so that it uses Conv2d layers instead of fully connected ones shown in class.
#
# You may look for inspiration in the encoder models used in Notebook 3 (W9S1 lecture).
#
# The critic should use three Conv2d layers with progressive downsampling.
#
# We do not advise to add more layers to the mix (BatchNorm, Dropout, etc.).

# %%
# Critic
class Critic(nn.Module):

    def __init__(self, image_size):
        """
        Only forced parameter will be the image size, set to 28.
        """
        super().__init__()
        assert image_size == 28, "This architecture is written for 28x28 MNIST."

        self.net = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=4, stride=2, padding=1),   # 28 -> 14
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=1),  # 14 -> 7
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(32, 1, kernel_size=7, stride=1, padding=0)    # 7 -> 1
        )

    def forward(self, x):
        x = self.net(x)                  # (B, 1, 1, 1)
        return x.view(x.size(0), 1)      # (B, 1)

# %% [markdown]
# ### Generator model as a set of Transposed Conv2d layers

# %% [markdown]
# **Task2:** Rewrite the Generator model below, so that it uses Transposed Conv2d layers instead of fully connected ones shown in class.
#
# You may look for inspiration in the encoder models used in Notebooks 2 and 3 (W9S1 lecture).
#
# The critic should use three Transposed Conv2d layers with progressive upsampling.
#
# We do not advise to add more layers to the mix (BatchNorm, Dropout, etc.).

# %%
# Generator
class Generator(nn.Module):

    def __init__(self, latent_size, image_size):
        """
        Only forced parameters will be the image size, set to 28,
        and the latent size set to 64.
        """
        super().__init__()
        assert image_size == 28, "This architecture is written for 28x28 MNIST."

        self.net = nn.Sequential(
            nn.ConvTranspose2d(latent_size, 32, kernel_size=7, stride=1, padding=0),   # 1 -> 7
            nn.ReLU(inplace=True),

            nn.ConvTranspose2d(32, 16, kernel_size=4, stride=2, padding=1),             # 7 -> 14
            nn.ReLU(inplace=True),

            nn.ConvTranspose2d(16, 1, kernel_size=4, stride=2, padding=1),              # 14 -> 28
            # nn.Sigmoid()
            nn.Tanh()
        )

    def forward(self, x):
        x = x.view(x.size(0), x.size(1), 1, 1)   # (B, 64) -> (B, 64, 1, 1)
        return self.net(x)

# %% [markdown]
# ### Trainer function
#
# **Task 3:** Decide on a number of iterations num_epochs for training!

# %%
# Hyperparameters for model generation and training
latent_size = 64
image_size = 28
num_epochs = 50
batch_size = 64
lambda_gp = 10
n_critic = 5

# %%
# Create discriminator model
f = Critic(image_size)
f.to(device)
# Out:
# Critic(
#   (net): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Conv2d(16, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (3): LeakyReLU(negative_slope=0.2, inplace=True)
#     (4): Conv2d(32, 1, kernel_size=(7, 7), stride=(1, 1))
#   )
# )

# %%
# Create generator model
G = Generator(latent_size, image_size)
G.to(device)
# Out:
# Generator(
#   (net): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(7, 7), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): ConvTranspose2d(32, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): ConvTranspose2d(16, 1, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (5): Tanh()
#   )
# )

# %%
# Losses and optimizers
d_optimizer = torch.optim.Adam(f.parameters(), lr = 0.0002)
g_optimizer = torch.optim.Adam(G.parameters(), lr = 0.0002)

d_optimizer = torch.optim.Adam(f.parameters(), lr=0.0002, betas=(0.5,0.9))
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002, betas=(0.5,0.9))

# %%
# History trackers for training curves
# Keeping track of losses
d_losses = np.zeros(num_epochs)
g_losses = np.zeros(num_epochs)

# %% [markdown]
# **Note: running the cell below (our trainer function) will take a long time!**

# %%
total_step = len(data_loader)
for epoch in range(num_epochs):
  for i, (images, _) in enumerate(data_loader):

      images = images.to(device)

      # TRAIN CRITIC (n_critic steps per G step)
      for _ in range(n_critic):
          outputs_real = f(images)

          z = torch.randn(images.size(0), latent_size).to(device)
          fake_images = G(z).detach()
          outputs_fake = f(fake_images)

          # Gradient penalty on interpolated samples
          alpha = torch.rand(images.size(0), 1, 1, 1).to(device)
          interpolated = (alpha * images + (1 - alpha) * fake_images).requires_grad_(True)
          d_interpolated = f(interpolated)

          gradients = autograd.grad(
              outputs=d_interpolated,
              inputs=interpolated,
              grad_outputs=torch.ones_like(d_interpolated),
              create_graph=True,
              retain_graph=True)[0]
          gradients = gradients.view(gradients.size(0), -1)
          gradient_penalty = ((gradients.norm(2, dim=1) - 1) ** 2).mean()

          d_loss = -outputs_real.mean() + outputs_fake.mean() + lambda_gp * gradient_penalty

          d_optimizer.zero_grad()
          d_loss.backward()
          d_optimizer.step()

      # NO weight clipping

      # TRAIN GENERATOR
      z = torch.randn(images.size(0), latent_size).to(device)
      fake_images = G(z)
      outputs = f(fake_images)

      g_loss = -outputs.mean()

      g_optimizer.zero_grad()
      g_loss.backward()
      g_optimizer.step()

      # LOGGING
      d_losses[epoch] = d_losses[epoch] * (i/(i+1.)) + d_loss.item() * (1./(i+1.))
      g_losses[epoch] = g_losses[epoch] * (i/(i+1.)) + g_loss.item() * (1./(i+1.))

      if (i+1) % 200 == 0:
          print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss:{:.4f}'
                .format(epoch, num_epochs, i+1, total_step,d_loss.item(), g_loss.item()))
# Out:
# Epoch [0/50], Step [200/1875], d_loss: -23.3386, g_loss:3.2678
# Epoch [0/50], Step [400/1875], d_loss: -15.7740, g_loss:-2.7706
# Epoch [0/50], Step [600/1875], d_loss: -8.6197, g_loss:1.9524
# Epoch [0/50], Step [800/1875], d_loss: -5.2129, g_loss:7.0924
# Epoch [0/50], Step [1000/1875], d_loss: -3.9008, g_loss:2.0855
# Epoch [0/50], Step [1200/1875], d_loss: -2.7748, g_loss:-1.3438
# Epoch [0/50], Step [1400/1875], d_loss: -2.4347, g_loss:-5.9803
# Epoch [0/50], Step [1600/1875], d_loss: -2.5135, g_loss:-6.6430
# Epoch [0/50], Step [1800/1875], d_loss: -2.5527, g_loss:-5.5204
# Epoch [1/50], Step [200/1875], d_loss: -2.7152, g_loss:-6.8646
# Epoch [1/50], Step [400/1875], d_loss: -2.9063, g_loss:-2.1193
# Epoch [1/50], Step [600/1875], d_loss: -2.7366, g_loss:-7.0527
# Epoch [1/50], Step [800/1875], d_loss: -2.3927, g_loss:-4.7012
# Epoch [1/50], Step [1000/1875], d_loss: -2.2054, g_loss:-4.1933
# Epoch [1/50], Step [1200/1875], d_loss: -2.6262, g_loss:-6.2623
# Epoch [1/50], Step [1400/1875], d_loss: -2.2943, g_loss:-10.3931
# Epoch [1/50], Step [1600/1875], d_loss: -1.9395, g_loss:-3.9383
# Epoch [1/50], Step [1800/1875], d_loss: -2.5332, g_loss:-2.4737
# Epoch [2/50], Step [200/1875], d_loss: -2.0709, g_loss:-1.0840
# Epoch [2/50], Step [400/1875], d_loss: -2.2320, g_loss:-6.2596
# Epoch [2/50], Step [600/1875], d_loss: -1.8891, g_loss:-0.7134
# Epoch [2/50], Step [800/1875], d_loss: -1.7449, g_loss:-3.8643
# Epoch [2/50], Step [1000/1875], d_loss: -1.9870, g_loss:-1.0618
# Epoch [2/50], Step [1200/1875], d_loss: -1.4090, g_loss:-3.5992
# Epoch [2/50], Step [1400/1875], d_loss: -1.6542, g_loss:-4.4529
# Epoch [2/50], Step [1600/1875], d_loss: -0.9767, g_loss:-1.3515
# Epoch [2/50], Step [1800/1875], d_loss: -1.8230, g_loss:-4.3595
# Epoch [3/50], Step [200/1875], d_loss: -1.2829, g_loss:-2.9534
# Epoch [3/50], Step [400/1875], d_loss: -0.9131, g_loss:-1.5909
# Epoch [3/50], Step [600/1875], d_loss: -1.1999, g_loss:-1.6396
# Epoch [3/50], Step [800/1875], d_loss: -1.7705, g_loss:-7.5635
# Epoch [3/50], Step [1000/1875], d_loss: -1.3526, g_loss:-6.1073
# Epoch [3/50], Step [1200/1875], d_loss: -1.2866, g_loss:-5.8412
# Epoch [3/50], Step [1400/1875], d_loss: -1.3843, g_loss:-7.4034
# Epoch [3/50], Step [1600/1875], d_loss: -1.6703, g_loss:-8.6661
# Epoch [3/50], Step [1800/1875], d_loss: -1.3589, g_loss:-8.6019
# Epoch [4/50], Step [200/1875], d_loss: -1.2692, g_loss:-7.7555
# Epoch [4/50], Step [400/1875], d_loss: -1.4674, g_loss:-8.3848
# Epoch [4/50], Step [600/1875], d_loss: -0.9135, g_loss:-6.7668
# Epoch [4/50], Step [800/1875], d_loss: -1.6586, g_loss:-10.7820
# Epoch [4/50], Step [1000/1875], d_loss: -0.7277, g_loss:-7.9699
# Epoch [4/50], Step [1200/1875], d_loss: -0.4825, g_loss:-7.0758
# Epoch [4/50], Step [1400/1875], d_loss: -0.9813, g_loss:-8.3203
# Epoch [4/50], Step [1600/1875], d_loss: -1.3148, g_loss:-5.5650
# Epoch [4/50], Step [1800/1875], d_loss: -1.3996, g_loss:-9.5583
# Epoch [5/50], Step [200/1875], d_loss: -1.3816, g_loss:-11.1820
# Epoch [5/50], Step [400/1875], d_loss: -1.0317, g_loss:-10.9220
# Epoch [5/50], Step [600/1875], d_loss: -1.5280, g_loss:-11.9662
# Epoch [5/50], Step [800/1875], d_loss: -1.6274, g_loss:-14.2644
# Epoch [5/50], Step [1000/1875], d_loss: -1.2967, g_loss:-10.7608
# Epoch [5/50], Step [1200/1875], d_loss: -1.1556, g_loss:-11.0954
# Epoch [5/50], Step [1400/1875], d_loss: -1.1770, g_loss:-11.9297
# Epoch [5/50], Step [1600/1875], d_loss: -1.0854, g_loss:-11.0737
# Epoch [5/50], Step [1800/1875], d_loss: -0.7180, g_loss:-12.6419
# Epoch [6/50], Step [200/1875], d_loss: -1.4865, g_loss:-7.3852
# Epoch [6/50], Step [400/1875], d_loss: -0.9530, g_loss:-9.9081
# Epoch [6/50], Step [600/1875], d_loss: -0.9929, g_loss:-15.0420
# Epoch [6/50], Step [800/1875], d_loss: -1.0425, g_loss:-12.6603
# Epoch [6/50], Step [1000/1875], d_loss: -1.8736, g_loss:-13.7340
# Epoch [6/50], Step [1200/1875], d_loss: -0.9447, g_loss:-10.7577
# Epoch [6/50], Step [1400/1875], d_loss: -0.5643, g_loss:-9.3274
# Epoch [6/50], Step [1600/1875], d_loss: -1.4354, g_loss:-11.7603
# Epoch [6/50], Step [1800/1875], d_loss: -0.5936, g_loss:-12.5379
# Epoch [7/50], Step [200/1875], d_loss: -1.3639, g_loss:-16.9170
# Epoch [7/50], Step [400/1875], d_loss: -0.7538, g_loss:-14.9388
# Epoch [7/50], Step [600/1875], d_loss: -0.9363, g_loss:-15.7431
# Epoch [7/50], Step [800/1875], d_loss: -0.7490, g_loss:-16.9676
# Epoch [7/50], Step [1000/1875], d_loss: -1.2788, g_loss:-15.7649
# Epoch [7/50], Step [1200/1875], d_loss: -0.8990, g_loss:-16.8277
# Epoch [7/50], Step [1400/1875], d_loss: -0.9516, g_loss:-14.0337
# Epoch [7/50], Step [1600/1875], d_loss: -0.7051, g_loss:-16.0741
# Epoch [7/50], Step [1800/1875], d_loss: -0.8146, g_loss:-17.9096
# Epoch [8/50], Step [200/1875], d_loss: -1.3212, g_loss:-18.2501
# Epoch [8/50], Step [400/1875], d_loss: -1.5465, g_loss:-16.9691
# Epoch [8/50], Step [600/1875], d_loss: -0.5442, g_loss:-16.6332
# Epoch [8/50], Step [800/1875], d_loss: -1.0171, g_loss:-17.0211
# Epoch [8/50], Step [1000/1875], d_loss: -0.5927, g_loss:-16.3366
# Epoch [8/50], Step [1200/1875], d_loss: -1.3078, g_loss:-13.0297
# Epoch [8/50], Step [1400/1875], d_loss: -0.1766, g_loss:-15.2873
# Epoch [8/50], Step [1600/1875], d_loss: -0.7293, g_loss:-14.1306
# Epoch [8/50], Step [1800/1875], d_loss: -0.8475, g_loss:-16.8000
# Epoch [9/50], Step [200/1875], d_loss: -0.4382, g_loss:-19.3307
# Epoch [9/50], Step [400/1875], d_loss: -0.5679, g_loss:-15.4876
# Epoch [9/50], Step [600/1875], d_loss: -2.0598, g_loss:-13.1313
# Epoch [9/50], Step [800/1875], d_loss: -1.1212, g_loss:-20.8648
# Epoch [9/50], Step [1000/1875], d_loss: -0.7069, g_loss:-21.4578
# Epoch [9/50], Step [1200/1875], d_loss: -0.7040, g_loss:-16.7881
# Epoch [9/50], Step [1400/1875], d_loss: -1.8052, g_loss:-19.6523
# Epoch [9/50], Step [1600/1875], d_loss: -1.1763, g_loss:-23.4958
# Epoch [9/50], Step [1800/1875], d_loss: -1.0863, g_loss:-22.6491
# Epoch [10/50], Step [200/1875], d_loss: -0.9041, g_loss:-20.4120
# Epoch [10/50], Step [400/1875], d_loss: -0.7756, g_loss:-21.2007
# Epoch [10/50], Step [600/1875], d_loss: -0.9802, g_loss:-21.7717
# Epoch [10/50], Step [800/1875], d_loss: -0.4401, g_loss:-21.2859
# Epoch [10/50], Step [1000/1875], d_loss: -1.4865, g_loss:-20.4602
# Epoch [10/50], Step [1200/1875], d_loss: -1.0645, g_loss:-20.6354
# Epoch [10/50], Step [1400/1875], d_loss: -0.9445, g_loss:-24.6911
# Epoch [10/50], Step [1600/1875], d_loss: -0.7477, g_loss:-23.2137
# Epoch [10/50], Step [1800/1875], d_loss: -0.9626, g_loss:-19.7818
# Epoch [11/50], Step [200/1875], d_loss: -0.8198, g_loss:-22.4047
# Epoch [11/50], Step [400/1875], d_loss: -0.6452, g_loss:-23.2822
# Epoch [11/50], Step [600/1875], d_loss: -0.8941, g_loss:-23.3402
# Epoch [11/50], Step [800/1875], d_loss: -1.0093, g_loss:-25.7880
# Epoch [11/50], Step [1000/1875], d_loss: -1.2841, g_loss:-25.9197
# Epoch [11/50], Step [1200/1875], d_loss: -1.0627, g_loss:-25.0298
# Epoch [11/50], Step [1400/1875], d_loss: -0.7600, g_loss:-24.0052
# Epoch [11/50], Step [1600/1875], d_loss: -0.5454, g_loss:-22.5304
# Epoch [11/50], Step [1800/1875], d_loss: -0.7240, g_loss:-22.5310
# Epoch [12/50], Step [200/1875], d_loss: -0.9491, g_loss:-24.4136
# Epoch [12/50], Step [400/1875], d_loss: -0.9920, g_loss:-23.2458
# Epoch [12/50], Step [600/1875], d_loss: -1.1076, g_loss:-25.0804
# Epoch [12/50], Step [800/1875], d_loss: -1.2008, g_loss:-24.3514
# Epoch [12/50], Step [1000/1875], d_loss: -0.9914, g_loss:-22.3487
# Epoch [12/50], Step [1200/1875], d_loss: -1.1420, g_loss:-26.7619
# Epoch [12/50], Step [1400/1875], d_loss: -1.6978, g_loss:-21.2267
# Epoch [12/50], Step [1600/1875], d_loss: -1.1680, g_loss:-20.4191
# Epoch [12/50], Step [1800/1875], d_loss: -0.5244, g_loss:-23.4892
# Epoch [13/50], Step [200/1875], d_loss: -1.0324, g_loss:-24.4546
# Epoch [13/50], Step [400/1875], d_loss: -0.5192, g_loss:-21.0986
# Epoch [13/50], Step [600/1875], d_loss: -0.9894, g_loss:-24.1335
# Epoch [13/50], Step [800/1875], d_loss: -1.1027, g_loss:-22.7032
# Epoch [13/50], Step [1000/1875], d_loss: -1.6408, g_loss:-18.9830
# Epoch [13/50], Step [1200/1875], d_loss: -0.6892, g_loss:-24.2265
# Epoch [13/50], Step [1400/1875], d_loss: -0.5442, g_loss:-23.2377
# Epoch [13/50], Step [1600/1875], d_loss: -1.1872, g_loss:-25.3208
# Epoch [13/50], Step [1800/1875], d_loss: -0.7550, g_loss:-21.4499
# Epoch [14/50], Step [200/1875], d_loss: -1.1003, g_loss:-21.7407
# Epoch [14/50], Step [400/1875], d_loss: -0.6285, g_loss:-22.5558
# Epoch [14/50], Step [600/1875], d_loss: -1.2095, g_loss:-22.4512
# Epoch [14/50], Step [800/1875], d_loss: -0.5959, g_loss:-22.0303
# Epoch [14/50], Step [1000/1875], d_loss: -0.6712, g_loss:-25.6436
# Epoch [14/50], Step [1200/1875], d_loss: -1.2007, g_loss:-22.2528
# Epoch [14/50], Step [1400/1875], d_loss: -0.8928, g_loss:-21.7418
# Epoch [14/50], Step [1600/1875], d_loss: -0.7774, g_loss:-24.6529
# Epoch [14/50], Step [1800/1875], d_loss: -0.9703, g_loss:-23.4587
# Epoch [15/50], Step [200/1875], d_loss: -0.8345, g_loss:-21.5503
# Epoch [15/50], Step [400/1875], d_loss: -0.5945, g_loss:-19.1910
# Epoch [15/50], Step [600/1875], d_loss: -1.1766, g_loss:-22.3688
# Epoch [15/50], Step [800/1875], d_loss: -0.7654, g_loss:-21.6618
# Epoch [15/50], Step [1000/1875], d_loss: -0.6858, g_loss:-20.9416
# Epoch [15/50], Step [1200/1875], d_loss: -1.0577, g_loss:-21.5103
# Epoch [15/50], Step [1400/1875], d_loss: -0.9496, g_loss:-18.4058
# Epoch [15/50], Step [1600/1875], d_loss: -0.6847, g_loss:-16.7038
# Epoch [15/50], Step [1800/1875], d_loss: -0.7902, g_loss:-18.8180
# Epoch [16/50], Step [200/1875], d_loss: -1.4364, g_loss:-19.2925
# Epoch [16/50], Step [400/1875], d_loss: -1.0596, g_loss:-19.1113
# Epoch [16/50], Step [600/1875], d_loss: -0.9232, g_loss:-17.8099
# Epoch [16/50], Step [800/1875], d_loss: -0.7154, g_loss:-19.9267
# Epoch [16/50], Step [1000/1875], d_loss: -0.6141, g_loss:-19.5056
# Epoch [16/50], Step [1200/1875], d_loss: -0.9164, g_loss:-20.7606
# Epoch [16/50], Step [1400/1875], d_loss: -0.9518, g_loss:-21.6099
# Epoch [16/50], Step [1600/1875], d_loss: -0.6207, g_loss:-21.7522
# Epoch [16/50], Step [1800/1875], d_loss: -0.7885, g_loss:-22.1366
# Epoch [17/50], Step [200/1875], d_loss: -0.8719, g_loss:-20.2737
# Epoch [17/50], Step [400/1875], d_loss: -0.8057, g_loss:-18.4551
# Epoch [17/50], Step [600/1875], d_loss: -1.0758, g_loss:-19.3943
# Epoch [17/50], Step [800/1875], d_loss: -0.5989, g_loss:-20.5090
# Epoch [17/50], Step [1000/1875], d_loss: -0.7158, g_loss:-20.1519
# Epoch [17/50], Step [1200/1875], d_loss: -1.1761, g_loss:-21.0349
# Epoch [17/50], Step [1400/1875], d_loss: -0.9761, g_loss:-21.2565
# Epoch [17/50], Step [1600/1875], d_loss: -1.2601, g_loss:-22.2664
# Epoch [17/50], Step [1800/1875], d_loss: -1.0943, g_loss:-20.9862
# Epoch [18/50], Step [200/1875], d_loss: -0.9505, g_loss:-20.7669
# Epoch [18/50], Step [400/1875], d_loss: -0.9404, g_loss:-20.1641
# Epoch [18/50], Step [600/1875], d_loss: -0.7100, g_loss:-22.9126
# Epoch [18/50], Step [800/1875], d_loss: -0.8781, g_loss:-17.1284
# Epoch [18/50], Step [1000/1875], d_loss: -0.7812, g_loss:-21.5590
# Epoch [18/50], Step [1200/1875], d_loss: -0.3631, g_loss:-20.1652
# Epoch [18/50], Step [1400/1875], d_loss: -0.3535, g_loss:-18.4891
# Epoch [18/50], Step [1600/1875], d_loss: -0.2877, g_loss:-19.5133
# Epoch [18/50], Step [1800/1875], d_loss: -1.1017, g_loss:-21.8815
# Epoch [19/50], Step [200/1875], d_loss: -0.8958, g_loss:-18.7595
# Epoch [19/50], Step [400/1875], d_loss: -0.7992, g_loss:-19.9937
# Epoch [19/50], Step [600/1875], d_loss: -0.7319, g_loss:-20.3599
# Epoch [19/50], Step [800/1875], d_loss: -0.8505, g_loss:-20.4621
# Epoch [19/50], Step [1000/1875], d_loss: -0.8589, g_loss:-20.0505
# Epoch [19/50], Step [1200/1875], d_loss: -0.5203, g_loss:-18.3147
# Epoch [19/50], Step [1400/1875], d_loss: -0.5090, g_loss:-21.9621
# Epoch [19/50], Step [1600/1875], d_loss: -1.1616, g_loss:-19.2334
# Epoch [19/50], Step [1800/1875], d_loss: -1.2002, g_loss:-19.6760
# Epoch [20/50], Step [200/1875], d_loss: -1.1016, g_loss:-17.8046
# Epoch [20/50], Step [400/1875], d_loss: -1.2825, g_loss:-17.7252
# Epoch [20/50], Step [600/1875], d_loss: -0.8503, g_loss:-17.5618
# Epoch [20/50], Step [800/1875], d_loss: -0.9455, g_loss:-16.4802
# Epoch [20/50], Step [1000/1875], d_loss: -0.9336, g_loss:-18.4853
# Epoch [20/50], Step [1200/1875], d_loss: -0.8978, g_loss:-18.9588
# Epoch [20/50], Step [1400/1875], d_loss: -0.6018, g_loss:-18.0847
# Epoch [20/50], Step [1600/1875], d_loss: -0.8469, g_loss:-18.9252
# Epoch [20/50], Step [1800/1875], d_loss: -1.1443, g_loss:-16.5798
# Epoch [21/50], Step [200/1875], d_loss: -1.8283, g_loss:-14.0339
# Epoch [21/50], Step [400/1875], d_loss: -0.7893, g_loss:-16.0918
# Epoch [21/50], Step [600/1875], d_loss: -1.0309, g_loss:-14.7144
# Epoch [21/50], Step [800/1875], d_loss: -0.5428, g_loss:-11.8454
# Epoch [21/50], Step [1000/1875], d_loss: -0.8369, g_loss:-11.6573
# Epoch [21/50], Step [1200/1875], d_loss: -0.7707, g_loss:-12.3310
# Epoch [21/50], Step [1400/1875], d_loss: -0.7615, g_loss:-13.1051
# Epoch [21/50], Step [1600/1875], d_loss: -1.0142, g_loss:-8.7384
# Epoch [21/50], Step [1800/1875], d_loss: -0.6294, g_loss:-12.3760
# Epoch [22/50], Step [200/1875], d_loss: -0.8867, g_loss:-11.1439
# Epoch [22/50], Step [400/1875], d_loss: -1.0113, g_loss:-9.7672
# Epoch [22/50], Step [600/1875], d_loss: -0.7768, g_loss:-11.9223
# Epoch [22/50], Step [800/1875], d_loss: -0.5053, g_loss:-10.7107
# Epoch [22/50], Step [1000/1875], d_loss: -0.3888, g_loss:-10.3080
# Epoch [22/50], Step [1200/1875], d_loss: -1.2509, g_loss:-10.7191
# Epoch [22/50], Step [1400/1875], d_loss: -1.1913, g_loss:-8.8690
# Epoch [22/50], Step [1600/1875], d_loss: -0.7475, g_loss:-11.0208
# Epoch [22/50], Step [1800/1875], d_loss: -0.7534, g_loss:-9.8787
# Epoch [23/50], Step [200/1875], d_loss: -0.9614, g_loss:-11.7038
# Epoch [23/50], Step [400/1875], d_loss: -0.7112, g_loss:-12.8140
# Epoch [23/50], Step [600/1875], d_loss: -0.5073, g_loss:-10.1612
# Epoch [23/50], Step [800/1875], d_loss: -0.7178, g_loss:-10.8741
# Epoch [23/50], Step [1000/1875], d_loss: -1.4004, g_loss:-10.5849
# Epoch [23/50], Step [1200/1875], d_loss: -0.5730, g_loss:-11.0334
# Epoch [23/50], Step [1400/1875], d_loss: -0.7162, g_loss:-11.8844
# Epoch [23/50], Step [1600/1875], d_loss: -0.5782, g_loss:-11.9841
# Epoch [23/50], Step [1800/1875], d_loss: -0.7592, g_loss:-9.9212
# Epoch [24/50], Step [200/1875], d_loss: -1.0663, g_loss:-10.9139
# Epoch [24/50], Step [400/1875], d_loss: -0.9085, g_loss:-12.6703
# Epoch [24/50], Step [600/1875], d_loss: -0.4059, g_loss:-11.5403
# Epoch [24/50], Step [800/1875], d_loss: -1.3040, g_loss:-10.5284
# Epoch [24/50], Step [1000/1875], d_loss: -0.6659, g_loss:-12.2037
# Epoch [24/50], Step [1200/1875], d_loss: -1.0489, g_loss:-11.2477
# Epoch [24/50], Step [1400/1875], d_loss: -0.7900, g_loss:-11.4800
# Epoch [24/50], Step [1600/1875], d_loss: -0.9640, g_loss:-12.5763
# Epoch [24/50], Step [1800/1875], d_loss: -0.8255, g_loss:-12.5903
# Epoch [25/50], Step [200/1875], d_loss: -1.1688, g_loss:-10.1901
# Epoch [25/50], Step [400/1875], d_loss: -1.0881, g_loss:-12.5278
# Epoch [25/50], Step [600/1875], d_loss: -0.9373, g_loss:-11.7168
# Epoch [25/50], Step [800/1875], d_loss: -0.5822, g_loss:-11.0925
# Epoch [25/50], Step [1000/1875], d_loss: -1.1391, g_loss:-11.8994
# Epoch [25/50], Step [1200/1875], d_loss: -0.7109, g_loss:-11.4646
# Epoch [25/50], Step [1400/1875], d_loss: -0.5760, g_loss:-10.1184
# Epoch [25/50], Step [1600/1875], d_loss: -1.1275, g_loss:-9.9298
# Epoch [25/50], Step [1800/1875], d_loss: -1.1457, g_loss:-9.9016
# Epoch [26/50], Step [200/1875], d_loss: -0.9585, g_loss:-8.8703
# Epoch [26/50], Step [400/1875], d_loss: -0.9810, g_loss:-12.4230
# Epoch [26/50], Step [600/1875], d_loss: -0.4844, g_loss:-11.4096
# Epoch [26/50], Step [800/1875], d_loss: -0.7253, g_loss:-11.6781
# Epoch [26/50], Step [1000/1875], d_loss: -0.4961, g_loss:-8.7641
# Epoch [26/50], Step [1200/1875], d_loss: -1.0332, g_loss:-10.4972
# Epoch [26/50], Step [1400/1875], d_loss: -0.7488, g_loss:-11.0963
# Epoch [26/50], Step [1600/1875], d_loss: -0.8589, g_loss:-12.5522
# Epoch [26/50], Step [1800/1875], d_loss: -1.2493, g_loss:-11.5151
# Epoch [27/50], Step [200/1875], d_loss: -0.7148, g_loss:-10.6649
# Epoch [27/50], Step [400/1875], d_loss: -0.6765, g_loss:-11.1536
# Epoch [27/50], Step [600/1875], d_loss: -0.8044, g_loss:-11.3182
# Epoch [27/50], Step [800/1875], d_loss: -0.8822, g_loss:-9.8819
# Epoch [27/50], Step [1000/1875], d_loss: -0.8796, g_loss:-10.3802
# Epoch [27/50], Step [1200/1875], d_loss: -0.9632, g_loss:-9.9397
# Epoch [27/50], Step [1400/1875], d_loss: -0.7583, g_loss:-10.8544
# Epoch [27/50], Step [1600/1875], d_loss: -0.8067, g_loss:-11.9760
# Epoch [27/50], Step [1800/1875], d_loss: -0.6623, g_loss:-10.6970
# Epoch [28/50], Step [200/1875], d_loss: -0.8455, g_loss:-10.0805
# Epoch [28/50], Step [400/1875], d_loss: -0.8268, g_loss:-10.6124
# Epoch [28/50], Step [600/1875], d_loss: -1.0798, g_loss:-10.6957
# Epoch [28/50], Step [800/1875], d_loss: -0.8314, g_loss:-9.7600
# Epoch [28/50], Step [1000/1875], d_loss: -0.7095, g_loss:-9.8960
# Epoch [28/50], Step [1200/1875], d_loss: -0.8308, g_loss:-11.2866
# Epoch [28/50], Step [1400/1875], d_loss: -0.7672, g_loss:-10.3518
# Epoch [28/50], Step [1600/1875], d_loss: -0.3023, g_loss:-9.6881
# Epoch [28/50], Step [1800/1875], d_loss: -0.6700, g_loss:-10.8199
# Epoch [29/50], Step [200/1875], d_loss: -0.6501, g_loss:-8.7078
# Epoch [29/50], Step [400/1875], d_loss: -0.8111, g_loss:-11.3238
# Epoch [29/50], Step [600/1875], d_loss: -1.0225, g_loss:-7.5202
# Epoch [29/50], Step [800/1875], d_loss: -1.1857, g_loss:-10.1815
# Epoch [29/50], Step [1000/1875], d_loss: -0.5067, g_loss:-6.9983
# Epoch [29/50], Step [1200/1875], d_loss: -0.6114, g_loss:-9.2784
# Epoch [29/50], Step [1400/1875], d_loss: -1.1266, g_loss:-9.2658
# Epoch [29/50], Step [1600/1875], d_loss: -0.3323, g_loss:-9.9692
# Epoch [29/50], Step [1800/1875], d_loss: -0.5506, g_loss:-6.9149
# Epoch [30/50], Step [200/1875], d_loss: -0.9839, g_loss:-8.5738
# Epoch [30/50], Step [400/1875], d_loss: -0.3067, g_loss:-7.6917
# Epoch [30/50], Step [600/1875], d_loss: -0.7802, g_loss:-6.7688
# Epoch [30/50], Step [800/1875], d_loss: -0.4623, g_loss:-8.3207
# Epoch [30/50], Step [1000/1875], d_loss: -0.6172, g_loss:-9.0990
# Epoch [30/50], Step [1200/1875], d_loss: -1.0953, g_loss:-9.9732
# Epoch [30/50], Step [1400/1875], d_loss: -0.8498, g_loss:-8.1241
# Epoch [30/50], Step [1600/1875], d_loss: -1.2506, g_loss:-9.5485
# Epoch [30/50], Step [1800/1875], d_loss: -0.8302, g_loss:-8.1362
# Epoch [31/50], Step [200/1875], d_loss: -0.9696, g_loss:-9.2183
# Epoch [31/50], Step [400/1875], d_loss: -0.6293, g_loss:-8.8668
# Epoch [31/50], Step [600/1875], d_loss: -0.7178, g_loss:-10.5105
# Epoch [31/50], Step [800/1875], d_loss: -1.3228, g_loss:-4.8401
# Epoch [31/50], Step [1000/1875], d_loss: -1.0664, g_loss:-9.8110
# Epoch [31/50], Step [1200/1875], d_loss: -0.4528, g_loss:-9.4849
# Epoch [31/50], Step [1400/1875], d_loss: -0.9866, g_loss:-7.8670
# Epoch [31/50], Step [1600/1875], d_loss: -0.8167, g_loss:-9.7042
# Epoch [31/50], Step [1800/1875], d_loss: -0.9301, g_loss:-11.1991
# Epoch [32/50], Step [200/1875], d_loss: -0.5119, g_loss:-8.9424
# Epoch [32/50], Step [400/1875], d_loss: -0.9946, g_loss:-8.1492
# Epoch [32/50], Step [600/1875], d_loss: -0.6757, g_loss:-9.1030
# Epoch [32/50], Step [800/1875], d_loss: -0.0979, g_loss:-8.7506
# Epoch [32/50], Step [1000/1875], d_loss: -0.8312, g_loss:-10.4900
# Epoch [32/50], Step [1200/1875], d_loss: -0.4435, g_loss:-9.7155
# Epoch [32/50], Step [1400/1875], d_loss: -0.2518, g_loss:-7.5914
# Epoch [32/50], Step [1600/1875], d_loss: -0.5040, g_loss:-6.6348
# Epoch [32/50], Step [1800/1875], d_loss: -1.2124, g_loss:-9.5098
# Epoch [33/50], Step [200/1875], d_loss: -0.4336, g_loss:-9.9234
# Epoch [33/50], Step [400/1875], d_loss: -0.8212, g_loss:-11.0357
# Epoch [33/50], Step [600/1875], d_loss: -0.8568, g_loss:-7.2811
# Epoch [33/50], Step [800/1875], d_loss: -1.3553, g_loss:-7.3017
# Epoch [33/50], Step [1000/1875], d_loss: -0.6188, g_loss:-9.5898
# Epoch [33/50], Step [1200/1875], d_loss: -0.1129, g_loss:-7.7331
# Epoch [33/50], Step [1400/1875], d_loss: -0.9870, g_loss:-9.3541
# Epoch [33/50], Step [1600/1875], d_loss: -0.6777, g_loss:-9.4398
# Epoch [33/50], Step [1800/1875], d_loss: -0.8049, g_loss:-9.2889
# Epoch [34/50], Step [200/1875], d_loss: -0.8529, g_loss:-9.3243
# Epoch [34/50], Step [400/1875], d_loss: -0.8517, g_loss:-7.7342
# Epoch [34/50], Step [600/1875], d_loss: -0.6005, g_loss:-8.5774
# Epoch [34/50], Step [800/1875], d_loss: -0.6084, g_loss:-9.5818
# Epoch [34/50], Step [1000/1875], d_loss: -1.0625, g_loss:-11.0434
# Epoch [34/50], Step [1200/1875], d_loss: -0.3646, g_loss:-6.8720
# Epoch [34/50], Step [1400/1875], d_loss: -0.6304, g_loss:-8.0297
# Epoch [34/50], Step [1600/1875], d_loss: -0.5070, g_loss:-10.8816
# Epoch [34/50], Step [1800/1875], d_loss: -0.6667, g_loss:-10.6971
# Epoch [35/50], Step [200/1875], d_loss: -0.9360, g_loss:-9.3915
# Epoch [35/50], Step [400/1875], d_loss: -0.6970, g_loss:-11.5255
# Epoch [35/50], Step [600/1875], d_loss: -0.2694, g_loss:-9.3111
# Epoch [35/50], Step [800/1875], d_loss: -0.5340, g_loss:-10.6248
# Epoch [35/50], Step [1000/1875], d_loss: -0.2450, g_loss:-10.1406
# Epoch [35/50], Step [1200/1875], d_loss: -0.5107, g_loss:-9.0106
# Epoch [35/50], Step [1400/1875], d_loss: -0.5681, g_loss:-7.9293
# Epoch [35/50], Step [1600/1875], d_loss: -1.0870, g_loss:-6.7900
# Epoch [35/50], Step [1800/1875], d_loss: -0.3972, g_loss:-6.0112
# Epoch [36/50], Step [200/1875], d_loss: -0.4764, g_loss:-12.1493
# Epoch [36/50], Step [400/1875], d_loss: -0.7353, g_loss:-7.8188
# Epoch [36/50], Step [600/1875], d_loss: -1.0896, g_loss:-8.0274
# Epoch [36/50], Step [800/1875], d_loss: -0.9901, g_loss:-7.3871
# Epoch [36/50], Step [1000/1875], d_loss: -0.4583, g_loss:-10.0178
# Epoch [36/50], Step [1200/1875], d_loss: -0.6360, g_loss:-9.6637
# Epoch [36/50], Step [1400/1875], d_loss: -0.6840, g_loss:-11.2649
# Epoch [36/50], Step [1600/1875], d_loss: -0.9150, g_loss:-10.2194
# Epoch [36/50], Step [1800/1875], d_loss: -0.8493, g_loss:-8.3478
# Epoch [37/50], Step [200/1875], d_loss: -0.5587, g_loss:-8.2875
# Epoch [37/50], Step [400/1875], d_loss: -0.6585, g_loss:-8.4657
# Epoch [37/50], Step [600/1875], d_loss: -0.9436, g_loss:-10.2236
# Epoch [37/50], Step [800/1875], d_loss: -0.7903, g_loss:-7.0963
# Epoch [37/50], Step [1000/1875], d_loss: -0.3832, g_loss:-7.1380
# Epoch [37/50], Step [1200/1875], d_loss: -0.6267, g_loss:-9.1841
# Epoch [37/50], Step [1400/1875], d_loss: -0.7210, g_loss:-7.5429
# Epoch [37/50], Step [1600/1875], d_loss: -1.0248, g_loss:-10.2755
# Epoch [37/50], Step [1800/1875], d_loss: -0.3947, g_loss:-7.3095
# Epoch [38/50], Step [200/1875], d_loss: -0.4412, g_loss:-8.3278
# Epoch [38/50], Step [400/1875], d_loss: -0.5159, g_loss:-7.7588
# Epoch [38/50], Step [600/1875], d_loss: -0.2418, g_loss:-8.6219
# Epoch [38/50], Step [800/1875], d_loss: -0.8007, g_loss:-7.1852
# Epoch [38/50], Step [1000/1875], d_loss: -0.7542, g_loss:-9.6881
# Epoch [38/50], Step [1200/1875], d_loss: -0.7344, g_loss:-7.6430
# Epoch [38/50], Step [1400/1875], d_loss: -0.5842, g_loss:-9.1385
# Epoch [38/50], Step [1600/1875], d_loss: -0.8450, g_loss:-8.9980
# Epoch [38/50], Step [1800/1875], d_loss: -1.2815, g_loss:-12.6255
# Epoch [39/50], Step [200/1875], d_loss: -0.6627, g_loss:-9.1231
# Epoch [39/50], Step [400/1875], d_loss: -0.9518, g_loss:-9.8026
# Epoch [39/50], Step [600/1875], d_loss: -0.9131, g_loss:-6.2988
# Epoch [39/50], Step [800/1875], d_loss: -0.7517, g_loss:-10.2902
# Epoch [39/50], Step [1000/1875], d_loss: -0.7328, g_loss:-10.1082
# Epoch [39/50], Step [1200/1875], d_loss: -0.6214, g_loss:-9.9503
# Epoch [39/50], Step [1400/1875], d_loss: -0.7544, g_loss:-9.2998
# Epoch [39/50], Step [1600/1875], d_loss: -1.0640, g_loss:-7.2370
# Epoch [39/50], Step [1800/1875], d_loss: -1.0599, g_loss:-8.4016
# Epoch [40/50], Step [200/1875], d_loss: -0.4579, g_loss:-7.2103
# Epoch [40/50], Step [400/1875], d_loss: -0.8911, g_loss:-10.8364
# Epoch [40/50], Step [600/1875], d_loss: -0.5322, g_loss:-8.9839
# Epoch [40/50], Step [800/1875], d_loss: -0.5901, g_loss:-8.2155
# Epoch [40/50], Step [1000/1875], d_loss: -0.7632, g_loss:-9.7918
# Epoch [40/50], Step [1200/1875], d_loss: -0.8397, g_loss:-6.2511
# Epoch [40/50], Step [1400/1875], d_loss: -0.5579, g_loss:-9.0767
# Epoch [40/50], Step [1600/1875], d_loss: -0.6102, g_loss:-10.9860
# Epoch [40/50], Step [1800/1875], d_loss: -0.4114, g_loss:-10.8772
# Epoch [41/50], Step [200/1875], d_loss: -0.5986, g_loss:-9.6307
# Epoch [41/50], Step [400/1875], d_loss: -0.9105, g_loss:-10.8697
# Epoch [41/50], Step [600/1875], d_loss: -0.6514, g_loss:-9.2603
# Epoch [41/50], Step [800/1875], d_loss: -0.6359, g_loss:-10.8397
# Epoch [41/50], Step [1000/1875], d_loss: -0.7592, g_loss:-10.6584
# Epoch [41/50], Step [1200/1875], d_loss: -0.6240, g_loss:-10.0975
# Epoch [41/50], Step [1400/1875], d_loss: -0.6871, g_loss:-11.3175
# Epoch [41/50], Step [1600/1875], d_loss: -0.5011, g_loss:-10.2596
# Epoch [41/50], Step [1800/1875], d_loss: -0.6920, g_loss:-6.6933
# Epoch [42/50], Step [200/1875], d_loss: -0.7671, g_loss:-11.2300
# Epoch [42/50], Step [400/1875], d_loss: -0.5297, g_loss:-9.4821
# Epoch [42/50], Step [600/1875], d_loss: -0.6032, g_loss:-10.3637
# Epoch [42/50], Step [800/1875], d_loss: -0.2004, g_loss:-7.8323
# Epoch [42/50], Step [1000/1875], d_loss: -0.6559, g_loss:-7.5835
# Epoch [42/50], Step [1200/1875], d_loss: -0.4376, g_loss:-8.4733
# Epoch [42/50], Step [1400/1875], d_loss: -0.6258, g_loss:-10.2640
# Epoch [42/50], Step [1600/1875], d_loss: -0.3381, g_loss:-9.5297
# Epoch [42/50], Step [1800/1875], d_loss: -1.0146, g_loss:-5.5283
# Epoch [43/50], Step [200/1875], d_loss: -0.3935, g_loss:-7.3083
# Epoch [43/50], Step [400/1875], d_loss: -0.6550, g_loss:-10.0968
# Epoch [43/50], Step [600/1875], d_loss: -0.5271, g_loss:-9.6479
# Epoch [43/50], Step [800/1875], d_loss: -0.5227, g_loss:-6.5965
# Epoch [43/50], Step [1000/1875], d_loss: -0.5100, g_loss:-9.2671
# Epoch [43/50], Step [1200/1875], d_loss: -0.7126, g_loss:-9.4413
# Epoch [43/50], Step [1400/1875], d_loss: -0.9101, g_loss:-10.0910
# Epoch [43/50], Step [1600/1875], d_loss: -0.5422, g_loss:-10.9082
# Epoch [43/50], Step [1800/1875], d_loss: -1.0629, g_loss:-7.3156
# Epoch [44/50], Step [200/1875], d_loss: -0.7665, g_loss:-10.1627
# Epoch [44/50], Step [400/1875], d_loss: -0.9553, g_loss:-6.8641
# Epoch [44/50], Step [600/1875], d_loss: -0.6434, g_loss:-10.6182
# Epoch [44/50], Step [800/1875], d_loss: -0.5094, g_loss:-11.2376
# Epoch [44/50], Step [1000/1875], d_loss: -0.9804, g_loss:-10.1580
# Epoch [44/50], Step [1200/1875], d_loss: -0.4476, g_loss:-8.6309
# Epoch [44/50], Step [1400/1875], d_loss: -0.3213, g_loss:-10.4704
# Epoch [44/50], Step [1600/1875], d_loss: -0.4524, g_loss:-6.8340
# Epoch [44/50], Step [1800/1875], d_loss: -0.7714, g_loss:-7.0160
# Epoch [45/50], Step [200/1875], d_loss: -0.4261, g_loss:-6.7084
# Epoch [45/50], Step [400/1875], d_loss: -1.0744, g_loss:-9.1888
# Epoch [45/50], Step [600/1875], d_loss: -0.4870, g_loss:-7.1601
# Epoch [45/50], Step [800/1875], d_loss: -0.6727, g_loss:-8.4448
# Epoch [45/50], Step [1000/1875], d_loss: -0.7803, g_loss:-7.7521
# Epoch [45/50], Step [1200/1875], d_loss: -0.4961, g_loss:-9.1058
# Epoch [45/50], Step [1400/1875], d_loss: -0.8171, g_loss:-5.8677
# Epoch [45/50], Step [1600/1875], d_loss: -1.1059, g_loss:-9.7411
# Epoch [45/50], Step [1800/1875], d_loss: -0.7043, g_loss:-8.5544
# Epoch [46/50], Step [200/1875], d_loss: -0.9424, g_loss:-9.4537
# Epoch [46/50], Step [400/1875], d_loss: -0.6222, g_loss:-9.4702
# Epoch [46/50], Step [600/1875], d_loss: -0.8293, g_loss:-8.2346
# Epoch [46/50], Step [800/1875], d_loss: -0.7137, g_loss:-8.9274
# Epoch [46/50], Step [1000/1875], d_loss: -0.5310, g_loss:-10.3713
# Epoch [46/50], Step [1200/1875], d_loss: -0.6169, g_loss:-9.8085
# Epoch [46/50], Step [1400/1875], d_loss: -0.5822, g_loss:-9.5378
# Epoch [46/50], Step [1600/1875], d_loss: -0.7907, g_loss:-8.5997
# Epoch [46/50], Step [1800/1875], d_loss: -1.0153, g_loss:-8.4537
# Epoch [47/50], Step [200/1875], d_loss: 0.5791, g_loss:-10.1549
# Epoch [47/50], Step [400/1875], d_loss: -0.8165, g_loss:-8.4293
# Epoch [47/50], Step [600/1875], d_loss: -0.8500, g_loss:-8.6761
# Epoch [47/50], Step [800/1875], d_loss: -0.6164, g_loss:-7.2739
# Epoch [47/50], Step [1000/1875], d_loss: -1.1521, g_loss:-8.4341
# Epoch [47/50], Step [1200/1875], d_loss: -0.1515, g_loss:-6.6590
# Epoch [47/50], Step [1400/1875], d_loss: -0.7013, g_loss:-6.1595
# Epoch [47/50], Step [1600/1875], d_loss: -0.6327, g_loss:-7.3647
# Epoch [47/50], Step [1800/1875], d_loss: -1.2058, g_loss:-9.5287
# Epoch [48/50], Step [200/1875], d_loss: -0.5778, g_loss:-6.2220
# Epoch [48/50], Step [400/1875], d_loss: -0.6677, g_loss:-10.3890
# Epoch [48/50], Step [600/1875], d_loss: -0.8105, g_loss:-8.8315
# Epoch [48/50], Step [800/1875], d_loss: -0.2967, g_loss:-8.7791
# Epoch [48/50], Step [1000/1875], d_loss: -0.6392, g_loss:-8.5449
# Epoch [48/50], Step [1200/1875], d_loss: -0.3189, g_loss:-7.7697
# Epoch [48/50], Step [1400/1875], d_loss: -0.9476, g_loss:-6.9977
# Epoch [48/50], Step [1600/1875], d_loss: -0.8517, g_loss:-7.7064
# Epoch [48/50], Step [1800/1875], d_loss: -0.4976, g_loss:-9.0031
# Epoch [49/50], Step [200/1875], d_loss: -1.0168, g_loss:-5.2473
# Epoch [49/50], Step [400/1875], d_loss: -0.5343, g_loss:-9.2477
# Epoch [49/50], Step [600/1875], d_loss: -0.1649, g_loss:-8.7282
# Epoch [49/50], Step [800/1875], d_loss: -0.4562, g_loss:-7.2807
# Epoch [49/50], Step [1000/1875], d_loss: -0.5933, g_loss:-5.1466
# Epoch [49/50], Step [1200/1875], d_loss: -0.5567, g_loss:-6.7936
# Epoch [49/50], Step [1400/1875], d_loss: -0.5784, g_loss:-7.9367
# Epoch [49/50], Step [1600/1875], d_loss: -0.9950, g_loss:-5.0961
# Epoch [49/50], Step [1800/1875], d_loss: -0.9895, g_loss:-6.1278

# %% [markdown]
# ### Visualization

# %%
# Display losses for both the generator and discriminator
plt.figure()
plt.plot(range(1, num_epochs + 1), d_losses, label = 'd loss')
plt.plot(range(1, num_epochs + 1), g_losses, label = 'g loss')
plt.legend()
plt.show()

# %%
n_samples = 16
z = torch.randn(n_samples, latent_size).to(device)                                                                             
fake_images = G(z)                                                                                 
fake_images = fake_images.cpu().detach().numpy().reshape(n_samples, 28, 28)
fake_images = (fake_images + 1) / 2                                                                                            
                                          
fig, axes = plt.subplots(4, 4, figsize=(8, 8))                                                                                 
for idx, ax in enumerate(axes.flat):                                                               
  ax.imshow(fake_images[idx], cmap='gray')                                                                                   
  ax.axis('off')                          
plt.tight_layout()                                                                                                             
plt.show()

# %% [markdown]
# ### Questions and expected answers for the report
#
# 1. [15 points] Copy and paste the code for your Critic class. Briefly explain your choice of architecture.
#
#
# 2. [15 points] Copy and paste the code for your Generator class. Briefly explain your choice of architecture.
#
#
# 3. [5 points] For how many iterations did you have to train when using Wasserstein with Conv/TransposeConv layers to get plausible images from the generator? Is it training faster than the Fully Connected Wasserstein/Vanilla GAN?
#
#
# 4. [5 points] Display some samples generated by your trained generator. Do they look plausible?
#
#
# 5. [10 points] Let us assume we use Conv2d layers in the Critic. We do NOT use Transposed Conv2d layers, but only Fully Connected layers in the Generator. Would the GAN still be able to train both models or would it encounter difficulties? Discuss.
