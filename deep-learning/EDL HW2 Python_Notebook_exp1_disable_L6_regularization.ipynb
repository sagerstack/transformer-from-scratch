# %% [markdown]
# # HW 2 - Descriptive Notebook
#
# In this homework notebook, we will create a Wasserstein GAN with Convolution and Transpose Convolution layers for the MNIST Digit Generation dataset.
#
# Get familiar with the code and write a small report (2 pages max), with answers to the questions listed at the end of the notebook.
#
# **The report must be submitted in PDF format, before April 15th, 11.59pm!**
#
# Do not forget to write your name and student ID on the report.
#
# You may also submit your own copy of the notebook along with the report. If you do so, please add your name and ID to the cell below.

# %%
# Name: Sagar Pratap Singh
# Student ID: 1010736

# %%
# Dependencies for SUTD Cluster env
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ### Imports needed

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
from torch import Tensor
from torch.autograd import Variable
import torch.autograd as autograd
from torchvision.utils import save_image

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'mps')
print(device)
# Out:
# cuda

# %% [markdown]
# ### Dataset and dataloader

# %%
# Image transform to be applied to dataset
# - Tensor conversion
transform = transforms.Compose([transforms.ToTensor()])

# %%
# MNIST train dataset
mnist = torchvision.datasets.MNIST(root = './data/',
                                   train = True,
                                   transform = transform,
                                   download = True)

# %%
# Data loader
batch_size = 32
data_loader = torch.utils.data.DataLoader(dataset = mnist,
                                          batch_size = batch_size,
                                          shuffle = True)

# %% [markdown]
# ### Critic model as a set of Conv2d layers

# %% [markdown]
# **Task1:** Rewrite the Critic model below, so that it uses Conv2d layers instead of fully connected ones shown in class.
#
# You may look for inspiration in the encoder models used in Notebook 3 (W9S1 lecture).
#
# The critic should use three Conv2d layers with progressive downsampling.
#
# We do not advise to add more layers to the mix (BatchNorm, Dropout, etc.).

# %%
# Critic
class Critic(nn.Module):

    def __init__(self, image_size):
        """
        Only forced parameter will be the image size, set to 28.
        """
        super().__init__()
        assert image_size == 28, "This architecture is written for 28x28 MNIST."

        self.net = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=4, stride=2, padding=1),   # 28 -> 14
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=1),  # 14 -> 7
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(32, 1, kernel_size=7, stride=1, padding=0)    # 7 -> 1
        )

    def forward(self, x):
        x = self.net(x)                  # (B, 1, 1, 1)
        return x.view(x.size(0), 1)      # (B, 1)

# %% [markdown]
# ### Generator model as a set of Transposed Conv2d layers

# %% [markdown]
# **Task2:** Rewrite the Generator model below, so that it uses Transposed Conv2d layers instead of fully connected ones shown in class.
#
# You may look for inspiration in the encoder models used in Notebooks 2 and 3 (W9S1 lecture).
#
# The critic should use three Transposed Conv2d layers with progressive upsampling.
#
# We do not advise to add more layers to the mix (BatchNorm, Dropout, etc.).

# %%
# Generator
class Generator(nn.Module):

    def __init__(self, latent_size, image_size):
        """
        Only forced parameters will be the image size, set to 28,
        and the latent size set to 64.
        """
        super().__init__()
        assert image_size == 28, "This architecture is written for 28x28 MNIST."

        self.net = nn.Sequential(
            nn.ConvTranspose2d(latent_size, 32, kernel_size=7, stride=1, padding=0),   # 1 -> 7
            nn.ReLU(inplace=True),

            nn.ConvTranspose2d(32, 16, kernel_size=4, stride=2, padding=1),             # 7 -> 14
            nn.ReLU(inplace=True),

            nn.ConvTranspose2d(16, 1, kernel_size=4, stride=2, padding=1),              # 14 -> 28
            nn.Sigmoid()
        )

    def forward(self, x):
        x = x.view(x.size(0), x.size(1), 1, 1)   # (B, 64) -> (B, 64, 1, 1)
        return self.net(x)

# %% [markdown]
# ### Trainer function
#
# **Task 3:** Decide on a number of iterations num_epochs for training!

# %%
# Hyperparameters for model generation and training
latent_size = 64
image_size = 28
num_epochs = 50 # exp 1 - vanilla training, 50 epochs
batch_size = 32
lambda_val = 0

# %%
# Create discriminator model
f = Critic(image_size)
f.to(device)
# Out:
# Critic(
#   (net): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Conv2d(16, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (3): LeakyReLU(negative_slope=0.2, inplace=True)
#     (4): Conv2d(32, 1, kernel_size=(7, 7), stride=(1, 1))
#   )
# )

# %%
# Create generator model
G = Generator(latent_size, image_size)
G.to(device)
# Out:
# Generator(
#   (net): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(7, 7), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): ConvTranspose2d(32, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): ConvTranspose2d(16, 1, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (5): Sigmoid()
#   )
# )

# %%
# Losses and optimizers
d_optimizer = torch.optim.Adam(f.parameters(), lr = 0.0002)
g_optimizer = torch.optim.Adam(G.parameters(), lr = 0.0002)

# %%
# History trackers for training curves
# Keeping track of losses
d_losses = np.zeros(num_epochs)
g_losses = np.zeros(num_epochs)

# %% [markdown]
# **Note: running the cell below (our trainer function) will take a long time!**

# %%
total_step = len(data_loader)
for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):

        # 1. Send image to device
        images = Variable(images, requires_grad = True).to(device)

        """
        PART 1: TRAIN THE CRITIC
        """

        # 2. Compute mean of critic decisions using real images
        outputs_real = f(images)

        # 2.bis. Compute mean of critic decisions using fake images
        z = torch.randn(batch_size, latent_size).to(device)
        z = Variable(z)
        fake_images = G(z)
        outputs_fake = f(fake_images)

        # 3. Compute gradient regularization
        real_grad_out = Variable(Tensor(images.size(0), 1).fill_(1.0), requires_grad = False).to(device)
        real_grad = autograd.grad(outputs_real, images, real_grad_out, create_graph = True, \
                                  retain_graph = True, only_inputs = True)[0]
        real_grad_norm = real_grad.view(real_grad.size(0), -1).pow(2).sum(1)**3
        fake_grad_out = Variable(Tensor(fake_images.size(0), 1).fill_(1.0), requires_grad = False).to(device)
        fake_grad = autograd.grad(outputs_fake, fake_images, fake_grad_out, create_graph = True, \
                                  retain_graph = True, only_inputs = True)[0]
        fake_grad_norm = fake_grad.view(fake_grad.size(0), -1).pow(2).sum(1)**3
        reg_term = torch.mean(real_grad_norm + fake_grad_norm)

        # 4. Backprop and optimize for f
        # Loss is simply the difference between means, plus regularization term
        # Remember to reset gradients for both optimizers!
        d_loss = -torch.mean(outputs_real) + torch.mean(outputs_fake) + lambda_val*reg_term
        d_optimizer.zero_grad()
        g_optimizer.zero_grad()
        d_loss.backward()
        d_optimizer.step()

        # 4.bis. Optional, weight clipping on critic
        # (Mentioned in WGAN paper)
        for p in f.parameters():
            p.data.clamp_(-0.01, 0.01)


        """
        PART 2: TRAIN THE GENERATOR
        """

        # 5. Generate fresh noise samples and produce fake images
        z = torch.randn(batch_size, latent_size).cuda()
        z = Variable(z)
        fake_images = G(z)
        outputs = f(fake_images)

        # 6. Loss for G
        g_loss = - torch.mean(outputs)

        # 7. Backprop and optimize G
        # Remember to reset gradients for both optimizers!
        d_optimizer.zero_grad()
        g_optimizer.zero_grad()
        g_loss.backward()
        g_optimizer.step()


        """
        PART 3: UPDATE STATISTICS FOR VISUALIZATION LATER
        """

        # 8. Update the losses and scores for mini-batches
        d_losses[epoch] = d_losses[epoch]*(i/(i+1.)) \
            + d_loss.item()*(1./(i+1.))
        g_losses[epoch] = g_losses[epoch]*(i/(i+1.)) \
            + g_loss.item()*(1./(i+1.))

        # 9. Display
        if (i+1) % 200 == 0:
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}'
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item()))
# Out:
# Epoch [0/50], Step [200/1875], d_loss: -0.2584, g_loss: 0.0640
# Epoch [0/50], Step [400/1875], d_loss: -0.1524, g_loss: -0.1580
# Epoch [0/50], Step [600/1875], d_loss: -0.0314, g_loss: -0.1484
# Epoch [0/50], Step [800/1875], d_loss: -0.0116, g_loss: 0.0350
# Epoch [0/50], Step [1000/1875], d_loss: -0.0186, g_loss: 0.1148
# Epoch [0/50], Step [1200/1875], d_loss: -0.1063, g_loss: 0.2398
# Epoch [0/50], Step [1400/1875], d_loss: 0.0001, g_loss: -0.2213
# Epoch [0/50], Step [1600/1875], d_loss: -0.0060, g_loss: 0.0125
# Epoch [0/50], Step [1800/1875], d_loss: -0.0368, g_loss: 0.1174
# Epoch [1/50], Step [200/1875], d_loss: -0.0331, g_loss: 0.1249
# Epoch [1/50], Step [400/1875], d_loss: 0.0654, g_loss: -0.3964
# Epoch [1/50], Step [600/1875], d_loss: -0.0041, g_loss: 0.1819
# Epoch [1/50], Step [800/1875], d_loss: -0.0033, g_loss: 0.0135
# Epoch [1/50], Step [1000/1875], d_loss: -0.0128, g_loss: 0.1001
# Epoch [1/50], Step [1200/1875], d_loss: -0.0319, g_loss: 0.1374
# Epoch [1/50], Step [1400/1875], d_loss: -0.0086, g_loss: 0.0240
# Epoch [1/50], Step [1600/1875], d_loss: 0.0037, g_loss: -0.1519
# Epoch [1/50], Step [1800/1875], d_loss: -0.0380, g_loss: -0.0967
# Epoch [2/50], Step [200/1875], d_loss: 0.0282, g_loss: -0.1454
# Epoch [2/50], Step [400/1875], d_loss: -0.0213, g_loss: -0.1385
# Epoch [2/50], Step [600/1875], d_loss: -0.0160, g_loss: -0.1500
# Epoch [2/50], Step [800/1875], d_loss: -0.0615, g_loss: -0.1220
# Epoch [2/50], Step [1000/1875], d_loss: -0.0369, g_loss: -0.0712
# Epoch [2/50], Step [1200/1875], d_loss: -0.0213, g_loss: -0.0183
# Epoch [2/50], Step [1400/1875], d_loss: -0.0142, g_loss: 0.0051
# Epoch [2/50], Step [1600/1875], d_loss: -0.0158, g_loss: 0.0028
# Epoch [2/50], Step [1800/1875], d_loss: -0.0037, g_loss: 0.0472
# Epoch [3/50], Step [200/1875], d_loss: -0.0249, g_loss: -0.1502
# Epoch [3/50], Step [400/1875], d_loss: -0.0528, g_loss: -0.1465
# Epoch [3/50], Step [600/1875], d_loss: -0.0455, g_loss: -0.1492
# Epoch [3/50], Step [800/1875], d_loss: -0.0194, g_loss: -0.1371
# Epoch [3/50], Step [1000/1875], d_loss: -0.0526, g_loss: -0.1256
# Epoch [3/50], Step [1200/1875], d_loss: -0.0054, g_loss: 0.0682
# Epoch [3/50], Step [1400/1875], d_loss: -0.0253, g_loss: 0.0962
# Epoch [3/50], Step [1600/1875], d_loss: -0.0327, g_loss: 0.0253
# Epoch [3/50], Step [1800/1875], d_loss: -0.0204, g_loss: -0.0341
# Epoch [4/50], Step [200/1875], d_loss: -0.0211, g_loss: -0.0355
# Epoch [4/50], Step [400/1875], d_loss: -0.0283, g_loss: -0.0381
# Epoch [4/50], Step [600/1875], d_loss: -0.0155, g_loss: -0.1114
# Epoch [4/50], Step [800/1875], d_loss: -0.0271, g_loss: -0.1858
# Epoch [4/50], Step [1000/1875], d_loss: -0.0191, g_loss: -0.3188
# Epoch [4/50], Step [1200/1875], d_loss: -0.0065, g_loss: -0.2248
# Epoch [4/50], Step [1400/1875], d_loss: -0.0133, g_loss: -0.1423
# Epoch [4/50], Step [1600/1875], d_loss: -0.0231, g_loss: -0.1463
# Epoch [4/50], Step [1800/1875], d_loss: -0.0195, g_loss: -0.1787
# Epoch [5/50], Step [200/1875], d_loss: -0.0114, g_loss: -0.2913
# Epoch [5/50], Step [400/1875], d_loss: 0.0008, g_loss: -0.1589
# Epoch [5/50], Step [600/1875], d_loss: -0.0045, g_loss: -0.0364
# Epoch [5/50], Step [800/1875], d_loss: 0.0180, g_loss: -0.1938
# Epoch [5/50], Step [1000/1875], d_loss: -0.0186, g_loss: -0.1764
# Epoch [5/50], Step [1200/1875], d_loss: -0.0380, g_loss: -0.1593
# Epoch [5/50], Step [1400/1875], d_loss: -0.0016, g_loss: -0.2157
# Epoch [5/50], Step [1600/1875], d_loss: 0.0091, g_loss: -0.1880
# Epoch [5/50], Step [1800/1875], d_loss: -0.0320, g_loss: -0.1165
# Epoch [6/50], Step [200/1875], d_loss: -0.0130, g_loss: -0.1291
# Epoch [6/50], Step [400/1875], d_loss: -0.0238, g_loss: -0.0887
# Epoch [6/50], Step [600/1875], d_loss: -0.0113, g_loss: -0.1752
# Epoch [6/50], Step [800/1875], d_loss: -0.0174, g_loss: -0.2638
# Epoch [6/50], Step [1000/1875], d_loss: -0.0360, g_loss: -0.3650
# Epoch [6/50], Step [1200/1875], d_loss: -0.0086, g_loss: -0.1326
# Epoch [6/50], Step [1400/1875], d_loss: -0.0127, g_loss: -0.0773
# Epoch [6/50], Step [1600/1875], d_loss: -0.0086, g_loss: -0.1236
# Epoch [6/50], Step [1800/1875], d_loss: -0.0029, g_loss: -0.1874
# Epoch [7/50], Step [200/1875], d_loss: -0.0262, g_loss: -0.1074
# Epoch [7/50], Step [400/1875], d_loss: -0.0068, g_loss: -0.0774
# Epoch [7/50], Step [600/1875], d_loss: -0.0127, g_loss: -0.0939
# Epoch [7/50], Step [800/1875], d_loss: -0.0044, g_loss: -0.1513
# Epoch [7/50], Step [1000/1875], d_loss: -0.0107, g_loss: -0.2497
# Epoch [7/50], Step [1200/1875], d_loss: 0.0002, g_loss: -0.1547
# Epoch [7/50], Step [1400/1875], d_loss: -0.0108, g_loss: -0.0690
# Epoch [7/50], Step [1600/1875], d_loss: -0.0040, g_loss: -0.1602
# Epoch [7/50], Step [1800/1875], d_loss: -0.0331, g_loss: -0.2848
# Epoch [8/50], Step [200/1875], d_loss: -0.0246, g_loss: -0.0653
# Epoch [8/50], Step [400/1875], d_loss: 0.0090, g_loss: -0.0623
# Epoch [8/50], Step [600/1875], d_loss: -0.0056, g_loss: -0.0992
# Epoch [8/50], Step [800/1875], d_loss: -0.0062, g_loss: -0.1038
# Epoch [8/50], Step [1000/1875], d_loss: -0.0117, g_loss: -0.1099
# Epoch [8/50], Step [1200/1875], d_loss: -0.0102, g_loss: -0.1182
# Epoch [8/50], Step [1400/1875], d_loss: -0.0104, g_loss: -0.1026
# Epoch [8/50], Step [1600/1875], d_loss: 0.0065, g_loss: 0.0696
# Epoch [8/50], Step [1800/1875], d_loss: -0.0013, g_loss: 0.0185
# Epoch [9/50], Step [200/1875], d_loss: 0.0245, g_loss: 0.0876
# Epoch [9/50], Step [400/1875], d_loss: -0.0188, g_loss: 0.1026
# Epoch [9/50], Step [600/1875], d_loss: -0.0104, g_loss: 0.0425
# Epoch [9/50], Step [800/1875], d_loss: -0.0263, g_loss: 0.1368
# Epoch [9/50], Step [1000/1875], d_loss: -0.0143, g_loss: 0.0738
# Epoch [9/50], Step [1200/1875], d_loss: -0.0141, g_loss: 0.0987
# Epoch [9/50], Step [1400/1875], d_loss: -0.0139, g_loss: 0.0434
# Epoch [9/50], Step [1600/1875], d_loss: -0.0060, g_loss: 0.2520
# Epoch [9/50], Step [1800/1875], d_loss: -0.0197, g_loss: 0.1794
# Epoch [10/50], Step [200/1875], d_loss: -0.0002, g_loss: -0.0043
# Epoch [10/50], Step [400/1875], d_loss: -0.0019, g_loss: 0.0194
# Epoch [10/50], Step [600/1875], d_loss: -0.0053, g_loss: 0.0316
# Epoch [10/50], Step [800/1875], d_loss: 0.0061, g_loss: 0.1092
# Epoch [10/50], Step [1000/1875], d_loss: -0.0285, g_loss: 0.1261
# Epoch [10/50], Step [1200/1875], d_loss: -0.0203, g_loss: 0.2817
# Epoch [10/50], Step [1400/1875], d_loss: -0.0276, g_loss: 0.2365
# Epoch [10/50], Step [1600/1875], d_loss: -0.0027, g_loss: 0.0768
# Epoch [10/50], Step [1800/1875], d_loss: 0.0643, g_loss: 0.6937
# Epoch [11/50], Step [200/1875], d_loss: -0.0244, g_loss: 0.2294
# Epoch [11/50], Step [400/1875], d_loss: -0.0003, g_loss: -0.0212
# Epoch [11/50], Step [600/1875], d_loss: 0.0123, g_loss: 0.1353
# Epoch [11/50], Step [800/1875], d_loss: -0.0052, g_loss: 0.2011
# Epoch [11/50], Step [1000/1875], d_loss: -0.0053, g_loss: 0.1890
# Epoch [11/50], Step [1200/1875], d_loss: -0.0060, g_loss: 0.1612
# Epoch [11/50], Step [1400/1875], d_loss: -0.0102, g_loss: 0.1244
# Epoch [11/50], Step [1600/1875], d_loss: -0.0041, g_loss: 0.1416
# Epoch [11/50], Step [1800/1875], d_loss: -0.0060, g_loss: 0.0921
# Epoch [12/50], Step [200/1875], d_loss: -0.0025, g_loss: 0.0257
# Epoch [12/50], Step [400/1875], d_loss: 0.0024, g_loss: 0.0047
# Epoch [12/50], Step [600/1875], d_loss: 0.0159, g_loss: -0.0351
# Epoch [12/50], Step [800/1875], d_loss: 0.0060, g_loss: 0.0156
# Epoch [12/50], Step [1000/1875], d_loss: 0.0109, g_loss: 0.0055
# Epoch [12/50], Step [1200/1875], d_loss: -0.0186, g_loss: -0.0747
# Epoch [12/50], Step [1400/1875], d_loss: -0.0144, g_loss: 0.0694
# Epoch [12/50], Step [1600/1875], d_loss: -0.0201, g_loss: 0.1236
# Epoch [12/50], Step [1800/1875], d_loss: 0.0346, g_loss: 0.4599
# Epoch [13/50], Step [200/1875], d_loss: -0.0074, g_loss: 0.0832
# Epoch [13/50], Step [400/1875], d_loss: 0.0347, g_loss: 0.2552
# Epoch [13/50], Step [600/1875], d_loss: -0.0173, g_loss: 0.0912
# Epoch [13/50], Step [800/1875], d_loss: 0.0199, g_loss: 0.2331
# Epoch [13/50], Step [1000/1875], d_loss: -0.0062, g_loss: 0.0698
# Epoch [13/50], Step [1200/1875], d_loss: 0.0020, g_loss: 0.1796
# Epoch [13/50], Step [1400/1875], d_loss: 0.0004, g_loss: 0.1284
# Epoch [13/50], Step [1600/1875], d_loss: -0.0024, g_loss: 0.0870
# Epoch [13/50], Step [1800/1875], d_loss: -0.0041, g_loss: 0.0529
# Epoch [14/50], Step [200/1875], d_loss: -0.0021, g_loss: 0.0276
# Epoch [14/50], Step [400/1875], d_loss: 0.0136, g_loss: 0.1074
# Epoch [14/50], Step [600/1875], d_loss: -0.0137, g_loss: 0.1102
# Epoch [14/50], Step [800/1875], d_loss: -0.0022, g_loss: 0.1604
# Epoch [14/50], Step [1000/1875], d_loss: -0.0073, g_loss: 0.0012
# Epoch [14/50], Step [1200/1875], d_loss: -0.0013, g_loss: 0.0320
# Epoch [14/50], Step [1400/1875], d_loss: 0.0024, g_loss: 0.0370
# Epoch [14/50], Step [1600/1875], d_loss: -0.0026, g_loss: 0.0316
# Epoch [14/50], Step [1800/1875], d_loss: -0.0128, g_loss: 0.0957
# Epoch [15/50], Step [200/1875], d_loss: -0.0010, g_loss: 0.0274
# Epoch [15/50], Step [400/1875], d_loss: 0.0046, g_loss: 0.1554
# Epoch [15/50], Step [600/1875], d_loss: -0.0124, g_loss: -0.0637
# Epoch [15/50], Step [800/1875], d_loss: -0.0028, g_loss: 0.0130
# Epoch [15/50], Step [1000/1875], d_loss: -0.0025, g_loss: 0.0335
# Epoch [15/50], Step [1200/1875], d_loss: -0.0001, g_loss: -0.0002
# Epoch [15/50], Step [1400/1875], d_loss: 0.0025, g_loss: 0.2168
# Epoch [15/50], Step [1600/1875], d_loss: -0.0026, g_loss: 0.0400
# Epoch [15/50], Step [1800/1875], d_loss: -0.0001, g_loss: -0.0012
# Epoch [16/50], Step [200/1875], d_loss: -0.0000, g_loss: 0.0157
# Epoch [16/50], Step [400/1875], d_loss: -0.0001, g_loss: 0.0125
# Epoch [16/50], Step [600/1875], d_loss: -0.0024, g_loss: -0.1631
# Epoch [16/50], Step [800/1875], d_loss: 0.0010, g_loss: 0.0230
# Epoch [16/50], Step [1000/1875], d_loss: 0.0081, g_loss: -0.0011
# Epoch [16/50], Step [1200/1875], d_loss: -0.0001, g_loss: 0.0049
# Epoch [16/50], Step [1400/1875], d_loss: -0.0097, g_loss: 0.1091
# Epoch [16/50], Step [1600/1875], d_loss: -0.0029, g_loss: -0.0060
# Epoch [16/50], Step [1800/1875], d_loss: -0.0007, g_loss: 0.0017
# Epoch [17/50], Step [200/1875], d_loss: 0.0100, g_loss: 0.0933
# Epoch [17/50], Step [400/1875], d_loss: 0.0004, g_loss: 0.0099
# Epoch [17/50], Step [600/1875], d_loss: -0.0018, g_loss: 0.0150
# Epoch [17/50], Step [800/1875], d_loss: 0.0101, g_loss: -0.1121
# Epoch [17/50], Step [1000/1875], d_loss: 0.0001, g_loss: 0.0062
# Epoch [17/50], Step [1200/1875], d_loss: -0.0057, g_loss: 0.0549
# Epoch [17/50], Step [1400/1875], d_loss: 0.0024, g_loss: 0.0316
# Epoch [17/50], Step [1600/1875], d_loss: 0.0002, g_loss: -0.3314
# Epoch [17/50], Step [1800/1875], d_loss: 0.0035, g_loss: 0.0115
# Epoch [18/50], Step [200/1875], d_loss: -0.0004, g_loss: -0.0632
# Epoch [18/50], Step [400/1875], d_loss: 0.0046, g_loss: -0.0372
# Epoch [18/50], Step [600/1875], d_loss: 0.0115, g_loss: -0.2126
# Epoch [18/50], Step [800/1875], d_loss: -0.0076, g_loss: -0.1389
# Epoch [18/50], Step [1000/1875], d_loss: -0.0078, g_loss: -0.1351
# Epoch [18/50], Step [1200/1875], d_loss: -0.0062, g_loss: -0.1213
# Epoch [18/50], Step [1400/1875], d_loss: -0.0059, g_loss: -0.0454
# Epoch [18/50], Step [1600/1875], d_loss: -0.0068, g_loss: -0.1335
# Epoch [18/50], Step [1800/1875], d_loss: 0.0025, g_loss: -0.1471
# Epoch [19/50], Step [200/1875], d_loss: 0.0006, g_loss: -0.0788
# Epoch [19/50], Step [400/1875], d_loss: -0.0084, g_loss: -0.1949
# Epoch [19/50], Step [600/1875], d_loss: -0.0070, g_loss: -0.2957
# Epoch [19/50], Step [800/1875], d_loss: -0.0004, g_loss: -0.1030
# Epoch [19/50], Step [1000/1875], d_loss: 0.0005, g_loss: -0.1130
# Epoch [19/50], Step [1200/1875], d_loss: -0.0081, g_loss: -0.0900
# Epoch [19/50], Step [1400/1875], d_loss: -0.0004, g_loss: -0.0630
# Epoch [19/50], Step [1600/1875], d_loss: -0.0095, g_loss: 0.0393
# Epoch [19/50], Step [1800/1875], d_loss: -0.0128, g_loss: 0.1040
# Epoch [20/50], Step [200/1875], d_loss: -0.0852, g_loss: -0.2950
# Epoch [20/50], Step [400/1875], d_loss: -0.0395, g_loss: 0.0464
# Epoch [20/50], Step [600/1875], d_loss: 0.0198, g_loss: -0.3963
# Epoch [20/50], Step [800/1875], d_loss: 0.0029, g_loss: 0.0311
# Epoch [20/50], Step [1000/1875], d_loss: -0.0015, g_loss: 0.0155
# Epoch [20/50], Step [1200/1875], d_loss: 0.0185, g_loss: 0.0740
# Epoch [20/50], Step [1400/1875], d_loss: -0.0034, g_loss: -0.2552
# Epoch [20/50], Step [1600/1875], d_loss: 0.0057, g_loss: 0.0834
# Epoch [20/50], Step [1800/1875], d_loss: -0.0047, g_loss: 0.0152
# Epoch [21/50], Step [200/1875], d_loss: -0.0016, g_loss: -0.0015
# Epoch [21/50], Step [400/1875], d_loss: -0.0020, g_loss: 0.0087
# Epoch [21/50], Step [600/1875], d_loss: -0.0033, g_loss: 0.0080
# Epoch [21/50], Step [800/1875], d_loss: -0.0132, g_loss: 0.1320
# Epoch [21/50], Step [1000/1875], d_loss: -0.0019, g_loss: 0.0024
# Epoch [21/50], Step [1200/1875], d_loss: 0.0100, g_loss: 0.1100
# Epoch [21/50], Step [1400/1875], d_loss: 0.0007, g_loss: 0.0359
# Epoch [21/50], Step [1600/1875], d_loss: -0.0000, g_loss: 0.0164
# Epoch [21/50], Step [1800/1875], d_loss: 0.0085, g_loss: 0.0391
# Epoch [22/50], Step [200/1875], d_loss: -0.0208, g_loss: 0.2523
# Epoch [22/50], Step [400/1875], d_loss: -0.0018, g_loss: 0.0350
# Epoch [22/50], Step [600/1875], d_loss: -0.0093, g_loss: 0.0764
# Epoch [22/50], Step [800/1875], d_loss: -0.0008, g_loss: 0.0277
# Epoch [22/50], Step [1000/1875], d_loss: 0.0002, g_loss: 0.0194
# Epoch [22/50], Step [1200/1875], d_loss: -0.0159, g_loss: 0.0439
# Epoch [22/50], Step [1400/1875], d_loss: -0.0231, g_loss: 0.3629
# Epoch [22/50], Step [1600/1875], d_loss: -0.0159, g_loss: 0.3790
# Epoch [22/50], Step [1800/1875], d_loss: 0.0225, g_loss: -0.1402
# Epoch [23/50], Step [200/1875], d_loss: -0.0123, g_loss: 0.0118
# Epoch [23/50], Step [400/1875], d_loss: -0.0080, g_loss: 0.1348
# Epoch [23/50], Step [600/1875], d_loss: -0.0055, g_loss: 0.0617
# Epoch [23/50], Step [800/1875], d_loss: -0.0097, g_loss: 0.0795
# Epoch [23/50], Step [1000/1875], d_loss: -0.0301, g_loss: 0.0026
# Epoch [23/50], Step [1200/1875], d_loss: 0.0209, g_loss: 0.1204
# Epoch [23/50], Step [1400/1875], d_loss: -0.0034, g_loss: 0.0663
# Epoch [23/50], Step [1600/1875], d_loss: -0.0204, g_loss: -0.0033
# Epoch [23/50], Step [1800/1875], d_loss: -0.0038, g_loss: 0.0258
# Epoch [24/50], Step [200/1875], d_loss: -0.0028, g_loss: 0.0188
# Epoch [24/50], Step [400/1875], d_loss: -0.0144, g_loss: 0.1163
# Epoch [24/50], Step [600/1875], d_loss: -0.0163, g_loss: 0.0846
# Epoch [24/50], Step [800/1875], d_loss: -0.0046, g_loss: -0.0759
# Epoch [24/50], Step [1000/1875], d_loss: -0.0036, g_loss: -0.1621
# Epoch [24/50], Step [1200/1875], d_loss: -0.0027, g_loss: -0.0049
# Epoch [24/50], Step [1400/1875], d_loss: 0.0184, g_loss: 0.1338
# Epoch [24/50], Step [1600/1875], d_loss: -0.0028, g_loss: -0.0089
# Epoch [24/50], Step [1800/1875], d_loss: -0.0066, g_loss: -0.0395
# Epoch [25/50], Step [200/1875], d_loss: -0.0073, g_loss: -0.0800
# Epoch [25/50], Step [400/1875], d_loss: -0.0007, g_loss: -0.1198
# Epoch [25/50], Step [600/1875], d_loss: -0.0026, g_loss: -0.0586
# Epoch [25/50], Step [800/1875], d_loss: 0.0090, g_loss: -0.1084
# Epoch [25/50], Step [1000/1875], d_loss: -0.0043, g_loss: -0.0836
# Epoch [25/50], Step [1200/1875], d_loss: 0.0054, g_loss: -0.0627
# Epoch [25/50], Step [1400/1875], d_loss: -0.0019, g_loss: -0.0778
# Epoch [25/50], Step [1600/1875], d_loss: 0.0022, g_loss: -0.0327
# Epoch [25/50], Step [1800/1875], d_loss: -0.0073, g_loss: -0.0940
# Epoch [26/50], Step [200/1875], d_loss: -0.0028, g_loss: 0.0284
# Epoch [26/50], Step [400/1875], d_loss: -0.0024, g_loss: -0.0084
# Epoch [26/50], Step [600/1875], d_loss: -0.0117, g_loss: 0.0013
# Epoch [26/50], Step [800/1875], d_loss: -0.0018, g_loss: 0.0951
# Epoch [26/50], Step [1000/1875], d_loss: -0.0198, g_loss: -0.0285
# Epoch [26/50], Step [1200/1875], d_loss: -0.0187, g_loss: -0.0188
# Epoch [26/50], Step [1400/1875], d_loss: -0.0017, g_loss: -0.0585
# Epoch [26/50], Step [1600/1875], d_loss: -0.0039, g_loss: 0.0653
# Epoch [26/50], Step [1800/1875], d_loss: 0.0012, g_loss: -0.0346
# Epoch [27/50], Step [200/1875], d_loss: -0.0004, g_loss: -0.0451
# Epoch [27/50], Step [400/1875], d_loss: 0.0299, g_loss: -0.1509
# Epoch [27/50], Step [600/1875], d_loss: -0.0016, g_loss: -0.0422
# Epoch [27/50], Step [800/1875], d_loss: -0.0046, g_loss: 0.0259
# Epoch [27/50], Step [1000/1875], d_loss: -0.0010, g_loss: -0.0582
# Epoch [27/50], Step [1200/1875], d_loss: -0.0023, g_loss: -0.0346
# Epoch [27/50], Step [1400/1875], d_loss: -0.0118, g_loss: -0.1695
# Epoch [27/50], Step [1600/1875], d_loss: 0.0045, g_loss: -0.0097
# Epoch [27/50], Step [1800/1875], d_loss: 0.0100, g_loss: 0.0016
# Epoch [28/50], Step [200/1875], d_loss: 0.0007, g_loss: 0.0177
# Epoch [28/50], Step [400/1875], d_loss: -0.0057, g_loss: -0.0352
# Epoch [28/50], Step [600/1875], d_loss: -0.0008, g_loss: 0.0091
# Epoch [28/50], Step [800/1875], d_loss: -0.0005, g_loss: 0.0064
# Epoch [28/50], Step [1000/1875], d_loss: -0.0084, g_loss: 0.0533
# Epoch [28/50], Step [1200/1875], d_loss: 0.0282, g_loss: 0.3752
# Epoch [28/50], Step [1400/1875], d_loss: 0.0016, g_loss: 0.1066
# Epoch [28/50], Step [1600/1875], d_loss: -0.0041, g_loss: 0.0593
# Epoch [28/50], Step [1800/1875], d_loss: -0.0032, g_loss: 0.2784
# Epoch [29/50], Step [200/1875], d_loss: -0.0090, g_loss: 0.0776
# Epoch [29/50], Step [400/1875], d_loss: -0.0096, g_loss: 0.0832
# Epoch [29/50], Step [600/1875], d_loss: -0.0076, g_loss: 0.1045
# Epoch [29/50], Step [800/1875], d_loss: -0.0092, g_loss: 0.0477
# Epoch [29/50], Step [1000/1875], d_loss: -0.0027, g_loss: 0.0619
# Epoch [29/50], Step [1200/1875], d_loss: -0.0109, g_loss: 0.0597
# Epoch [29/50], Step [1400/1875], d_loss: -0.0058, g_loss: 0.0647
# Epoch [29/50], Step [1600/1875], d_loss: -0.0057, g_loss: 0.0658
# Epoch [29/50], Step [1800/1875], d_loss: -0.0062, g_loss: 0.0556
# Epoch [30/50], Step [200/1875], d_loss: -0.0066, g_loss: 0.0492
# Epoch [30/50], Step [400/1875], d_loss: -0.0055, g_loss: 0.0343
# Epoch [30/50], Step [600/1875], d_loss: -0.0044, g_loss: 0.0315
# Epoch [30/50], Step [800/1875], d_loss: -0.0040, g_loss: 0.0374
# Epoch [30/50], Step [1000/1875], d_loss: -0.0043, g_loss: 0.0382
# Epoch [30/50], Step [1200/1875], d_loss: -0.0050, g_loss: 0.0413
# Epoch [30/50], Step [1400/1875], d_loss: -0.0029, g_loss: 0.0376
# Epoch [30/50], Step [1600/1875], d_loss: 0.0222, g_loss: 0.1750
# Epoch [30/50], Step [1800/1875], d_loss: -0.0002, g_loss: 0.0168
# Epoch [31/50], Step [200/1875], d_loss: -0.0057, g_loss: 0.3104
# Epoch [31/50], Step [400/1875], d_loss: -0.0146, g_loss: 0.0281
# Epoch [31/50], Step [600/1875], d_loss: 0.0019, g_loss: 0.0702
# Epoch [31/50], Step [800/1875], d_loss: -0.0140, g_loss: 0.0721
# Epoch [31/50], Step [1000/1875], d_loss: -0.0173, g_loss: -0.1342
# Epoch [31/50], Step [1200/1875], d_loss: -0.0001, g_loss: 0.0460
# Epoch [31/50], Step [1400/1875], d_loss: 0.0016, g_loss: -0.0157
# Epoch [31/50], Step [1600/1875], d_loss: -0.0022, g_loss: -0.0252
# Epoch [31/50], Step [1800/1875], d_loss: -0.0159, g_loss: 0.1063
# Epoch [32/50], Step [200/1875], d_loss: 0.0085, g_loss: -0.0764
# Epoch [32/50], Step [400/1875], d_loss: -0.0007, g_loss: 0.0004
# Epoch [32/50], Step [600/1875], d_loss: -0.0056, g_loss: -0.0134
# Epoch [32/50], Step [800/1875], d_loss: -0.0070, g_loss: -0.0294
# Epoch [32/50], Step [1000/1875], d_loss: -0.0190, g_loss: 0.0715
# Epoch [32/50], Step [1200/1875], d_loss: -0.0064, g_loss: 0.0687
# Epoch [32/50], Step [1400/1875], d_loss: -0.0069, g_loss: -0.0281
# Epoch [32/50], Step [1600/1875], d_loss: -0.0011, g_loss: -0.0211
# Epoch [32/50], Step [1800/1875], d_loss: -0.0092, g_loss: -0.0935
# Epoch [33/50], Step [200/1875], d_loss: -0.0011, g_loss: -0.1242
# Epoch [33/50], Step [400/1875], d_loss: -0.0001, g_loss: -0.0433
# Epoch [33/50], Step [600/1875], d_loss: -0.0041, g_loss: 0.0075
# Epoch [33/50], Step [800/1875], d_loss: 0.0011, g_loss: -0.1267
# Epoch [33/50], Step [1000/1875], d_loss: 0.0048, g_loss: -0.0166
# Epoch [33/50], Step [1200/1875], d_loss: -0.0058, g_loss: 0.0413
# Epoch [33/50], Step [1400/1875], d_loss: -0.0020, g_loss: 0.0012
# Epoch [33/50], Step [1600/1875], d_loss: -0.0105, g_loss: 0.0036
# Epoch [33/50], Step [1800/1875], d_loss: 0.0022, g_loss: 0.0129
# Epoch [34/50], Step [200/1875], d_loss: -0.0003, g_loss: 0.0192
# Epoch [34/50], Step [400/1875], d_loss: 0.0002, g_loss: 0.0108
# Epoch [34/50], Step [600/1875], d_loss: 0.0004, g_loss: 0.0338
# Epoch [34/50], Step [800/1875], d_loss: 0.0239, g_loss: 0.2478
# Epoch [34/50], Step [1000/1875], d_loss: -0.0031, g_loss: -0.0711
# Epoch [34/50], Step [1200/1875], d_loss: -0.0051, g_loss: -0.0272
# Epoch [34/50], Step [1400/1875], d_loss: -0.0033, g_loss: -0.0632
# Epoch [34/50], Step [1600/1875], d_loss: -0.0028, g_loss: -0.0440
# Epoch [34/50], Step [1800/1875], d_loss: 0.0005, g_loss: -0.0895
# Epoch [35/50], Step [200/1875], d_loss: 0.0025, g_loss: -0.1183
# Epoch [35/50], Step [400/1875], d_loss: -0.0031, g_loss: -0.0905
# Epoch [35/50], Step [600/1875], d_loss: 0.0014, g_loss: 0.0619
# Epoch [35/50], Step [800/1875], d_loss: -0.0098, g_loss: -0.0082
# Epoch [35/50], Step [1000/1875], d_loss: -0.0059, g_loss: -0.2196
# Epoch [35/50], Step [1200/1875], d_loss: -0.0033, g_loss: -0.0539
# Epoch [35/50], Step [1400/1875], d_loss: 0.0034, g_loss: 0.0437
# Epoch [35/50], Step [1600/1875], d_loss: -0.0018, g_loss: 0.0039
# Epoch [35/50], Step [1800/1875], d_loss: -0.0257, g_loss: -0.2197
# Epoch [36/50], Step [200/1875], d_loss: -0.0008, g_loss: -0.0842
# Epoch [36/50], Step [400/1875], d_loss: -0.0094, g_loss: 0.0499
# Epoch [36/50], Step [600/1875], d_loss: -0.0010, g_loss: -0.0337
# Epoch [36/50], Step [800/1875], d_loss: 0.0029, g_loss: -0.0742
# Epoch [36/50], Step [1000/1875], d_loss: -0.0462, g_loss: -0.1241
# Epoch [36/50], Step [1200/1875], d_loss: 0.0012, g_loss: 0.1628
# Epoch [36/50], Step [1400/1875], d_loss: -0.0036, g_loss: 0.0264
# Epoch [36/50], Step [1600/1875], d_loss: 0.0007, g_loss: 0.0031
# Epoch [36/50], Step [1800/1875], d_loss: -0.0002, g_loss: 0.0104
# Epoch [37/50], Step [200/1875], d_loss: -0.0045, g_loss: 0.1048
# Epoch [37/50], Step [400/1875], d_loss: 0.0081, g_loss: -0.0464
# Epoch [37/50], Step [600/1875], d_loss: 0.0056, g_loss: 0.1192
# Epoch [37/50], Step [800/1875], d_loss: -0.0011, g_loss: -0.0348
# Epoch [37/50], Step [1000/1875], d_loss: -0.0003, g_loss: -0.0622
# Epoch [37/50], Step [1200/1875], d_loss: -0.0016, g_loss: -0.0144
# Epoch [37/50], Step [1400/1875], d_loss: -0.0092, g_loss: -0.1033
# Epoch [37/50], Step [1600/1875], d_loss: 0.0167, g_loss: 0.1674
# Epoch [37/50], Step [1800/1875], d_loss: 0.0026, g_loss: -0.0774
# Epoch [38/50], Step [200/1875], d_loss: -0.0117, g_loss: 0.1636
# Epoch [38/50], Step [400/1875], d_loss: 0.0117, g_loss: -0.0603
# Epoch [38/50], Step [600/1875], d_loss: 0.0013, g_loss: 0.0236
# Epoch [38/50], Step [800/1875], d_loss: 0.0149, g_loss: -0.0554
# Epoch [38/50], Step [1000/1875], d_loss: -0.0107, g_loss: 0.0640
# Epoch [38/50], Step [1200/1875], d_loss: -0.0014, g_loss: -0.0037
# Epoch [38/50], Step [1400/1875], d_loss: -0.0072, g_loss: -0.0745
# Epoch [38/50], Step [1600/1875], d_loss: -0.0001, g_loss: -0.0138
# Epoch [38/50], Step [1800/1875], d_loss: -0.0111, g_loss: -0.0844
# Epoch [39/50], Step [200/1875], d_loss: 0.0015, g_loss: -0.1380
# Epoch [39/50], Step [400/1875], d_loss: 0.0088, g_loss: 0.0521
# Epoch [39/50], Step [600/1875], d_loss: 0.0009, g_loss: -0.0295
# Epoch [39/50], Step [800/1875], d_loss: -0.0006, g_loss: -0.0335
# Epoch [39/50], Step [1000/1875], d_loss: -0.0001, g_loss: -0.0225
# Epoch [39/50], Step [1200/1875], d_loss: -0.0029, g_loss: -0.0176
# Epoch [39/50], Step [1400/1875], d_loss: -0.0000, g_loss: -0.0083
# Epoch [39/50], Step [1600/1875], d_loss: -0.0251, g_loss: -0.1888
# Epoch [39/50], Step [1800/1875], d_loss: -0.0035, g_loss: -0.0298
# Epoch [40/50], Step [200/1875], d_loss: -0.0018, g_loss: -0.0577
# Epoch [40/50], Step [400/1875], d_loss: 0.0021, g_loss: -0.1037
# Epoch [40/50], Step [600/1875], d_loss: -0.0016, g_loss: -0.0930
# Epoch [40/50], Step [800/1875], d_loss: -0.0034, g_loss: -0.0779
# Epoch [40/50], Step [1000/1875], d_loss: 0.0005, g_loss: -0.0910
# Epoch [40/50], Step [1200/1875], d_loss: -0.0213, g_loss: -0.3939
# Epoch [40/50], Step [1400/1875], d_loss: 0.0027, g_loss: 0.0419
# Epoch [40/50], Step [1600/1875], d_loss: 0.0030, g_loss: -0.0360
# Epoch [40/50], Step [1800/1875], d_loss: -0.0035, g_loss: -0.2133
# Epoch [41/50], Step [200/1875], d_loss: -0.0095, g_loss: -0.2032
# Epoch [41/50], Step [400/1875], d_loss: -0.0006, g_loss: -0.1955
# Epoch [41/50], Step [600/1875], d_loss: -0.0021, g_loss: -0.1756
# Epoch [41/50], Step [800/1875], d_loss: 0.0016, g_loss: -0.1547
# Epoch [41/50], Step [1000/1875], d_loss: -0.0031, g_loss: -0.1678
# Epoch [41/50], Step [1200/1875], d_loss: -0.0066, g_loss: -0.1225
# Epoch [41/50], Step [1400/1875], d_loss: -0.0005, g_loss: -0.1752
# Epoch [41/50], Step [1600/1875], d_loss: 0.0004, g_loss: -0.1316
# Epoch [41/50], Step [1800/1875], d_loss: 0.0031, g_loss: -0.1146
# Epoch [42/50], Step [200/1875], d_loss: -0.0031, g_loss: -0.1391
# Epoch [42/50], Step [400/1875], d_loss: 0.0005, g_loss: -0.1824
# Epoch [42/50], Step [600/1875], d_loss: 0.0000, g_loss: -0.1265
# Epoch [42/50], Step [800/1875], d_loss: -0.0040, g_loss: -0.0756
# Epoch [42/50], Step [1000/1875], d_loss: -0.0057, g_loss: -0.1379
# Epoch [42/50], Step [1200/1875], d_loss: -0.0031, g_loss: -0.1559
# Epoch [42/50], Step [1400/1875], d_loss: -0.0036, g_loss: -0.1528
# Epoch [42/50], Step [1600/1875], d_loss: -0.0047, g_loss: -0.1139
# Epoch [42/50], Step [1800/1875], d_loss: -0.0057, g_loss: -0.1357
# Epoch [43/50], Step [200/1875], d_loss: -0.0033, g_loss: -0.1526
# Epoch [43/50], Step [400/1875], d_loss: -0.0051, g_loss: -0.1642
# Epoch [43/50], Step [600/1875], d_loss: -0.0035, g_loss: -0.1471
# Epoch [43/50], Step [800/1875], d_loss: -0.0018, g_loss: -0.2060
# Epoch [43/50], Step [1000/1875], d_loss: 0.0013, g_loss: 0.0031
# Epoch [43/50], Step [1200/1875], d_loss: -0.0073, g_loss: -0.0584
# Epoch [43/50], Step [1400/1875], d_loss: 0.0035, g_loss: -0.1266
# Epoch [43/50], Step [1600/1875], d_loss: 0.0071, g_loss: -0.1469
# Epoch [43/50], Step [1800/1875], d_loss: -0.0002, g_loss: -0.1419
# Epoch [44/50], Step [200/1875], d_loss: -0.0073, g_loss: -0.1376
# Epoch [44/50], Step [400/1875], d_loss: -0.0034, g_loss: -0.0340
# Epoch [44/50], Step [600/1875], d_loss: 0.0010, g_loss: -0.0636
# Epoch [44/50], Step [800/1875], d_loss: 0.0001, g_loss: -0.0286
# Epoch [44/50], Step [1000/1875], d_loss: -0.0020, g_loss: -0.0398
# Epoch [44/50], Step [1200/1875], d_loss: -0.0025, g_loss: -0.0653
# Epoch [44/50], Step [1400/1875], d_loss: -0.0025, g_loss: -0.0795
# Epoch [44/50], Step [1600/1875], d_loss: -0.0038, g_loss: -0.0543
# Epoch [44/50], Step [1800/1875], d_loss: -0.0027, g_loss: -0.1229
# Epoch [45/50], Step [200/1875], d_loss: -0.0012, g_loss: -0.1655
# Epoch [45/50], Step [400/1875], d_loss: -0.0051, g_loss: -0.1637
# Epoch [45/50], Step [600/1875], d_loss: -0.0034, g_loss: -0.0703
# Epoch [45/50], Step [800/1875], d_loss: -0.0016, g_loss: 0.0165
# Epoch [45/50], Step [1000/1875], d_loss: 0.0000, g_loss: 0.0186
# Epoch [45/50], Step [1200/1875], d_loss: -0.0066, g_loss: -0.1369
# Epoch [45/50], Step [1400/1875], d_loss: -0.0037, g_loss: -0.1470
# Epoch [45/50], Step [1600/1875], d_loss: -0.0030, g_loss: -0.1491
# Epoch [45/50], Step [1800/1875], d_loss: 0.0084, g_loss: -0.1914
# Epoch [46/50], Step [200/1875], d_loss: -0.0040, g_loss: -0.1928
# Epoch [46/50], Step [400/1875], d_loss: 0.0086, g_loss: -0.1558
# Epoch [46/50], Step [600/1875], d_loss: -0.0008, g_loss: -0.1334
# Epoch [46/50], Step [800/1875], d_loss: -0.0019, g_loss: -0.1419
# Epoch [46/50], Step [1000/1875], d_loss: 0.0017, g_loss: -0.1196
# Epoch [46/50], Step [1200/1875], d_loss: -0.0021, g_loss: -0.1470
# Epoch [46/50], Step [1400/1875], d_loss: 0.0015, g_loss: -0.1525
# Epoch [46/50], Step [1600/1875], d_loss: -0.0001, g_loss: -0.1573
# Epoch [46/50], Step [1800/1875], d_loss: 0.0002, g_loss: -0.1646
# Epoch [47/50], Step [200/1875], d_loss: 0.0027, g_loss: -0.1933
# Epoch [47/50], Step [400/1875], d_loss: 0.0044, g_loss: -0.1783
# Epoch [47/50], Step [600/1875], d_loss: 0.0078, g_loss: -0.1691
# Epoch [47/50], Step [800/1875], d_loss: -0.0017, g_loss: -0.1628
# Epoch [47/50], Step [1000/1875], d_loss: 0.0027, g_loss: -0.1320
# Epoch [47/50], Step [1200/1875], d_loss: -0.0042, g_loss: -0.1359
# Epoch [47/50], Step [1400/1875], d_loss: 0.0031, g_loss: -0.1033
# Epoch [47/50], Step [1600/1875], d_loss: -0.0066, g_loss: -0.0897
# Epoch [47/50], Step [1800/1875], d_loss: -0.0002, g_loss: -0.1343
# Epoch [48/50], Step [200/1875], d_loss: 0.0003, g_loss: -0.1775
# Epoch [48/50], Step [400/1875], d_loss: 0.0050, g_loss: -0.1691
# Epoch [48/50], Step [600/1875], d_loss: 0.0023, g_loss: -0.1615
# Epoch [48/50], Step [800/1875], d_loss: -0.0166, g_loss: -0.2045
# Epoch [48/50], Step [1000/1875], d_loss: 0.0037, g_loss: -0.1825
# Epoch [48/50], Step [1200/1875], d_loss: -0.0015, g_loss: -0.1340
# Epoch [48/50], Step [1400/1875], d_loss: -0.0013, g_loss: -0.1128
# Epoch [48/50], Step [1600/1875], d_loss: 0.0012, g_loss: -0.1183
# Epoch [48/50], Step [1800/1875], d_loss: -0.0036, g_loss: -0.0975
# Epoch [49/50], Step [200/1875], d_loss: -0.0016, g_loss: -0.1635
# Epoch [49/50], Step [400/1875], d_loss: -0.0066, g_loss: -0.1675
# Epoch [49/50], Step [600/1875], d_loss: 0.0006, g_loss: -0.1485
# Epoch [49/50], Step [800/1875], d_loss: 0.0040, g_loss: -0.1627
# Epoch [49/50], Step [1000/1875], d_loss: -0.0010, g_loss: -0.1549
# Epoch [49/50], Step [1200/1875], d_loss: 0.0031, g_loss: -0.1570
# Epoch [49/50], Step [1400/1875], d_loss: -0.0045, g_loss: -0.1438
# Epoch [49/50], Step [1600/1875], d_loss: 0.0041, g_loss: -0.2757
# Epoch [49/50], Step [1800/1875], d_loss: -0.0016, g_loss: -0.0924

# %% [markdown]
# ### Visualization

# %%
# Display losses for both the generator and discriminator
plt.figure()
plt.plot(range(1, num_epochs + 1), d_losses, label = 'd loss')
plt.plot(range(1, num_epochs + 1), g_losses, label = 'g loss')
plt.legend()
plt.show()

# %%
# Generate a few fake samples (5 of them) for visualization
n_samples = 5
z = torch.randn(n_samples, latent_size).cuda()
z = Variable(z)
fake_images = G(z)
fake_images = fake_images.cpu().detach().numpy().reshape(n_samples, 28, 28)
print(fake_images.shape)
# Out:
# (5, 28, 28)

# %%
# Display
plt.figure()
plt.imshow(fake_images[0])
plt.show()
plt.figure()
plt.imshow(fake_images[1])
plt.show()
plt.figure()
plt.imshow(fake_images[2])
plt.show()
plt.figure()
plt.imshow(fake_images[3])
plt.show()
plt.figure()
plt.imshow(fake_images[4])
plt.show()

# %% [markdown]
# ### Questions and expected answers for the report
#
# 1. [15 points] Copy and paste the code for your Critic class. Briefly explain your choice of architecture.
#
#
# 2. [15 points] Copy and paste the code for your Generator class. Briefly explain your choice of architecture.
#
#
# 3. [5 points] For how many iterations did you have to train when using Wasserstein with Conv/TransposeConv layers to get plausible images from the generator? Is it training faster than the Fully Connected Wasserstein/Vanilla GAN?
#
#
# 4. [5 points] Display some samples generated by your trained generator. Do they look plausible?
#
#
# 5. [10 points] Let us assume we use Conv2d layers in the Critic. We do NOT use Transposed Conv2d layers, but only Fully Connected layers in the Generator. Would the GAN still be able to train both models or would it encounter difficulties? Discuss.
